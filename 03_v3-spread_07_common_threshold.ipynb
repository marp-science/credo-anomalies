# %%
import numpy as np

from commons import *
from dataset_loader import load_images, prepare_dataset, load_from_file
from IPython.display import display
import cv2
import pickle
import matplotlib.pyplot as plt
from keras.models import load_model


# TODO: https://pl.wikipedia.org/wiki/Dywergencja_Kullbacka-Leiblera
# https://towardsdatascience.com/kl-divergence-python-example-b87069e4b810
# TODO: entropia wzajemna, cross entropy


DOTS_AC = 'cache/dots_v3_spread.h5'
TRACKS_AC = 'cache/tracks_v3_spread.h5'
WORMS_AC = 'cache/worms_v3_spread.h5'
ARTIFACTS_AC = 'cache/artifacts_v3_spread.h5'

DOTS_SPREAD = 'cache/dots_v3_spread.pickle'
WORMS_SPREAD = 'cache/worms_v3_spread.pickle'
TRACKS_SPREAD = 'cache/tracks_v3_spread.pickle'
ARTIFACTS_SPREAD = 'cache/artifacts_v3_spread.pickle'

dots_set =  prepare_dataset(load_from_file(DOTS_SPREAD)[0])
worms_set =  prepare_dataset(load_from_file(WORMS_SPREAD)[0])
tracks_set =  prepare_dataset(load_from_file(TRACKS_SPREAD)[0])
artifacts_set =  prepare_dataset(load_from_file(ARTIFACTS_SPREAD)[0])

dots_autoencoder = load_model(DOTS_AC)
worms_autoencoder = load_model(WORMS_AC)
tracks_autoencoder = load_model(TRACKS_AC)
artifacts_autoencoder = load_model(ARTIFACTS_AC)

# %%
# def find_threshold(sa, sb):
#     a = sorted(sa)
#     b = sorted(sb)
#
#     la = len(a)
#     lb = len(b)
#
#     if la > lb:
#         from scipy.ndimage import zoom
#         a2 = zoom(a, lb / la)
#         a = a2
#     elif la < lb:
#         from scipy.ndimage import zoom
#         b2 = zoom(b, la / lb)
#         b = b2
#
#     la = len(a)
#     lb = len(b)
#
#     ta = int(la // 2)
#     tb = int(lb // 2)
#
#     ca = a[ta]
#     cb = b[tb]
#
#     if ca > cb:
#         swap = a
#         a = b
#         b = swap
#
#     np_a = np.array(a)
#     np_b = np.array(b)
#
#     np_a_ex = append_label_column(np_a, 1)
#     np_b_ex = append_label_column(np_b, 2)
#
#     left = 4
#     right = 3
#
#     np_ab = np.vstack([np_a_ex, np_b_ex])
#     np_ab = np_ab[np_ab[:, 0].argsort()]
#
#     labels = np_ab[:,1]
#
#     cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
#     cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
#     cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
#     cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())
#
#     np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])
#
#     half = 0
#     for row in np_ab_ex:
#         rl = row[left]
#         rr = row[right]
#         if rl > rr:
#             break
#         half += 1
#
#     threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2
#
#     fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
#     fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]
#
#     percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100
#
#     return threshold, percent
#

config = {}

dm_funcs = [dm_func_mean2, dm_func_avg_hash, dm_func_p_hash, dm_func_d_hash, dm_func_haar_hash, dm_func_db4_hash] #  , dm_func_cr_hash, dm_func_color_hash
#dm_funcs = [dm_func_mean2]
cutoff_backgrounds = [True, False]
normalizes = [True, False]
autoencoders = [
    (dots_autoencoder, 'dots', dots_set),
    (worms_autoencoder, 'worms', worms_set),
    (tracks_autoencoder, 'tracks', tracks_set),
    (artifacts_autoencoder, 'artifacts', artifacts_set)
]

#calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, normalize=True, cutoff_background=False)
#trained_set = calculated['dots']
#other_set = np.hstack([calculated['worms'], calculated['tracks'], calculated['artifacts']])




for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = []
            for dm_func in dm_funcs:
                print('====| dm_func = %s, cutoff_background = %s, normalize = %s |====' % (str(dm_func.__name__), str(cutoff_background), str(normalize)))
                argv = {'cutoff_background': cutoff_background, 'normalize': normalize, 'dm_func': dm_func}

                #dots_reconstruction = autoencoder.predict(dots_set) if name != 'dots' else []
                #worms_reconstruction = autoencoder.predict(worms_set) if name != 'worms' else []
                #tracks_reconstruction = autoencoder.predict(tracks_set) if name != 'tracks' else []
                #artifacts_reconstruction = autoencoder.predict(artifacts_set) if name != 'artifacts' else []

                #others = np.vstack([dots_reconstruction, worms_reconstruction, tracks_reconstruction, artifacts_reconstruction])

                #prepare_for_histogram(trained_set, others, dm_func, **argv)

                calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv)

                trained_set = calculated[name]
                other_set = []
                for sn in calculated.keys():
                    if sn != name:
                        other_set.append(calculated[sn])
                other_set = np.hstack(other_set)

                threshold, percent = find_threshold(trained_set, other_set)
                plot_threshold(trained_set, other_set, threshold, 'dots', 'others')

                print('Channel %s, threshold: %f, percent: %f' % (name, threshold, percent))

                rows.append((dm_func.__name__, str(cutoff_background), str(normalize), calculated, threshold))
            config[(autoencoder, cutoff_background, normalize)] = rows
# Out:
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 2s 8ms/step
# 16/16 [==============================] - 0s 9ms/step
# 96/96 [==============================] - 1s 10ms/step
# 21/21 [==============================] - 0s 7ms/step
# Channel dots, threshold: -15.662881, percent: 3.573333
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 8.746667
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 7.200000
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000038, percent: 23.840000
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000262, percent: 25.040000
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 26ms/step
# 96/96 [==============================] - 1s 10ms/step
# 21/21 [==============================] - 0s 11ms/step
# Channel dots, threshold: 0.001121, percent: 26.640000
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 1s 10ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: -1.435866, percent: 2.320000
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 8.746667
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 7.200000
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 1.000000, percent: 18.133333
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 1s 7ms/step
# 21/21 [==============================] - 0s 11ms/step
# Channel dots, threshold: 11.000000, percent: 42.906667
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 46.000000, percent: 29.920000
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: -15.482986, percent: 3.920000
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 9.706667
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 8.266667
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 1s 12ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000043, percent: 28.186667
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 1s 11ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 8ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000307, percent: 26.186667
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 1s 17ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 8ms/step
# Channel dots, threshold: 0.001479, percent: 24.400000
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 6ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: -1.601356, percent: 4.560000
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 1s 13ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 7ms/step
# Channel dots, threshold: 0.000000, percent: 9.706667
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 1s 13ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 6ms/step
# 21/21 [==============================] - 0s 7ms/step
# Channel dots, threshold: 0.000000, percent: 8.266667
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 1.000000, percent: 20.586667
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 12.000000, percent: 40.053333
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 52.000000, percent: 26.986667
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: -13.019738, percent: 32.157258
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000036, percent: 47.782258
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000097, percent: 47.479839
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.000056, percent: 45.766129
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000138, percent: 32.560484
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000655, percent: 32.459677
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 3.344618, percent: 25.504032
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 4.000000, percent: 40.625000
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 12.000000, percent: 42.338710
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 6.000000, percent: 32.862903
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 12.000000, percent: 49.495968
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 56.502159, percent: 38.810484
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: -13.003508, percent: 32.157258
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000037, percent: 47.379032
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000102, percent: 49.193548
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000058, percent: 45.967742
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000153, percent: 30.241935
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000760, percent: 27.520161
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 3.357599, percent: 25.504032
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 4.000000, percent: 39.818548
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 12.000000, percent: 43.044355
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 6.000000, percent: 31.754032
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 13.000000, percent: 46.875000
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 63.000000, percent: 40.423387
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: -13.860764, percent: 33.874710
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000035, percent: 23.500166
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000087, percent: 22.853828
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000051, percent: 33.990719
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000200, percent: 39.973484
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000907, percent: 41.117004
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 1.828530, percent: 27.345045
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 2.000000, percent: 26.118661
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 8.000000, percent: 28.720583
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 3.000000, percent: 27.113026
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 12.000000, percent: 44.216109
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 51.000000, percent: 36.261187
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: -13.817098, percent: 34.371893
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000035, percent: 24.030494
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000100, percent: 26.764998
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000054, percent: 36.095459
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000235, percent: 36.145177
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.001164, percent: 33.791846
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 1.850571, percent: 27.510772
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 2.000000, percent: 26.019224
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 8.000000, percent: 30.891614
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 3.000000, percent: 26.997017
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 13.000000, percent: 43.022870
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 58.000000, percent: 35.979450
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: -12.697758, percent: 23.219814
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000030, percent: 44.427245
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000076, percent: 46.517028
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000049, percent: 47.678019
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000160, percent: 39.396285
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000754, percent: 40.015480
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 2.156195, percent: 45.433437
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 2.000000, percent: 50.541796
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 8.000000, percent: 50.232198
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 3.999845, percent: 46.981424
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 11.000000, percent: 45.975232
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 49.522304, percent: 47.058824
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: -12.640764, percent: 22.213622
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000030, percent: 44.349845
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000125, percent: 41.718266
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000051, percent: 47.600619
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000260, percent: 44.969040
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.001287, percent: 44.349845
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 2.205872, percent: 44.969040
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 2.000000, percent: 50.232198
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 12.000000, percent: 36.377709
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 4.000000, percent: 49.071207
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 13.000000, percent: 49.690402
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 60.000000, percent: 46.671827

# %%
def find_percent(sa, sb, threshold):
    a = sorted(sa)
    b = sorted(sb)

    la = len(a)
    lb = len(b)

    if la > lb:
        from scipy.ndimage import zoom
        a2 = zoom(a, lb / la)
        a = a2
    elif la < lb:
        from scipy.ndimage import zoom
        b2 = zoom(b, la / lb)
        b = b2

    la = len(a)
    lb = len(b)

    ta = int(la // 2)
    tb = int(lb // 2)

    ca = a[ta]
    cb = b[tb]

    if ca > cb:
        swap = a
        a = b
        b = swap

    np_a = np.array(a)
    np_b = np.array(b)

    np_a_ex = append_label_column(np_a, 1)
    np_b_ex = append_label_column(np_b, 2)

    left = 4
    right = 3

    np_ab = np.vstack([np_a_ex, np_b_ex])
    np_ab = np_ab[np_ab[:, 0].argsort()]

    labels = np_ab[:,1]

    cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
    cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
    cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
    cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())

    np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])

    half = 0
    for row in np_ab_ex:
        rl = row[left]
        rr = row[right]
        if rl > rr:
            break
        half += 1

    #threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2

    fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
    fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]

    percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100

    return percent


def confusion_matrix2(rows, channel):
    import matplotlib.pyplot as plt

    x_labels = ["dots", "tracks", "worms", "artifacts"]
    y_labels = []

    matrix = np.zeros((len(rows), len(x_labels)), dtype=np.int32)

    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            set_name = x_labels[j]
            (fun_name, cutoff_background, normalize, similarity, threshold) = rows[i]

            la = channel
            lb = set_name

            if la == lb:
                continue

            a = similarity[la]
            b = similarity[lb]


            #threshold, percent = find_threshold(a, b)
            percent = find_percent(a, b, threshold)

            print('Channel %s, compare %s vs %s, threshold: %s, fp/fn percent: %s %%' % (la, la, lb, str(threshold), str(percent)))
            #plot_threshold(a, b, threshold, la, lb)

            matrix[i, j] = int(100 - percent)
        y_labels.append(rows[i][0])

    fig, ax = plt.subplots()
    im = ax.imshow(matrix)

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(x_labels)), labels=x_labels)
    ax.set_yticks(np.arange(len(y_labels)), labels=y_labels)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            text = ax.text(j, i, matrix[i, j], ha="center", va="center", color="w")

    ax.set_title("x - data set, y - compare method")
    fig.tight_layout()
    plt.show()

for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = config[(autoencoder, cutoff_background, normalize)]
            confusion_matrix2(rows, name)
# Out:
# Channel dots, compare dots vs tracks, threshold: -15.662880694439764, fp/fn percent: 4.026666666666666 %
# Channel dots, compare dots vs worms, threshold: -15.662880694439764, fp/fn percent: 2.318548387096774 %
# Channel dots, compare dots vs artifacts, threshold: -15.662880694439764, fp/fn percent: 2.3993808049535605 %
# Channel dots, compare dots vs tracks, threshold: 2.373249256849197e-80, fp/fn percent: 6.613333333333333 %
# Channel dots, compare dots vs worms, threshold: 2.373249256849197e-80, fp/fn percent: 7.963709677419355 %
# Channel dots, compare dots vs artifacts, threshold: 2.373249256849197e-80, fp/fn percent: 22.678018575851393 %
# Channel dots, compare dots vs tracks, threshold: 2.006958899659091e-284, fp/fn percent: 5.866666666666666 %
# Channel dots, compare dots vs worms, threshold: 2.006958899659091e-284, fp/fn percent: 11.189516129032258 %
# Channel dots, compare dots vs artifacts, threshold: 2.006958899659091e-284, fp/fn percent: 29.3343653250774 %
# Channel dots, compare dots vs tracks, threshold: 3.750599920401665e-05, fp/fn percent: 22.133333333333333 %
# Channel dots, compare dots vs worms, threshold: 3.750599920401665e-05, fp/fn percent: 21.370967741935484 %
# Channel dots, compare dots vs artifacts, threshold: 3.750599920401665e-05, fp/fn percent: 33.82352941176471 %
# Channel dots, compare dots vs tracks, threshold: 0.00026177025258200927, fp/fn percent: 25.78666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.00026177025258200927, fp/fn percent: 16.532258064516128 %
# Channel dots, compare dots vs artifacts, threshold: 0.00026177025258200927, fp/fn percent: 28.01857585139319 %
# Channel dots, compare dots vs tracks, threshold: 0.0011210197569679245, fp/fn percent: 27.439999999999998 %
# Channel dots, compare dots vs worms, threshold: 0.0011210197569679245, fp/fn percent: 17.741935483870968 %
# Channel dots, compare dots vs artifacts, threshold: 0.0011210197569679245, fp/fn percent: 29.79876160990712 %
# Channel dots, compare dots vs tracks, threshold: -1.4358664345818508, fp/fn percent: 1.8933333333333333 %
# Channel dots, compare dots vs worms, threshold: -1.4358664345818508, fp/fn percent: 1.5120967741935485 %
# Channel dots, compare dots vs artifacts, threshold: -1.4358664345818508, fp/fn percent: 5.108359133126935 %
# Channel dots, compare dots vs tracks, threshold: 5.858939973285611e-75, fp/fn percent: 6.613333333333333 %
# Channel dots, compare dots vs worms, threshold: 5.858939973285611e-75, fp/fn percent: 7.963709677419355 %
# Channel dots, compare dots vs artifacts, threshold: 5.858939973285611e-75, fp/fn percent: 22.60061919504644 %
# Channel dots, compare dots vs tracks, threshold: 4.55783866195893e-279, fp/fn percent: 5.866666666666666 %
# Channel dots, compare dots vs worms, threshold: 4.55783866195893e-279, fp/fn percent: 11.088709677419354 %
# Channel dots, compare dots vs artifacts, threshold: 4.55783866195893e-279, fp/fn percent: 29.3343653250774 %
# Channel dots, compare dots vs tracks, threshold: 1.0, fp/fn percent: 16.586666666666666 %
# Channel dots, compare dots vs worms, threshold: 1.0, fp/fn percent: 14.012096774193546 %
# Channel dots, compare dots vs artifacts, threshold: 1.0, fp/fn percent: 29.721362229102166 %
# Channel dots, compare dots vs tracks, threshold: 11.000000000000004, fp/fn percent: 41.839999999999996 %
# Channel dots, compare dots vs worms, threshold: 11.000000000000004, fp/fn percent: 43.145161290322584 %
# Channel dots, compare dots vs artifacts, threshold: 11.000000000000004, fp/fn percent: 49.45820433436533 %
# Channel dots, compare dots vs tracks, threshold: 46.0, fp/fn percent: 28.933333333333334 %
# Channel dots, compare dots vs worms, threshold: 46.0, fp/fn percent: 24.899193548387096 %
# Channel dots, compare dots vs artifacts, threshold: 46.0, fp/fn percent: 38.93188854489164 %
# Channel dots, compare dots vs tracks, threshold: -15.48298645679473, fp/fn percent: 4.533333333333333 %
# Channel dots, compare dots vs worms, threshold: -15.48298645679473, fp/fn percent: 2.4193548387096775 %
# Channel dots, compare dots vs artifacts, threshold: -15.48298645679473, fp/fn percent: 2.1671826625387 %
# Channel dots, compare dots vs tracks, threshold: 1.9470803827757896e-36, fp/fn percent: 7.706666666666667 %
# Channel dots, compare dots vs worms, threshold: 1.9470803827757896e-36, fp/fn percent: 7.459677419354839 %
# Channel dots, compare dots vs artifacts, threshold: 1.9470803827757896e-36, fp/fn percent: 22.13622291021672 %
# Channel dots, compare dots vs tracks, threshold: 4.956885407329075e-56, fp/fn percent: 7.893333333333333 %
# Channel dots, compare dots vs worms, threshold: 4.956885407329075e-56, fp/fn percent: 6.653225806451612 %
# Channel dots, compare dots vs artifacts, threshold: 4.956885407329075e-56, fp/fn percent: 13.544891640866874 %
# Channel dots, compare dots vs tracks, threshold: 4.3282548476454294e-05, fp/fn percent: 26.640000000000004 %
# Channel dots, compare dots vs worms, threshold: 4.3282548476454294e-05, fp/fn percent: 25.90725806451613 %
# Channel dots, compare dots vs artifacts, threshold: 4.3282548476454294e-05, fp/fn percent: 37.38390092879257 %
# Channel dots, compare dots vs tracks, threshold: 0.00030706553995074094, fp/fn percent: 24.906666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.00030706553995074094, fp/fn percent: 16.834677419354836 %
# Channel dots, compare dots vs artifacts, threshold: 0.00030706553995074094, fp/fn percent: 39.39628482972136 %
# Channel dots, compare dots vs tracks, threshold: 0.0014790691116439675, fp/fn percent: 22.773333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0014790691116439675, fp/fn percent: 15.423387096774194 %
# Channel dots, compare dots vs artifacts, threshold: 0.0014790691116439675, fp/fn percent: 38.93188854489164 %
# Channel dots, compare dots vs tracks, threshold: -1.6013556048814839, fp/fn percent: 2.7199999999999998 %
# Channel dots, compare dots vs worms, threshold: -1.6013556048814839, fp/fn percent: 2.5201612903225805 %
# Channel dots, compare dots vs artifacts, threshold: -1.6013556048814839, fp/fn percent: 15.015479876160992 %
# Channel dots, compare dots vs tracks, threshold: 3.715589636684719e-31, fp/fn percent: 7.706666666666667 %
# Channel dots, compare dots vs worms, threshold: 3.715589636684719e-31, fp/fn percent: 7.459677419354839 %
# Channel dots, compare dots vs artifacts, threshold: 3.715589636684719e-31, fp/fn percent: 22.13622291021672 %
# Channel dots, compare dots vs tracks, threshold: 1.2321002355748825e-50, fp/fn percent: 7.893333333333333 %
# Channel dots, compare dots vs worms, threshold: 1.2321002355748825e-50, fp/fn percent: 6.552419354838709 %
# Channel dots, compare dots vs artifacts, threshold: 1.2321002355748825e-50, fp/fn percent: 13.544891640866874 %
# Channel dots, compare dots vs tracks, threshold: 1.0, fp/fn percent: 18.986666666666665 %
# Channel dots, compare dots vs worms, threshold: 1.0, fp/fn percent: 15.826612903225806 %
# Channel dots, compare dots vs artifacts, threshold: 1.0, fp/fn percent: 31.269349845201237 %
# Channel dots, compare dots vs tracks, threshold: 12.0, fp/fn percent: 39.36 %
# Channel dots, compare dots vs worms, threshold: 12.0, fp/fn percent: 42.13709677419355 %
# Channel dots, compare dots vs artifacts, threshold: 12.0, fp/fn percent: 45.20123839009288 %
# Channel dots, compare dots vs tracks, threshold: 52.000000000010694, fp/fn percent: 26.479999999999997 %
# Channel dots, compare dots vs worms, threshold: 52.000000000010694, fp/fn percent: 23.68951612903226 %
# Channel dots, compare dots vs artifacts, threshold: 52.000000000010694, fp/fn percent: 32.89473684210527 %
# Channel worms, compare worms vs dots, threshold: -13.01973800873979, fp/fn percent: 16.129032258064516 %
# Channel worms, compare worms vs tracks, threshold: -13.01973800873979, fp/fn percent: 36.59274193548387 %
# Channel worms, compare worms vs artifacts, threshold: -13.01973800873979, fp/fn percent: 41.935483870967744 %
# Channel worms, compare worms vs dots, threshold: 3.641786356727193e-05, fp/fn percent: 28.125 %
# Channel worms, compare worms vs tracks, threshold: 3.641786356727193e-05, fp/fn percent: 39.314516129032256 %
# Channel worms, compare worms vs artifacts, threshold: 3.641786356727193e-05, fp/fn percent: 43.95161290322581 %
# Channel worms, compare worms vs dots, threshold: 9.71067115031164e-05, fp/fn percent: 27.116935483870968 %
# Channel worms, compare worms vs tracks, threshold: 9.71067115031164e-05, fp/fn percent: 39.41532258064516 %
# Channel worms, compare worms vs artifacts, threshold: 9.71067115031164e-05, fp/fn percent: 44.45564516129033 %
# Channel worms, compare worms vs dots, threshold: 5.6200195720641846e-05, fp/fn percent: 33.36693548387097 %
# Channel worms, compare worms vs tracks, threshold: 5.6200195720641846e-05, fp/fn percent: 46.57258064516129 %
# Channel worms, compare worms vs artifacts, threshold: 5.6200195720641846e-05, fp/fn percent: 45.26209677419355 %
# Channel worms, compare worms vs dots, threshold: 0.00013762841138264826, fp/fn percent: 23.487903225806452 %
# Channel worms, compare worms vs tracks, threshold: 0.00013762841138264826, fp/fn percent: 35.483870967741936 %
# Channel worms, compare worms vs artifacts, threshold: 0.00013762841138264826, fp/fn percent: 55.04032258064516 %
# Channel worms, compare worms vs dots, threshold: 0.000655389537689409, fp/fn percent: 23.790322580645164 %
# Channel worms, compare worms vs tracks, threshold: 0.000655389537689409, fp/fn percent: 35.181451612903224 %
# Channel worms, compare worms vs artifacts, threshold: 0.000655389537689409, fp/fn percent: 44.45564516129033 %
# Channel worms, compare worms vs dots, threshold: 3.3446175157634057, fp/fn percent: 12.80241935483871 %
# Channel worms, compare worms vs tracks, threshold: 3.3446175157634057, fp/fn percent: 30.94758064516129 %
# Channel worms, compare worms vs artifacts, threshold: 3.3446175157634057, fp/fn percent: 36.29032258064516 %
# Channel worms, compare worms vs dots, threshold: 4.0, fp/fn percent: 22.076612903225808 %
# Channel worms, compare worms vs tracks, threshold: 4.0, fp/fn percent: 51.41129032258065 %
# Channel worms, compare worms vs artifacts, threshold: 4.0, fp/fn percent: 40.42338709677419 %
# Channel worms, compare worms vs dots, threshold: 12.0, fp/fn percent: 24.697580645161292 %
# Channel worms, compare worms vs tracks, threshold: 12.0, fp/fn percent: 52.11693548387096 %
# Channel worms, compare worms vs artifacts, threshold: 12.0, fp/fn percent: 46.471774193548384 %
# Channel worms, compare worms vs dots, threshold: 6.0, fp/fn percent: 18.447580645161292 %
# Channel worms, compare worms vs tracks, threshold: 6.0, fp/fn percent: 40.32258064516129 %
# Channel worms, compare worms vs artifacts, threshold: 6.0, fp/fn percent: 38.20564516129033 %
# Channel worms, compare worms vs dots, threshold: 12.000000000000004, fp/fn percent: 44.25403225806452 %
# Channel worms, compare worms vs tracks, threshold: 12.000000000000004, fp/fn percent: 48.99193548387097 %
# Channel worms, compare worms vs artifacts, threshold: 12.000000000000004, fp/fn percent: 45.564516129032256 %
# Channel worms, compare worms vs dots, threshold: 56.50215857945631, fp/fn percent: 27.116935483870968 %
# Channel worms, compare worms vs tracks, threshold: 56.50215857945631, fp/fn percent: 45.96774193548387 %
# Channel worms, compare worms vs artifacts, threshold: 56.50215857945631, fp/fn percent: 38.608870967741936 %
# Channel worms, compare worms vs dots, threshold: -13.003508279325619, fp/fn percent: 16.129032258064516 %
# Channel worms, compare worms vs tracks, threshold: -13.003508279325619, fp/fn percent: 36.391129032258064 %
# Channel worms, compare worms vs artifacts, threshold: -13.003508279325619, fp/fn percent: 41.028225806451616 %
# Channel worms, compare worms vs dots, threshold: 3.6875313273427654e-05, fp/fn percent: 28.225806451612907 %
# Channel worms, compare worms vs tracks, threshold: 3.6875313273427654e-05, fp/fn percent: 40.020161290322584 %
# Channel worms, compare worms vs artifacts, threshold: 3.6875313273427654e-05, fp/fn percent: 43.649193548387096 %
# Channel worms, compare worms vs dots, threshold: 0.00010243270956621779, fp/fn percent: 28.326612903225808 %
# Channel worms, compare worms vs tracks, threshold: 0.00010243270956621779, fp/fn percent: 39.21370967741936 %
# Channel worms, compare worms vs artifacts, threshold: 0.00010243270956621779, fp/fn percent: 43.95161290322581 %
# Channel worms, compare worms vs dots, threshold: 5.811411433755483e-05, fp/fn percent: 34.979838709677416 %
# Channel worms, compare worms vs tracks, threshold: 5.811411433755483e-05, fp/fn percent: 47.07661290322581 %
# Channel worms, compare worms vs artifacts, threshold: 5.811411433755483e-05, fp/fn percent: 45.46370967741936 %
# Channel worms, compare worms vs dots, threshold: 0.00015282504357001867, fp/fn percent: 21.975806451612904 %
# Channel worms, compare worms vs tracks, threshold: 0.00015282504357001867, fp/fn percent: 34.87903225806452 %
# Channel worms, compare worms vs artifacts, threshold: 0.00015282504357001867, fp/fn percent: 32.45967741935484 %
# Channel worms, compare worms vs dots, threshold: 0.00075988373036553, fp/fn percent: 17.237903225806452 %
# Channel worms, compare worms vs tracks, threshold: 0.00075988373036553, fp/fn percent: 33.064516129032256 %
# Channel worms, compare worms vs artifacts, threshold: 0.00075988373036553, fp/fn percent: 31.149193548387093 %
# Channel worms, compare worms vs dots, threshold: 3.3575989213803537, fp/fn percent: 12.80241935483871 %
# Channel worms, compare worms vs tracks, threshold: 3.3575989213803537, fp/fn percent: 30.94758064516129 %
# Channel worms, compare worms vs artifacts, threshold: 3.3575989213803537, fp/fn percent: 36.391129032258064 %
# Channel worms, compare worms vs dots, threshold: 4.0, fp/fn percent: 21.16935483870968 %
# Channel worms, compare worms vs tracks, threshold: 4.0, fp/fn percent: 50.60483870967742 %
# Channel worms, compare worms vs artifacts, threshold: 4.0, fp/fn percent: 40.524193548387096 %
# Channel worms, compare worms vs dots, threshold: 12.0, fp/fn percent: 23.68951612903226 %
# Channel worms, compare worms vs tracks, threshold: 12.0, fp/fn percent: 51.81451612903226 %
# Channel worms, compare worms vs artifacts, threshold: 12.0, fp/fn percent: 48.38709677419355 %
# Channel worms, compare worms vs dots, threshold: 6.0, fp/fn percent: 16.834677419354836 %
# Channel worms, compare worms vs tracks, threshold: 6.0, fp/fn percent: 39.61693548387097 %
# Channel worms, compare worms vs artifacts, threshold: 6.0, fp/fn percent: 37.399193548387096 %
# Channel worms, compare worms vs dots, threshold: 13.000000000000004, fp/fn percent: 40.82661290322581 %
# Channel worms, compare worms vs tracks, threshold: 13.000000000000004, fp/fn percent: 50.403225806451616 %
# Channel worms, compare worms vs artifacts, threshold: 13.000000000000004, fp/fn percent: 47.88306451612903 %
# Channel worms, compare worms vs dots, threshold: 63.0, fp/fn percent: 26.411290322580644 %
# Channel worms, compare worms vs tracks, threshold: 63.0, fp/fn percent: 47.78225806451613 %
# Channel worms, compare worms vs artifacts, threshold: 63.0, fp/fn percent: 44.153225806451616 %
# Channel tracks, compare tracks vs dots, threshold: -13.860763667396764, fp/fn percent: 16.96 %
# Channel tracks, compare tracks vs worms, threshold: -13.860763667396764, fp/fn percent: 39.61693548387097 %
# Channel tracks, compare tracks vs artifacts, threshold: -13.860763667396764, fp/fn percent: 37.38390092879257 %
# Channel tracks, compare tracks vs dots, threshold: 3.4572242915913696e-05, fp/fn percent: 16.0 %
# Channel tracks, compare tracks vs worms, threshold: 3.4572242915913696e-05, fp/fn percent: 40.221774193548384 %
# Channel tracks, compare tracks vs artifacts, threshold: 3.4572242915913696e-05, fp/fn percent: 32.43034055727554 %
# Channel tracks, compare tracks vs dots, threshold: 8.656558204049347e-05, fp/fn percent: 14.773333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 8.656558204049347e-05, fp/fn percent: 39.818548387096776 %
# Channel tracks, compare tracks vs artifacts, threshold: 8.656558204049347e-05, fp/fn percent: 33.28173374613003 %
# Channel tracks, compare tracks vs dots, threshold: 5.1151289283705265e-05, fp/fn percent: 27.973333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 5.1151289283705265e-05, fp/fn percent: 48.58870967741936 %
# Channel tracks, compare tracks vs artifacts, threshold: 5.1151289283705265e-05, fp/fn percent: 40.3250773993808 %
# Channel tracks, compare tracks vs dots, threshold: 0.00019999925518174457, fp/fn percent: 29.86666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.00019999925518174457, fp/fn percent: 38.00403225806452 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.00019999925518174457, fp/fn percent: 47.44582043343653 %
# Channel tracks, compare tracks vs dots, threshold: 0.0009068484429751785, fp/fn percent: 31.333333333333336 %
# Channel tracks, compare tracks vs worms, threshold: 0.0009068484429751785, fp/fn percent: 36.49193548387097 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0009068484429751785, fp/fn percent: 47.60061919504644 %
# Channel tracks, compare tracks vs dots, threshold: 1.828530301849291, fp/fn percent: 13.653333333333334 %
# Channel tracks, compare tracks vs worms, threshold: 1.828530301849291, fp/fn percent: 39.61693548387097 %
# Channel tracks, compare tracks vs artifacts, threshold: 1.828530301849291, fp/fn percent: 58.28173374613003 %
# Channel tracks, compare tracks vs dots, threshold: 2.0000000000000004, fp/fn percent: 13.919999999999998 %
# Channel tracks, compare tracks vs worms, threshold: 2.0000000000000004, fp/fn percent: 46.57258064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: 2.0000000000000004, fp/fn percent: 38.39009287925697 %
# Channel tracks, compare tracks vs dots, threshold: 8.0, fp/fn percent: 16.853333333333335 %
# Channel tracks, compare tracks vs worms, threshold: 8.0, fp/fn percent: 52.11693548387096 %
# Channel tracks, compare tracks vs artifacts, threshold: 8.0, fp/fn percent: 43.4984520123839 %
# Channel tracks, compare tracks vs dots, threshold: 3.000000000000001, fp/fn percent: 14.266666666666666 %
# Channel tracks, compare tracks vs worms, threshold: 3.000000000000001, fp/fn percent: 43.95161290322581 %
# Channel tracks, compare tracks vs artifacts, threshold: 3.000000000000001, fp/fn percent: 40.40247678018576 %
# Channel tracks, compare tracks vs dots, threshold: 12.0, fp/fn percent: 42.693333333333335 %
# Channel tracks, compare tracks vs worms, threshold: 12.0, fp/fn percent: 50.60483870967742 %
# Channel tracks, compare tracks vs artifacts, threshold: 12.0, fp/fn percent: 43.88544891640867 %
# Channel tracks, compare tracks vs dots, threshold: 51.0, fp/fn percent: 29.84 %
# Channel tracks, compare tracks vs worms, threshold: 51.0, fp/fn percent: 47.07661290322581 %
# Channel tracks, compare tracks vs artifacts, threshold: 51.0, fp/fn percent: 40.94427244582043 %
# Channel tracks, compare tracks vs dots, threshold: -13.817098016849169, fp/fn percent: 17.226666666666667 %
# Channel tracks, compare tracks vs worms, threshold: -13.817098016849169, fp/fn percent: 39.41532258064516 %
# Channel tracks, compare tracks vs artifacts, threshold: -13.817098016849169, fp/fn percent: 35.91331269349845 %
# Channel tracks, compare tracks vs dots, threshold: 3.48065192610576e-05, fp/fn percent: 16.586666666666666 %
# Channel tracks, compare tracks vs worms, threshold: 3.48065192610576e-05, fp/fn percent: 40.725806451612904 %
# Channel tracks, compare tracks vs artifacts, threshold: 3.48065192610576e-05, fp/fn percent: 32.89473684210527 %
# Channel tracks, compare tracks vs dots, threshold: 9.980560675539054e-05, fp/fn percent: 17.093333333333334 %
# Channel tracks, compare tracks vs worms, threshold: 9.980560675539054e-05, fp/fn percent: 39.314516129032256 %
# Channel tracks, compare tracks vs artifacts, threshold: 9.980560675539054e-05, fp/fn percent: 54.79876160990712 %
# Channel tracks, compare tracks vs dots, threshold: 5.37832192302541e-05, fp/fn percent: 31.04 %
# Channel tracks, compare tracks vs worms, threshold: 5.37832192302541e-05, fp/fn percent: 48.58870967741936 %
# Channel tracks, compare tracks vs artifacts, threshold: 5.37832192302541e-05, fp/fn percent: 41.17647058823529 %
# Channel tracks, compare tracks vs dots, threshold: 0.000235495173052408, fp/fn percent: 28.24 %
# Channel tracks, compare tracks vs worms, threshold: 0.000235495173052408, fp/fn percent: 38.810483870967744 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.000235495173052408, fp/fn percent: 39.78328173374613 %
# Channel tracks, compare tracks vs dots, threshold: 0.0011643869044013302, fp/fn percent: 24.826666666666668 %
# Channel tracks, compare tracks vs worms, threshold: 0.0011643869044013302, fp/fn percent: 38.40725806451613 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0011643869044013302, fp/fn percent: 38.46749226006192 %
# Channel tracks, compare tracks vs dots, threshold: 1.8505706231157673, fp/fn percent: 13.76 %
# Channel tracks, compare tracks vs worms, threshold: 1.8505706231157673, fp/fn percent: 39.41532258064516 %
# Channel tracks, compare tracks vs artifacts, threshold: 1.8505706231157673, fp/fn percent: 57.89473684210527 %
# Channel tracks, compare tracks vs dots, threshold: 2.0000000000000004, fp/fn percent: 13.733333333333334 %
# Channel tracks, compare tracks vs worms, threshold: 2.0000000000000004, fp/fn percent: 46.270161290322584 %
# Channel tracks, compare tracks vs artifacts, threshold: 2.0000000000000004, fp/fn percent: 38.23529411764706 %
# Channel tracks, compare tracks vs dots, threshold: 8.0, fp/fn percent: 16.453333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 8.0, fp/fn percent: 52.721774193548384 %
# Channel tracks, compare tracks vs artifacts, threshold: 8.0, fp/fn percent: 52.012383900928796 %
# Channel tracks, compare tracks vs dots, threshold: 3.000000000000001, fp/fn percent: 13.973333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 3.000000000000001, fp/fn percent: 44.65725806451613 %
# Channel tracks, compare tracks vs artifacts, threshold: 3.000000000000001, fp/fn percent: 40.47987616099071 %
# Channel tracks, compare tracks vs dots, threshold: 12.999999999865594, fp/fn percent: 39.86666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 12.999999999865594, fp/fn percent: 49.79838709677419 %
# Channel tracks, compare tracks vs artifacts, threshold: 12.999999999865594, fp/fn percent: 46.749226006191954 %
# Channel tracks, compare tracks vs dots, threshold: 58.0, fp/fn percent: 27.813333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 58.0, fp/fn percent: 46.068548387096776 %
# Channel tracks, compare tracks vs artifacts, threshold: 58.0, fp/fn percent: 45.82043343653251 %
# Channel artifacts, compare artifacts vs dots, threshold: -12.697758308375702, fp/fn percent: 11.609907120743033 %
# Channel artifacts, compare artifacts vs tracks, threshold: -12.697758308375702, fp/fn percent: 27.321981424148607 %
# Channel artifacts, compare artifacts vs worms, threshold: -12.697758308375702, fp/fn percent: 41.733870967741936 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.9955263457381627e-05, fp/fn percent: 32.12074303405573 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.9955263457381627e-05, fp/fn percent: 30.65015479876161 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.9955263457381627e-05, fp/fn percent: 40.32258064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 7.611920695891331e-05, fp/fn percent: 30.263157894736842 %
# Channel artifacts, compare artifacts vs tracks, threshold: 7.611920695891331e-05, fp/fn percent: 32.972136222910216 %
# Channel artifacts, compare artifacts vs worms, threshold: 7.611920695891331e-05, fp/fn percent: 41.431451612903224 %
# Channel artifacts, compare artifacts vs dots, threshold: 4.883812890653571e-05, fp/fn percent: 37.38390092879257 %
# Channel artifacts, compare artifacts vs tracks, threshold: 4.883812890653571e-05, fp/fn percent: 39.473684210526315 %
# Channel artifacts, compare artifacts vs worms, threshold: 4.883812890653571e-05, fp/fn percent: 40.725806451612904 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.00016025570600091603, fp/fn percent: 28.095975232198146 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.00016025570600091603, fp/fn percent: 43.343653250774 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.00016025570600091603, fp/fn percent: 57.15725806451613 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0007535997875701914, fp/fn percent: 28.947368421052634 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0007535997875701914, fp/fn percent: 43.808049535603715 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0007535997875701914, fp/fn percent: 42.23790322580645 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.1561952420656487, fp/fn percent: 22.755417956656345 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.1561952420656487, fp/fn percent: 55.804953560371516 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.1561952420656487, fp/fn percent: 31.75403225806452 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.0000000000000004, fp/fn percent: 25.696594427244584 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.0000000000000004, fp/fn percent: 38.39009287925697 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.0000000000000004, fp/fn percent: 34.07258064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 8.0, fp/fn percent: 25.61919504643963 %
# Channel artifacts, compare artifacts vs tracks, threshold: 8.0, fp/fn percent: 43.4984520123839 %
# Channel artifacts, compare artifacts vs worms, threshold: 8.0, fp/fn percent: 40.725806451612904 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.9998447531797323, fp/fn percent: 23.606811145510836 %
# Channel artifacts, compare artifacts vs tracks, threshold: 3.9998447531797323, fp/fn percent: 42.027863777089784 %
# Channel artifacts, compare artifacts vs worms, threshold: 3.9998447531797323, fp/fn percent: 31.451612903225808 %
# Channel artifacts, compare artifacts vs dots, threshold: 11.000000000000002, fp/fn percent: 49.690402476780186 %
# Channel artifacts, compare artifacts vs tracks, threshold: 11.000000000000002, fp/fn percent: 42.56965944272446 %
# Channel artifacts, compare artifacts vs worms, threshold: 11.000000000000002, fp/fn percent: 44.25403225806452 %
# Channel artifacts, compare artifacts vs dots, threshold: 49.52230350469256, fp/fn percent: 39.08668730650155 %
# Channel artifacts, compare artifacts vs tracks, threshold: 49.52230350469256, fp/fn percent: 40.3250773993808 %
# Channel artifacts, compare artifacts vs worms, threshold: 49.52230350469256, fp/fn percent: 35.58467741935484 %
# Channel artifacts, compare artifacts vs dots, threshold: -12.640764440632223, fp/fn percent: 11.145510835913312 %
# Channel artifacts, compare artifacts vs tracks, threshold: -12.640764440632223, fp/fn percent: 26.006191950464398 %
# Channel artifacts, compare artifacts vs worms, threshold: -12.640764440632223, fp/fn percent: 40.625 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.0440126173882276e-05, fp/fn percent: 32.585139318885446 %
# Channel artifacts, compare artifacts vs tracks, threshold: 3.0440126173882276e-05, fp/fn percent: 30.804953560371516 %
# Channel artifacts, compare artifacts vs worms, threshold: 3.0440126173882276e-05, fp/fn percent: 39.71774193548387 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.00012547485389211791, fp/fn percent: 24.30340557275542 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.00012547485389211791, fp/fn percent: 52.70897832817337 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.00012547485389211791, fp/fn percent: 40.725806451612904 %
# Channel artifacts, compare artifacts vs dots, threshold: 5.131981598064671e-05, fp/fn percent: 39.39628482972136 %
# Channel artifacts, compare artifacts vs tracks, threshold: 5.131981598064671e-05, fp/fn percent: 40.55727554179567 %
# Channel artifacts, compare artifacts vs worms, threshold: 5.131981598064671e-05, fp/fn percent: 41.53225806451613 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.000260412185437808, fp/fn percent: 39.0092879256966 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.000260412185437808, fp/fn percent: 38.0030959752322 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.000260412185437808, fp/fn percent: 28.62903225806452 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0012869191592441154, fp/fn percent: 37.22910216718267 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0012869191592441154, fp/fn percent: 36.06811145510836 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0012869191592441154, fp/fn percent: 26.51209677419355 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.2058716232469866, fp/fn percent: 22.523219814241486 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.2058716232469866, fp/fn percent: 55.185758513931894 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.2058716232469866, fp/fn percent: 32.15725806451613 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.0000000000000004, fp/fn percent: 25.696594427244584 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.0000000000000004, fp/fn percent: 38.23529411764706 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.0000000000000004, fp/fn percent: 33.66935483870967 %
# Channel artifacts, compare artifacts vs dots, threshold: 12.000000000000004, fp/fn percent: 18.343653250773993 %
# Channel artifacts, compare artifacts vs tracks, threshold: 12.000000000000004, fp/fn percent: 45.588235294117645 %
# Channel artifacts, compare artifacts vs worms, threshold: 12.000000000000004, fp/fn percent: 42.943548387096776 %
# Channel artifacts, compare artifacts vs dots, threshold: 4.0, fp/fn percent: 25.773993808049532 %
# Channel artifacts, compare artifacts vs tracks, threshold: 4.0, fp/fn percent: 45.27863777089783 %
# Channel artifacts, compare artifacts vs worms, threshold: 4.0, fp/fn percent: 34.274193548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: 12.999999999999972, fp/fn percent: 42.72445820433436 %
# Channel artifacts, compare artifacts vs tracks, threshold: 12.999999999999972, fp/fn percent: 46.671826625387 %
# Channel artifacts, compare artifacts vs worms, threshold: 12.999999999999972, fp/fn percent: 45.96774193548387 %
# Channel artifacts, compare artifacts vs dots, threshold: 59.999999999990976, fp/fn percent: 31.424148606811148 %
# Channel artifacts, compare artifacts vs tracks, threshold: 59.999999999990976, fp/fn percent: 45.897832817337466 %
# Channel artifacts, compare artifacts vs worms, threshold: 59.999999999990976, fp/fn percent: 41.33064516129033 %
