# %%
import numpy as np

from commons import *
from dataset_loader import load_images, prepare_dataset, load_from_file
from IPython.display import display
import cv2
import pickle
import matplotlib.pyplot as plt
from keras.models import load_model


# TODO: https://pl.wikipedia.org/wiki/Dywergencja_Kullbacka-Leiblera
# https://towardsdatascience.com/kl-divergence-python-example-b87069e4b810
# TODO: entropia wzajemna, cross entropy


DOTS_DST = 'cache/dots_v3.pickle'
TRACKS_DST = 'cache/tracks_v3.pickle'
WORMS_DST = 'cache/worms_v3.pickle'
ARTIFACTS_DST = 'cache/artifacts_v3.pickle'

DOTS_AC = 'cache/dots_v3.h5'
TRACKS_AC = 'cache/tracks_v3.h5'
WORMS_AC = 'cache/worms_v3.h5'
ARTIFACTS_AC = 'cache/artifacts_v3.h5'



dots_set = prepare_dataset(np.asarray(load_from_file(DOTS_DST)[0]))
worms_set = prepare_dataset(np.asarray(load_from_file(WORMS_DST)[0]))
tracks_set = prepare_dataset(np.asarray(load_from_file(TRACKS_DST)[0]))
artifacts_set = prepare_dataset(np.asarray(load_from_file(ARTIFACTS_DST)[0]))

dots_autoencoder = load_model(DOTS_AC)
worms_autoencoder = load_model(WORMS_AC)
tracks_autoencoder = load_model(TRACKS_AC)
artifacts_autoencoder = load_model(ARTIFACTS_AC)

# %%
# def find_threshold(sa, sb):
#     a = sorted(sa)
#     b = sorted(sb)
#
#     la = len(a)
#     lb = len(b)
#
#     if la > lb:
#         from scipy.ndimage import zoom
#         a2 = zoom(a, lb / la)
#         a = a2
#     elif la < lb:
#         from scipy.ndimage import zoom
#         b2 = zoom(b, la / lb)
#         b = b2
#
#     la = len(a)
#     lb = len(b)
#
#     ta = int(la // 2)
#     tb = int(lb // 2)
#
#     ca = a[ta]
#     cb = b[tb]
#
#     if ca > cb:
#         swap = a
#         a = b
#         b = swap
#
#     np_a = np.array(a)
#     np_b = np.array(b)
#
#     np_a_ex = append_label_column(np_a, 1)
#     np_b_ex = append_label_column(np_b, 2)
#
#     left = 4
#     right = 3
#
#     np_ab = np.vstack([np_a_ex, np_b_ex])
#     np_ab = np_ab[np_ab[:, 0].argsort()]
#
#     labels = np_ab[:,1]
#
#     cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
#     cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
#     cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
#     cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())
#
#     np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])
#
#     half = 0
#     for row in np_ab_ex:
#         rl = row[left]
#         rr = row[right]
#         if rl > rr:
#             break
#         half += 1
#
#     threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2
#
#     fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
#     fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]
#
#     percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100
#
#     return threshold, percent
#

config = {}

dm_funcs = [dm_func_mean2, dm_func_avg_hash, dm_func_p_hash, dm_func_d_hash, dm_func_haar_hash, dm_func_db4_hash] #  , dm_func_cr_hash, dm_func_color_hash
#dm_funcs = [dm_func_mean2]
cutoff_backgrounds = [True, False]
normalizes = [True, False]
autoencoders = [
    (dots_autoencoder, 'dots', dots_set),
    (worms_autoencoder, 'worms', worms_set),
    (tracks_autoencoder, 'tracks', tracks_set),
    (artifacts_autoencoder, 'artifacts', artifacts_set)
]

#calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, normalize=True, cutoff_background=False)
#trained_set = calculated['dots']
#other_set = np.hstack([calculated['worms'], calculated['tracks'], calculated['artifacts']])




for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = []
            for dm_func in dm_funcs:
                print('====| dm_func = %s, cutoff_background = %s, normalize = %s |====' % (str(dm_func.__name__), str(cutoff_background), str(normalize)))
                argv = {'cutoff_background': cutoff_background, 'normalize': normalize, 'dm_func': dm_func}

                #dots_reconstruction = autoencoder.predict(dots_set) if name != 'dots' else []
                #worms_reconstruction = autoencoder.predict(worms_set) if name != 'worms' else []
                #tracks_reconstruction = autoencoder.predict(tracks_set) if name != 'tracks' else []
                #artifacts_reconstruction = autoencoder.predict(artifacts_set) if name != 'artifacts' else []

                #others = np.vstack([dots_reconstruction, worms_reconstruction, tracks_reconstruction, artifacts_reconstruction])

                #prepare_for_histogram(trained_set, others, dm_func, **argv)

                calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv)

                trained_set = calculated[name]
                other_set = []
                for sn in calculated.keys():
                    if sn != name:
                        other_set.append(calculated[sn])
                other_set = np.hstack(other_set)

                threshold, percent = find_threshold(trained_set, other_set)
                plot_threshold(trained_set, other_set, threshold, 'dots', 'others')

                print('Channel %s, threshold: %f, percent: %f' % (name, threshold, percent))

                rows.append((dm_func.__name__, str(cutoff_background), str(normalize), calculated, threshold))
            config[(autoencoder, cutoff_background, normalize)] = rows
# Out:
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel dots, threshold: -15.958375, percent: 1.760000
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000010, percent: 10.240000
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 52.533333
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000054, percent: 17.493333
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000287, percent: 23.626667
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.001114, percent: 28.400000
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel dots, threshold: -1.848732, percent: 1.680000
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 1.000000, percent: 10.240000
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 52.533333
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 1.000000, percent: 14.373333
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 11.000000, percent: 43.733333
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 42.000000, percent: 25.600000
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel dots, threshold: -15.679945, percent: 2.160000
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000016, percent: 11.306667
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 52.400000
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000059, percent: 19.653333
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000306, percent: 24.506667
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.001380, percent: 25.573333
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel dots, threshold: -2.088576, percent: 4.133333
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 1.000000, percent: 12.720000
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 52.400000
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 1.000000, percent: 16.586667
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 11.000000, percent: 38.960000
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 48.000000, percent: 20.933333
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel worms, threshold: -12.873035, percent: 32.762097
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.000039, percent: 50.000000
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.000101, percent: 45.766129
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.000076, percent: 49.395161
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.000135, percent: 33.064516
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.000663, percent: 29.536290
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 3.394528, percent: 26.411290
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 4.000000, percent: 39.919355
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 12.000000, percent: 39.919355
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 7.000000, percent: 36.189516
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 12.000000, percent: 50.504032
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 52.000000, percent: 41.532258
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel worms, threshold: -12.859508, percent: 33.064516
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.000039, percent: 49.697581
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.000105, percent: 45.362903
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.000078, percent: 48.891129
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.000157, percent: 33.467742
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.000796, percent: 30.040323
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 3.431112, percent: 26.209677
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 4.000000, percent: 39.919355
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 12.000000, percent: 39.717742
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 7.000000, percent: 35.282258
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 13.000000, percent: 45.463710
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 62.000000, percent: 38.709677
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: -13.690187, percent: 33.576400
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000038, percent: 23.533311
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000087, percent: 21.544581
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000076, percent: 24.792841
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000207, percent: 39.724892
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000937, percent: 42.144514
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 1.874685, percent: 27.543918
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 2.000000, percent: 24.726550
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 8.000000, percent: 28.670865
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 5.000000, percent: 25.406032
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 11.000000, percent: 43.785217
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 47.000071, percent: 30.825323
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: -13.644709, percent: 33.974147
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000039, percent: 24.163076
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000090, percent: 22.422937
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000079, percent: 25.886642
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000233, percent: 38.564799
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.001122, percent: 39.376864
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 1.917938, percent: 27.709645
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 2.024511, percent: 25.091150
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 8.000000, percent: 28.405701
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 5.000000, percent: 26.731853
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 12.000000, percent: 41.895923
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 55.000000, percent: 30.228704
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: -12.498266, percent: 22.832817
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000035, percent: 45.510836
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000079, percent: 46.981424
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000072, percent: 47.213622
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000160, percent: 38.544892
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000809, percent: 40.712074
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 2.250458, percent: 44.504644
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 2.999996, percent: 49.613003
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 8.000000, percent: 48.993808
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 5.000000, percent: 51.780186
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 10.000409, percent: 45.975232
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 46.000000, percent: 46.594427
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: -12.420598, percent: 21.517028
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.000036, percent: 45.975232
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.000088, percent: 49.148607
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.000077, percent: 48.219814
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.000189, percent: 41.331269
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.000977, percent: 41.486068
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 2.355536, percent: 43.730650
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 3.000000, percent: 52.554180
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 8.000000, percent: 48.065015
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 5.000000, percent: 49.303406
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 12.000000, percent: 49.458204
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 58.000000, percent: 45.975232

# %%
def find_percent(sa, sb, threshold):
    a = sorted(sa)
    b = sorted(sb)

    la = len(a)
    lb = len(b)

    if la > lb:
        from scipy.ndimage import zoom
        a2 = zoom(a, lb / la)
        a = a2
    elif la < lb:
        from scipy.ndimage import zoom
        b2 = zoom(b, la / lb)
        b = b2

    la = len(a)
    lb = len(b)

    ta = int(la // 2)
    tb = int(lb // 2)

    ca = a[ta]
    cb = b[tb]

    if ca > cb:
        swap = a
        a = b
        b = swap

    np_a = np.array(a)
    np_b = np.array(b)

    np_a_ex = append_label_column(np_a, 1)
    np_b_ex = append_label_column(np_b, 2)

    left = 4
    right = 3

    np_ab = np.vstack([np_a_ex, np_b_ex])
    np_ab = np_ab[np_ab[:, 0].argsort()]

    labels = np_ab[:,1]

    cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
    cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
    cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
    cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())

    np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])

    half = 0
    for row in np_ab_ex:
        rl = row[left]
        rr = row[right]
        if rl > rr:
            break
        half += 1

    #threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2

    fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
    fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]

    percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100

    return percent


def confusion_matrix2(rows, channel):
    import matplotlib.pyplot as plt

    x_labels = ["dots", "tracks", "worms", "artifacts"]
    y_labels = []

    matrix = np.zeros((len(rows), len(x_labels)), dtype=np.int32)

    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            set_name = x_labels[j]
            (fun_name, cutoff_background, normalize, similarity, threshold) = rows[i]

            la = channel
            lb = set_name

            if la == lb:
                continue

            a = similarity[la]
            b = similarity[lb]


            #threshold, percent = find_threshold(a, b)
            percent = find_percent(a, b, threshold)

            print('Channel %s, compare %s vs %s, threshold: %s, fp/fn percent: %s %%' % (la, la, lb, str(threshold), str(percent)))
            #plot_threshold(a, b, threshold, la, lb)

            matrix[i, j] = int(100 - percent)
        y_labels.append(rows[i][0])

    fig, ax = plt.subplots()
    im = ax.imshow(matrix)

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(x_labels)), labels=x_labels)
    ax.set_yticks(np.arange(len(y_labels)), labels=y_labels)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            text = ax.text(j, i, matrix[i, j], ha="center", va="center", color="w")

    ax.set_title("x - data set, y - compare method")
    fig.tight_layout()
    plt.show()

for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = config[(autoencoder, cutoff_background, normalize)]
            confusion_matrix2(rows, name)
# Out:
# Channel dots, compare dots vs tracks, threshold: -15.958374609450857, fp/fn percent: 1.92 %
# Channel dots, compare dots vs worms, threshold: -15.958374609450857, fp/fn percent: 1.1088709677419355 %
# Channel dots, compare dots vs artifacts, threshold: -15.958374609450857, fp/fn percent: 1.5479876160990713 %
# Channel dots, compare dots vs tracks, threshold: 9.975307232982863e-06, fp/fn percent: 8.213333333333333 %
# Channel dots, compare dots vs worms, threshold: 9.975307232982863e-06, fp/fn percent: 7.258064516129033 %
# Channel dots, compare dots vs artifacts, threshold: 9.975307232982863e-06, fp/fn percent: 22.21362229102167 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 51.54666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 43.44758064516129 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 60.8359133126935 %
# Channel dots, compare dots vs tracks, threshold: 5.4063351615300556e-05, fp/fn percent: 14.000000000000002 %
# Channel dots, compare dots vs worms, threshold: 5.4063351615300556e-05, fp/fn percent: 21.471774193548388 %
# Channel dots, compare dots vs artifacts, threshold: 5.4063351615300556e-05, fp/fn percent: 30.959752321981426 %
# Channel dots, compare dots vs tracks, threshold: 0.0002872737719046251, fp/fn percent: 24.266666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.0002872737719046251, fp/fn percent: 16.532258064516128 %
# Channel dots, compare dots vs artifacts, threshold: 0.0002872737719046251, fp/fn percent: 26.160990712074305 %
# Channel dots, compare dots vs tracks, threshold: 0.0011137348346498465, fp/fn percent: 29.439999999999998 %
# Channel dots, compare dots vs worms, threshold: 0.0011137348346498465, fp/fn percent: 19.153225806451612 %
# Channel dots, compare dots vs artifacts, threshold: 0.0011137348346498465, fp/fn percent: 30.572755417956653 %
# Channel dots, compare dots vs tracks, threshold: -1.8487319239411324, fp/fn percent: 1.4133333333333333 %
# Channel dots, compare dots vs worms, threshold: -1.8487319239411324, fp/fn percent: 0.9072580645161291 %
# Channel dots, compare dots vs artifacts, threshold: -1.8487319239411324, fp/fn percent: 3.560371517027864 %
# Channel dots, compare dots vs tracks, threshold: 0.9999999995226176, fp/fn percent: 8.426666666666668 %
# Channel dots, compare dots vs worms, threshold: 0.9999999995226176, fp/fn percent: 6.451612903225806 %
# Channel dots, compare dots vs artifacts, threshold: 0.9999999995226176, fp/fn percent: 20.6656346749226 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 51.54666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 43.346774193548384 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 60.681114551083596 %
# Channel dots, compare dots vs tracks, threshold: 1.0, fp/fn percent: 12.293333333333333 %
# Channel dots, compare dots vs worms, threshold: 1.0, fp/fn percent: 10.887096774193548 %
# Channel dots, compare dots vs artifacts, threshold: 1.0, fp/fn percent: 27.012383900928793 %
# Channel dots, compare dots vs tracks, threshold: 11.0, fp/fn percent: 42.85333333333333 %
# Channel dots, compare dots vs worms, threshold: 11.0, fp/fn percent: 43.649193548387096 %
# Channel dots, compare dots vs artifacts, threshold: 11.0, fp/fn percent: 52.012383900928796 %
# Channel dots, compare dots vs tracks, threshold: 42.0, fp/fn percent: 23.466666666666665 %
# Channel dots, compare dots vs worms, threshold: 42.0, fp/fn percent: 24.29435483870968 %
# Channel dots, compare dots vs artifacts, threshold: 42.0, fp/fn percent: 37.38390092879257 %
# Channel dots, compare dots vs tracks, threshold: -15.67994450588756, fp/fn percent: 2.48 %
# Channel dots, compare dots vs worms, threshold: -15.67994450588756, fp/fn percent: 1.310483870967742 %
# Channel dots, compare dots vs artifacts, threshold: -15.67994450588756, fp/fn percent: 1.238390092879257 %
# Channel dots, compare dots vs tracks, threshold: 1.6400865453197553e-05, fp/fn percent: 8.853333333333333 %
# Channel dots, compare dots vs worms, threshold: 1.6400865453197553e-05, fp/fn percent: 9.07258064516129 %
# Channel dots, compare dots vs artifacts, threshold: 1.6400865453197553e-05, fp/fn percent: 24.690402476780186 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 51.49333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 43.145161290322584 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 59.210526315789465 %
# Channel dots, compare dots vs tracks, threshold: 5.9171597633136094e-05, fp/fn percent: 16.026666666666667 %
# Channel dots, compare dots vs worms, threshold: 5.9171597633136094e-05, fp/fn percent: 25.50403225806452 %
# Channel dots, compare dots vs artifacts, threshold: 5.9171597633136094e-05, fp/fn percent: 32.27554179566564 %
# Channel dots, compare dots vs tracks, threshold: 0.00030571327832958496, fp/fn percent: 24.8 %
# Channel dots, compare dots vs worms, threshold: 0.00030571327832958496, fp/fn percent: 16.93548387096774 %
# Channel dots, compare dots vs artifacts, threshold: 0.00030571327832958496, fp/fn percent: 28.86996904024768 %
# Channel dots, compare dots vs tracks, threshold: 0.0013797581365148932, fp/fn percent: 25.973333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0013797581365148932, fp/fn percent: 16.733870967741936 %
# Channel dots, compare dots vs artifacts, threshold: 0.0013797581365148932, fp/fn percent: 30.340557275541798 %
# Channel dots, compare dots vs tracks, threshold: -2.088575503919853, fp/fn percent: 2.4533333333333336 %
# Channel dots, compare dots vs worms, threshold: -2.088575503919853, fp/fn percent: 2.1169354838709675 %
# Channel dots, compare dots vs artifacts, threshold: -2.088575503919853, fp/fn percent: 13.69969040247678 %
# Channel dots, compare dots vs tracks, threshold: 1.0, fp/fn percent: 10.906666666666668 %
# Channel dots, compare dots vs worms, threshold: 1.0, fp/fn percent: 9.576612903225806 %
# Channel dots, compare dots vs artifacts, threshold: 1.0, fp/fn percent: 24.922600619195045 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 51.49333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 43.145161290322584 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 59.05572755417957 %
# Channel dots, compare dots vs tracks, threshold: 1.0, fp/fn percent: 14.399999999999999 %
# Channel dots, compare dots vs worms, threshold: 1.0, fp/fn percent: 13.407258064516128 %
# Channel dots, compare dots vs artifacts, threshold: 1.0, fp/fn percent: 29.102167182662537 %
# Channel dots, compare dots vs tracks, threshold: 11.000000000000002, fp/fn percent: 38.906666666666666 %
# Channel dots, compare dots vs worms, threshold: 11.000000000000002, fp/fn percent: 38.00403225806452 %
# Channel dots, compare dots vs artifacts, threshold: 11.000000000000002, fp/fn percent: 43.188854489164086 %
# Channel dots, compare dots vs tracks, threshold: 48.0, fp/fn percent: 19.733333333333334 %
# Channel dots, compare dots vs worms, threshold: 48.0, fp/fn percent: 18.548387096774192 %
# Channel dots, compare dots vs artifacts, threshold: 48.0, fp/fn percent: 28.01857585139319 %
# Channel worms, compare worms vs dots, threshold: -12.87303502803011, fp/fn percent: 16.532258064516128 %
# Channel worms, compare worms vs tracks, threshold: -12.87303502803011, fp/fn percent: 37.19758064516129 %
# Channel worms, compare worms vs artifacts, threshold: -12.87303502803011, fp/fn percent: 40.82661290322581 %
# Channel worms, compare worms vs dots, threshold: 3.8580246913580246e-05, fp/fn percent: 30.141129032258064 %
# Channel worms, compare worms vs tracks, threshold: 3.8580246913580246e-05, fp/fn percent: 36.895161290322584 %
# Channel worms, compare worms vs artifacts, threshold: 3.8580246913580246e-05, fp/fn percent: 46.57258064516129 %
# Channel worms, compare worms vs dots, threshold: 0.00010061229957329262, fp/fn percent: 23.68951612903226 %
# Channel worms, compare worms vs tracks, threshold: 0.00010061229957329262, fp/fn percent: 40.524193548387096 %
# Channel worms, compare worms vs artifacts, threshold: 0.00010061229957329262, fp/fn percent: 44.153225806451616 %
# Channel worms, compare worms vs dots, threshold: 7.561513643950278e-05, fp/fn percent: 30.846774193548388 %
# Channel worms, compare worms vs tracks, threshold: 7.561513643950278e-05, fp/fn percent: 36.895161290322584 %
# Channel worms, compare worms vs artifacts, threshold: 7.561513643950278e-05, fp/fn percent: 48.48790322580645 %
# Channel worms, compare worms vs dots, threshold: 0.0001347744092724819, fp/fn percent: 23.286290322580644 %
# Channel worms, compare worms vs tracks, threshold: 0.0001347744092724819, fp/fn percent: 36.49193548387097 %
# Channel worms, compare worms vs artifacts, threshold: 0.0001347744092724819, fp/fn percent: 54.33467741935484 %
# Channel worms, compare worms vs dots, threshold: 0.0006632691913730209, fp/fn percent: 22.681451612903224 %
# Channel worms, compare worms vs tracks, threshold: 0.0006632691913730209, fp/fn percent: 30.94758064516129 %
# Channel worms, compare worms vs artifacts, threshold: 0.0006632691913730209, fp/fn percent: 42.23790322580645 %
# Channel worms, compare worms vs dots, threshold: 3.3945284272441167, fp/fn percent: 13.205645161290322 %
# Channel worms, compare worms vs tracks, threshold: 3.3945284272441167, fp/fn percent: 32.25806451612903 %
# Channel worms, compare worms vs artifacts, threshold: 3.3945284272441167, fp/fn percent: 36.99596774193548 %
# Channel worms, compare worms vs dots, threshold: 4.0, fp/fn percent: 21.27016129032258 %
# Channel worms, compare worms vs tracks, threshold: 4.0, fp/fn percent: 51.20967741935484 %
# Channel worms, compare worms vs artifacts, threshold: 4.0, fp/fn percent: 41.33064516129033 %
# Channel worms, compare worms vs dots, threshold: 12.0, fp/fn percent: 22.681451612903224 %
# Channel worms, compare worms vs tracks, threshold: 12.0, fp/fn percent: 49.49596774193548 %
# Channel worms, compare worms vs artifacts, threshold: 12.0, fp/fn percent: 45.26209677419355 %
# Channel worms, compare worms vs dots, threshold: 7.0, fp/fn percent: 18.346774193548388 %
# Channel worms, compare worms vs tracks, threshold: 7.0, fp/fn percent: 46.16935483870967 %
# Channel worms, compare worms vs artifacts, threshold: 7.0, fp/fn percent: 39.314516129032256 %
# Channel worms, compare worms vs dots, threshold: 12.0, fp/fn percent: 46.068548387096776 %
# Channel worms, compare worms vs tracks, threshold: 12.0, fp/fn percent: 50.90725806451613 %
# Channel worms, compare worms vs artifacts, threshold: 12.0, fp/fn percent: 45.564516129032256 %
# Channel worms, compare worms vs dots, threshold: 52.000000000000014, fp/fn percent: 26.008064516129032 %
# Channel worms, compare worms vs tracks, threshold: 52.000000000000014, fp/fn percent: 49.193548387096776 %
# Channel worms, compare worms vs artifacts, threshold: 52.000000000000014, fp/fn percent: 39.91935483870967 %
# Channel worms, compare worms vs dots, threshold: -12.85950815259664, fp/fn percent: 16.633064516129032 %
# Channel worms, compare worms vs tracks, threshold: -12.85950815259664, fp/fn percent: 37.399193548387096 %
# Channel worms, compare worms vs artifacts, threshold: -12.85950815259664, fp/fn percent: 39.71774193548387 %
# Channel worms, compare worms vs dots, threshold: 3.947526807668163e-05, fp/fn percent: 30.64516129032258 %
# Channel worms, compare worms vs tracks, threshold: 3.947526807668163e-05, fp/fn percent: 36.895161290322584 %
# Channel worms, compare worms vs artifacts, threshold: 3.947526807668163e-05, fp/fn percent: 46.67338709677419 %
# Channel worms, compare worms vs dots, threshold: 0.00010492848627449114, fp/fn percent: 23.68951612903226 %
# Channel worms, compare worms vs tracks, threshold: 0.00010492848627449114, fp/fn percent: 41.431451612903224 %
# Channel worms, compare worms vs artifacts, threshold: 0.00010492848627449114, fp/fn percent: 45.564516129032256 %
# Channel worms, compare worms vs dots, threshold: 7.763259457279964e-05, fp/fn percent: 32.15725806451613 %
# Channel worms, compare worms vs tracks, threshold: 7.763259457279964e-05, fp/fn percent: 36.895161290322584 %
# Channel worms, compare worms vs artifacts, threshold: 7.763259457279964e-05, fp/fn percent: 49.29435483870967 %
# Channel worms, compare worms vs dots, threshold: 0.00015697915126839317, fp/fn percent: 22.983870967741936 %
# Channel worms, compare worms vs tracks, threshold: 0.00015697915126839317, fp/fn percent: 37.70161290322581 %
# Channel worms, compare worms vs artifacts, threshold: 0.00015697915126839317, fp/fn percent: 43.850806451612904 %
# Channel worms, compare worms vs dots, threshold: 0.0007957281611571903, fp/fn percent: 21.27016129032258 %
# Channel worms, compare worms vs tracks, threshold: 0.0007957281611571903, fp/fn percent: 32.96370967741936 %
# Channel worms, compare worms vs artifacts, threshold: 0.0007957281611571903, fp/fn percent: 41.83467741935484 %
# Channel worms, compare worms vs dots, threshold: 3.431112372115755, fp/fn percent: 13.104838709677418 %
# Channel worms, compare worms vs tracks, threshold: 3.431112372115755, fp/fn percent: 31.85483870967742 %
# Channel worms, compare worms vs artifacts, threshold: 3.431112372115755, fp/fn percent: 37.29838709677419 %
# Channel worms, compare worms vs dots, threshold: 4.0, fp/fn percent: 21.16935483870968 %
# Channel worms, compare worms vs tracks, threshold: 4.0, fp/fn percent: 50.30241935483871 %
# Channel worms, compare worms vs artifacts, threshold: 4.0, fp/fn percent: 41.229838709677416 %
# Channel worms, compare worms vs dots, threshold: 12.0, fp/fn percent: 22.278225806451612 %
# Channel worms, compare worms vs tracks, threshold: 12.0, fp/fn percent: 49.29435483870967 %
# Channel worms, compare worms vs artifacts, threshold: 12.0, fp/fn percent: 45.96774193548387 %
# Channel worms, compare worms vs dots, threshold: 7.000000000000001, fp/fn percent: 17.338709677419356 %
# Channel worms, compare worms vs tracks, threshold: 7.000000000000001, fp/fn percent: 45.16129032258064 %
# Channel worms, compare worms vs artifacts, threshold: 7.000000000000001, fp/fn percent: 39.91935483870967 %
# Channel worms, compare worms vs dots, threshold: 13.000000000000002, fp/fn percent: 38.810483870967744 %
# Channel worms, compare worms vs tracks, threshold: 13.000000000000002, fp/fn percent: 48.48790322580645 %
# Channel worms, compare worms vs artifacts, threshold: 13.000000000000002, fp/fn percent: 47.479838709677416 %
# Channel worms, compare worms vs dots, threshold: 62.0, fp/fn percent: 21.471774193548388 %
# Channel worms, compare worms vs tracks, threshold: 62.0, fp/fn percent: 47.58064516129033 %
# Channel worms, compare worms vs artifacts, threshold: 62.0, fp/fn percent: 44.05241935483871 %
# Channel tracks, compare tracks vs dots, threshold: -13.690186527090122, fp/fn percent: 16.826666666666668 %
# Channel tracks, compare tracks vs worms, threshold: -13.690186527090122, fp/fn percent: 41.229838709677416 %
# Channel tracks, compare tracks vs artifacts, threshold: -13.690186527090122, fp/fn percent: 37.074303405572756 %
# Channel tracks, compare tracks vs dots, threshold: 3.839070298329975e-05, fp/fn percent: 16.69333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 3.839070298329975e-05, fp/fn percent: 36.895161290322584 %
# Channel tracks, compare tracks vs artifacts, threshold: 3.839070298329975e-05, fp/fn percent: 33.126934984520126 %
# Channel tracks, compare tracks vs dots, threshold: 8.708461789971896e-05, fp/fn percent: 11.600000000000001 %
# Channel tracks, compare tracks vs worms, threshold: 8.708461789971896e-05, fp/fn percent: 43.850806451612904 %
# Channel tracks, compare tracks vs artifacts, threshold: 8.708461789971896e-05, fp/fn percent: 33.28173374613003 %
# Channel tracks, compare tracks vs dots, threshold: 7.598732034872334e-05, fp/fn percent: 17.866666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 7.598732034872334e-05, fp/fn percent: 37.096774193548384 %
# Channel tracks, compare tracks vs artifacts, threshold: 7.598732034872334e-05, fp/fn percent: 35.60371517027864 %
# Channel tracks, compare tracks vs dots, threshold: 0.00020676790767788794, fp/fn percent: 29.46666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.00020676790767788794, fp/fn percent: 38.70967741935484 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.00020676790767788794, fp/fn percent: 46.98142414860681 %
# Channel tracks, compare tracks vs dots, threshold: 0.0009367648297590676, fp/fn percent: 32.879999999999995 %
# Channel tracks, compare tracks vs worms, threshold: 0.0009367648297590676, fp/fn percent: 36.391129032258064 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0009367648297590676, fp/fn percent: 47.44582043343653 %
# Channel tracks, compare tracks vs dots, threshold: 1.874685173207824, fp/fn percent: 13.813333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 1.874685173207824, fp/fn percent: 39.91935483870967 %
# Channel tracks, compare tracks vs artifacts, threshold: 1.874685173207824, fp/fn percent: 57.50773993808049 %
# Channel tracks, compare tracks vs dots, threshold: 2.0000000001030838, fp/fn percent: 12.426666666666666 %
# Channel tracks, compare tracks vs worms, threshold: 2.0000000001030838, fp/fn percent: 45.564516129032256 %
# Channel tracks, compare tracks vs artifacts, threshold: 2.0000000001030838, fp/fn percent: 37.461300309597526 %
# Channel tracks, compare tracks vs dots, threshold: 8.0, fp/fn percent: 15.706666666666665 %
# Channel tracks, compare tracks vs worms, threshold: 8.0, fp/fn percent: 47.278225806451616 %
# Channel tracks, compare tracks vs artifacts, threshold: 8.0, fp/fn percent: 43.343653250774 %
# Channel tracks, compare tracks vs dots, threshold: 5.0, fp/fn percent: 12.64 %
# Channel tracks, compare tracks vs worms, threshold: 5.0, fp/fn percent: 46.270161290322584 %
# Channel tracks, compare tracks vs artifacts, threshold: 5.0, fp/fn percent: 39.318885448916404 %
# Channel tracks, compare tracks vs dots, threshold: 11.000000000000002, fp/fn percent: 42.29333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 11.000000000000002, fp/fn percent: 49.596774193548384 %
# Channel tracks, compare tracks vs artifacts, threshold: 11.000000000000002, fp/fn percent: 43.26625386996904 %
# Channel tracks, compare tracks vs dots, threshold: 47.00007083035156, fp/fn percent: 23.493333333333332 %
# Channel tracks, compare tracks vs worms, threshold: 47.00007083035156, fp/fn percent: 49.596774193548384 %
# Channel tracks, compare tracks vs artifacts, threshold: 47.00007083035156, fp/fn percent: 37.61609907120743 %
# Channel tracks, compare tracks vs dots, threshold: -13.644709011902304, fp/fn percent: 17.013333333333332 %
# Channel tracks, compare tracks vs worms, threshold: -13.644709011902304, fp/fn percent: 41.33064516129033 %
# Channel tracks, compare tracks vs artifacts, threshold: -13.644709011902304, fp/fn percent: 35.681114551083596 %
# Channel tracks, compare tracks vs dots, threshold: 3.93677680928585e-05, fp/fn percent: 17.52 %
# Channel tracks, compare tracks vs worms, threshold: 3.93677680928585e-05, fp/fn percent: 36.99596774193548 %
# Channel tracks, compare tracks vs artifacts, threshold: 3.93677680928585e-05, fp/fn percent: 33.591331269349844 %
# Channel tracks, compare tracks vs dots, threshold: 9.007705972954066e-05, fp/fn percent: 12.24 %
# Channel tracks, compare tracks vs worms, threshold: 9.007705972954066e-05, fp/fn percent: 43.75 %
# Channel tracks, compare tracks vs artifacts, threshold: 9.007705972954066e-05, fp/fn percent: 35.681114551083596 %
# Channel tracks, compare tracks vs dots, threshold: 7.876384640197724e-05, fp/fn percent: 19.306666666666665 %
# Channel tracks, compare tracks vs worms, threshold: 7.876384640197724e-05, fp/fn percent: 36.79435483870967 %
# Channel tracks, compare tracks vs artifacts, threshold: 7.876384640197724e-05, fp/fn percent: 36.60990712074303 %
# Channel tracks, compare tracks vs dots, threshold: 0.00023309960048208648, fp/fn percent: 28.720000000000002 %
# Channel tracks, compare tracks vs worms, threshold: 0.00023309960048208648, fp/fn percent: 39.818548387096776 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.00023309960048208648, fp/fn percent: 49.45820433436533 %
# Channel tracks, compare tracks vs dots, threshold: 0.0011223403227117704, fp/fn percent: 29.28 %
# Channel tracks, compare tracks vs worms, threshold: 0.0011223403227117704, fp/fn percent: 37.29838709677419 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0011223403227117704, fp/fn percent: 49.303405572755416 %
# Channel tracks, compare tracks vs dots, threshold: 1.9179382779979124, fp/fn percent: 13.893333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 1.9179382779979124, fp/fn percent: 39.71774193548387 %
# Channel tracks, compare tracks vs artifacts, threshold: 1.9179382779979124, fp/fn percent: 57.120743034055735 %
# Channel tracks, compare tracks vs dots, threshold: 2.024510902231545, fp/fn percent: 12.559999999999999 %
# Channel tracks, compare tracks vs worms, threshold: 2.024510902231545, fp/fn percent: 45.26209677419355 %
# Channel tracks, compare tracks vs artifacts, threshold: 2.024510902231545, fp/fn percent: 38.69969040247678 %
# Channel tracks, compare tracks vs dots, threshold: 8.0, fp/fn percent: 15.466666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 8.0, fp/fn percent: 46.67338709677419 %
# Channel tracks, compare tracks vs artifacts, threshold: 8.0, fp/fn percent: 43.4984520123839 %
# Channel tracks, compare tracks vs dots, threshold: 5.000000000000001, fp/fn percent: 14.346666666666666 %
# Channel tracks, compare tracks vs worms, threshold: 5.000000000000001, fp/fn percent: 45.86693548387097 %
# Channel tracks, compare tracks vs artifacts, threshold: 5.000000000000001, fp/fn percent: 40.47987616099071 %
# Channel tracks, compare tracks vs dots, threshold: 12.000000000000002, fp/fn percent: 37.653333333333336 %
# Channel tracks, compare tracks vs worms, threshold: 12.000000000000002, fp/fn percent: 49.395161290322584 %
# Channel tracks, compare tracks vs artifacts, threshold: 12.000000000000002, fp/fn percent: 46.82662538699691 %
# Channel tracks, compare tracks vs dots, threshold: 55.00000000237033, fp/fn percent: 20.080000000000002 %
# Channel tracks, compare tracks vs worms, threshold: 55.00000000237033, fp/fn percent: 48.99193548387097 %
# Channel tracks, compare tracks vs artifacts, threshold: 55.00000000237033, fp/fn percent: 43.4984520123839 %
# Channel artifacts, compare artifacts vs dots, threshold: -12.498265636441207, fp/fn percent: 11.455108359133128 %
# Channel artifacts, compare artifacts vs tracks, threshold: -12.498265636441207, fp/fn percent: 26.857585139318886 %
# Channel artifacts, compare artifacts vs worms, threshold: -12.498265636441207, fp/fn percent: 40.524193548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.4639211813860734e-05, fp/fn percent: 32.19814241486068 %
# Channel artifacts, compare artifacts vs tracks, threshold: 3.4639211813860734e-05, fp/fn percent: 32.19814241486068 %
# Channel artifacts, compare artifacts vs worms, threshold: 3.4639211813860734e-05, fp/fn percent: 42.54032258064516 %
# Channel artifacts, compare artifacts vs dots, threshold: 7.869312127182525e-05, fp/fn percent: 27.476780185758514 %
# Channel artifacts, compare artifacts vs tracks, threshold: 7.869312127182525e-05, fp/fn percent: 32.73993808049536 %
# Channel artifacts, compare artifacts vs worms, threshold: 7.869312127182525e-05, fp/fn percent: 37.70161290322581 %
# Channel artifacts, compare artifacts vs dots, threshold: 7.228092510063579e-05, fp/fn percent: 32.27554179566564 %
# Channel artifacts, compare artifacts vs tracks, threshold: 7.228092510063579e-05, fp/fn percent: 34.52012383900929 %
# Channel artifacts, compare artifacts vs worms, threshold: 7.228092510063579e-05, fp/fn percent: 47.58064516129033 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.00015981853915878125, fp/fn percent: 26.857585139318886 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.00015981853915878125, fp/fn percent: 42.64705882352941 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.00015981853915878125, fp/fn percent: 56.3508064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0008090339875944388, fp/fn percent: 30.41795665634675 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0008090339875944388, fp/fn percent: 43.73065015479876 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0008090339875944388, fp/fn percent: 39.71774193548387 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.2504582572862786, fp/fn percent: 22.291021671826623 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.2504582572862786, fp/fn percent: 54.643962848297214 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.2504582572862786, fp/fn percent: 33.064516129032256 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.999995740575944, fp/fn percent: 24.922600619195045 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.999995740575944, fp/fn percent: 37.925696594427244 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.999995740575944, fp/fn percent: 32.45967741935484 %
# Channel artifacts, compare artifacts vs dots, threshold: 8.0, fp/fn percent: 24.38080495356037 %
# Channel artifacts, compare artifacts vs tracks, threshold: 8.0, fp/fn percent: 43.343653250774 %
# Channel artifacts, compare artifacts vs worms, threshold: 8.0, fp/fn percent: 36.99596774193548 %
# Channel artifacts, compare artifacts vs dots, threshold: 5.0, fp/fn percent: 25.696594427244584 %
# Channel artifacts, compare artifacts vs tracks, threshold: 5.0, fp/fn percent: 39.318885448916404 %
# Channel artifacts, compare artifacts vs worms, threshold: 5.0, fp/fn percent: 34.07258064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 10.000409176986398, fp/fn percent: 51.08359133126935 %
# Channel artifacts, compare artifacts vs tracks, threshold: 10.000409176986398, fp/fn percent: 43.26625386996904 %
# Channel artifacts, compare artifacts vs worms, threshold: 10.000409176986398, fp/fn percent: 42.84274193548387 %
# Channel artifacts, compare artifacts vs dots, threshold: 46.0, fp/fn percent: 36.22291021671827 %
# Channel artifacts, compare artifacts vs tracks, threshold: 46.0, fp/fn percent: 37.461300309597526 %
# Channel artifacts, compare artifacts vs worms, threshold: 46.0, fp/fn percent: 38.20564516129033 %
# Channel artifacts, compare artifacts vs dots, threshold: -12.420597835585788, fp/fn percent: 10.758513931888544 %
# Channel artifacts, compare artifacts vs tracks, threshold: -12.420597835585788, fp/fn percent: 25.30959752321981 %
# Channel artifacts, compare artifacts vs worms, threshold: -12.420597835585788, fp/fn percent: 39.01209677419355 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.603156616265137e-05, fp/fn percent: 32.50773993808049 %
# Channel artifacts, compare artifacts vs tracks, threshold: 3.603156616265137e-05, fp/fn percent: 33.04953560371517 %
# Channel artifacts, compare artifacts vs worms, threshold: 3.603156616265137e-05, fp/fn percent: 43.95161290322581 %
# Channel artifacts, compare artifacts vs dots, threshold: 8.802157399522165e-05, fp/fn percent: 26.47058823529412 %
# Channel artifacts, compare artifacts vs tracks, threshold: 8.802157399522165e-05, fp/fn percent: 35.44891640866873 %
# Channel artifacts, compare artifacts vs worms, threshold: 8.802157399522165e-05, fp/fn percent: 41.12903225806452 %
# Channel artifacts, compare artifacts vs dots, threshold: 7.653927218600306e-05, fp/fn percent: 32.50773993808049 %
# Channel artifacts, compare artifacts vs tracks, threshold: 7.653927218600306e-05, fp/fn percent: 36.22291021671827 %
# Channel artifacts, compare artifacts vs worms, threshold: 7.653927218600306e-05, fp/fn percent: 48.79032258064516 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.00018852817211359674, fp/fn percent: 28.560371517027868 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.00018852817211359674, fp/fn percent: 46.362229102167184 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.00018852817211359674, fp/fn percent: 42.03629032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0009771531965394931, fp/fn percent: 28.86996904024768 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0009771531965394931, fp/fn percent: 45.975232198142415 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0009771531965394931, fp/fn percent: 39.314516129032256 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.3555356965724785, fp/fn percent: 21.904024767801857 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.3555356965724785, fp/fn percent: 53.637770897832816 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.3555356965724785, fp/fn percent: 33.770161290322584 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.0, fp/fn percent: 27.86377708978328 %
# Channel artifacts, compare artifacts vs tracks, threshold: 3.0, fp/fn percent: 39.08668730650155 %
# Channel artifacts, compare artifacts vs worms, threshold: 3.0, fp/fn percent: 38.104838709677416 %
# Channel artifacts, compare artifacts vs dots, threshold: 8.0, fp/fn percent: 23.374613003095977 %
# Channel artifacts, compare artifacts vs tracks, threshold: 8.0, fp/fn percent: 43.4984520123839 %
# Channel artifacts, compare artifacts vs worms, threshold: 8.0, fp/fn percent: 37.5 %
# Channel artifacts, compare artifacts vs dots, threshold: 5.000000000000001, fp/fn percent: 24.071207430340557 %
# Channel artifacts, compare artifacts vs tracks, threshold: 5.000000000000001, fp/fn percent: 40.47987616099071 %
# Channel artifacts, compare artifacts vs worms, threshold: 5.000000000000001, fp/fn percent: 34.979838709677416 %
# Channel artifacts, compare artifacts vs dots, threshold: 12.000000000000004, fp/fn percent: 42.26006191950464 %
# Channel artifacts, compare artifacts vs tracks, threshold: 12.000000000000004, fp/fn percent: 48.21981424148607 %
# Channel artifacts, compare artifacts vs worms, threshold: 12.000000000000004, fp/fn percent: 46.875 %
# Channel artifacts, compare artifacts vs dots, threshold: 58.0, fp/fn percent: 26.702786377708975 %
# Channel artifacts, compare artifacts vs tracks, threshold: 58.0, fp/fn percent: 45.04643962848297 %
# Channel artifacts, compare artifacts vs worms, threshold: 58.0, fp/fn percent: 43.24596774193548 %
