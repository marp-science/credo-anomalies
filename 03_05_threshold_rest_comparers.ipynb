# %%
import numpy as np

from commons import *
from dataset_loader import load_images, prepare_dataset
from IPython.display import display
import cv2
import pickle
import matplotlib.pyplot as plt
from keras.models import load_model


DOTS_SRC = 'hit-images-final2/dot'
TRACKS_SRC = 'hit-images-final2/line'
WORMS_SRC = 'hit-images-final2/worms'
ARTIFACTS_SRC = 'hit-images-final2/artefact'

DOTS_AC = 'cache/dots_100000.h5'
TRACKS_AC = 'cache/tracks_100000.h5'
WORMS_AC = 'cache/worms_100000.h5'
ARTIFACTS_AC = 'cache/artifacts_100000.h5'



dots_set =  prepare_dataset(load_images(DOTS_SRC))
worms_set =  prepare_dataset(load_images(WORMS_SRC))
tracks_set =  prepare_dataset(load_images(TRACKS_SRC))
artifacts_set =  prepare_dataset(load_images(ARTIFACTS_SRC))

dots_autoencoder = load_model(DOTS_AC)
worms_autoencoder = load_model(WORMS_AC)
tracks_autoencoder = load_model(TRACKS_AC)
artifacts_autoencoder = load_model(ARTIFACTS_AC)

# %%
for dm_func in [dm_func_avg_hash, dm_func_p_hash, dm_func_d_hash, dm_func_haar_hash, dm_func_db4_hash, dm_func_cr_hash, dm_func_color_hash]:
      for cutoff_background in [False, True]:
            for normalize in [False, True]:
                  print('====| dm_func = %s, cutoff_background = %s, normalize = %s |====' % (str(dm_func.__name__), str(cutoff_background), str(normalize)))
                  argv = {'cutoff_background': cutoff_background, 'normalize': normalize, 'dm_func': dm_func}

                  on = {'dots': calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv),
                        'worms': calc_similarity(worms_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv),
                        'tracks': calc_similarity(tracks_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv),
                        'artifacts': calc_similarity(artifacts_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv)}
                  confusion_matrix(on)
# Out:
# ====| dm_func = <function dm_func_avg_hash at 0x00000200F6550AF0>, cutoff_background = False, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.12145748987854 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 84.90088570223534 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 86.43395477984926 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 99.31174089068826 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 91.2945801741084 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 91.91592562651576 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 97.25854070012653 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 76.21454647570907 %
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 40.19264448336252 %
# Channel artifacts, compare artifacts vs dots, threshold: 7.0, fp/fn percent: 28.361761205870685 %
# Channel artifacts, compare artifacts vs tracks, threshold: 5.0, fp/fn percent: 55.05254648342765 %
# Channel artifacts, compare artifacts vs worms, threshold: 5.0, fp/fn percent: 49.12434325744308 %
# ====| dm_func = <function dm_func_avg_hash at 0x00000200F6550AF0>, cutoff_background = False, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.12145748987854 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 84.90088570223534 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 86.43395477984926 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 99.31174089068826 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 91.2945801741084 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 91.91592562651576 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 97.25854070012653 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 76.21454647570907 %
# Channel worms, compare worms vs artifacts, threshold: 0.00040924764513648596, fp/fn percent: 31.61120840630473 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.1836734693877551, fp/fn percent: 35.938119793732646 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0234375, fp/fn percent: 45.21692266235516 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.008310249307479225, fp/fn percent: 45.27145359019264 %
# ====| dm_func = <function dm_func_avg_hash at 0x00000200F6550AF0>, cutoff_background = True, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.04048582995951 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 84.85870940531422 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 86.43395477984926 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 99.25101214574899 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 90.92951418140971 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 91.8620317973592 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 98.69253479544497 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 78.15220443695591 %
# Channel worms, compare worms vs artifacts, threshold: 0.0, fp/fn percent: 74.95621716287215 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.0, fp/fn percent: 31.416104720349068 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.0, fp/fn percent: 53.83993532740501 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.0, fp/fn percent: 52.53940455341506 %
# ====| dm_func = <function dm_func_avg_hash at 0x00000200F6550AF0>, cutoff_background = True, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.04048582995951 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 84.85870940531422 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 86.43395477984926 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 99.25101214574899 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 90.92951418140971 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 91.8620317973592 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 98.69253479544497 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 78.15220443695591 %
# Channel worms, compare worms vs artifacts, threshold: 0.0, fp/fn percent: 74.95621716287215 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.03, fp/fn percent: 16.22372074573582 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.002770083102493075, fp/fn percent: 40.31258420910805 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.001973847614873256, fp/fn percent: 43.25744308231174 %
# ====| dm_func = <function dm_func_p_hash at 0x00000200F6550B80>, cutoff_background = False, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 60.08097165991902 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 83.97300716997049 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 80.68226894089648 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 97.4493927125506 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 91.51923616961528 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 88.62840204796551 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 88.82328131590046 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 67.62145464757091 %
# Channel worms, compare worms vs artifacts, threshold: 2.0, fp/fn percent: 37.478108581436075 %
# Channel artifacts, compare artifacts vs dots, threshold: 26.0, fp/fn percent: 40.73780245934153 %
# Channel artifacts, compare artifacts vs tracks, threshold: 18.0, fp/fn percent: 54.27108596065751 %
# Channel artifacts, compare artifacts vs worms, threshold: 14.0, fp/fn percent: 48.33625218914185 %
# ====| dm_func = <function dm_func_p_hash at 0x00000200F6550B80>, cutoff_background = False, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 60.08097165991902 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 83.97300716997049 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 80.68226894089648 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 97.4493927125506 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 91.51923616961528 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 88.62840204796551 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 88.82328131590046 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 67.62145464757091 %
# Channel worms, compare worms vs artifacts, threshold: 0.002832662492322152, fp/fn percent: 33.274956217162874 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.6122448979591837, fp/fn percent: 36.85045616818723 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.08304498269896193, fp/fn percent: 46.80679062247373 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.027133017619118405, fp/fn percent: 42.819614711033275 %
# ====| dm_func = <function dm_func_p_hash at 0x00000200F6550B80>, cutoff_background = True, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 60.0 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 84.35259384226065 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 86.83062276874256 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 97.89473684210527 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 92.44594215108116 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 92.96685529506871 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 94.22184732180514 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 69.98034260039316 %
# Channel worms, compare worms vs artifacts, threshold: 0.0, fp/fn percent: 77.05779334500875 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 92.6219754065847 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 62.30126650498518 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.0, fp/fn percent: 41.94395796847636 %
# ====| dm_func = <function dm_func_p_hash at 0x00000200F6550B80>, cutoff_background = True, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 60.0 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 84.35259384226065 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 86.83062276874256 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 97.89473684210527 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 92.44594215108116 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 92.96685529506871 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 94.22184732180514 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 69.98034260039316 %
# Channel worms, compare worms vs artifacts, threshold: 0.0, fp/fn percent: 77.05779334500875 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 92.6219754065847 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 62.30126650498518 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0016326530612244899, fp/fn percent: 39.229422066549915 %
# ====| dm_func = <function dm_func_d_hash at 0x00000200F6550C10>, cutoff_background = False, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 55.97165991902834 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 82.11725010544075 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 84.25228084093614 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 99.79757085020243 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 91.23841617523168 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 91.2961465912153 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 99.4517081400253 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 70.14883459702331 %
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 42.819614711033275 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.0, fp/fn percent: 75.84291947639825 %
# Channel artifacts, compare artifacts vs tracks, threshold: 3.0, fp/fn percent: 62.94799245486392 %
# Channel artifacts, compare artifacts vs worms, threshold: 3.0, fp/fn percent: 47.285464098073554 %
# ====| dm_func = <function dm_func_d_hash at 0x00000200F6550C10>, cutoff_background = False, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 55.97165991902834 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 82.11725010544075 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 84.25228084093614 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 99.79757085020243 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 91.23841617523168 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 91.2961465912153 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 99.4517081400253 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 70.14883459702331 %
# Channel worms, compare worms vs artifacts, threshold: 0.0010368202887832063, fp/fn percent: 35.72679509632224 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.05555555555555555, fp/fn percent: 43.395477984926615 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.013333333333333334, fp/fn percent: 47.076259768256534 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.007795138888888889, fp/fn percent: 45.62171628721541 %
# ====| dm_func = <function dm_func_d_hash at 0x00000200F6550C10>, cutoff_background = True, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 55.97165991902834 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 82.201602699283 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 84.25228084093614 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 99.63562753036437 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 90.98567818028643 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 91.43088116410671 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 99.49388443694643 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 71.6371805672564 %
# Channel worms, compare worms vs artifacts, threshold: 0.0, fp/fn percent: 72.85464098073555 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.0, fp/fn percent: 63.14954383181277 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.0, fp/fn percent: 67.71759633521962 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.0, fp/fn percent: 52.27670753064798 %
# ====| dm_func = <function dm_func_d_hash at 0x00000200F6550C10>, cutoff_background = True, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 55.97165991902834 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 82.201602699283 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 84.25228084093614 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 99.63562753036437 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 90.98567818028643 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 91.43088116410671 %
# Channel worms, compare worms vs dots, threshold: 0.0, fp/fn percent: 99.49388443694643 %
# Channel worms, compare worms vs tracks, threshold: 0.0, fp/fn percent: 71.6371805672564 %
# Channel worms, compare worms vs artifacts, threshold: 0.0, fp/fn percent: 72.85464098073555 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0051966125251594174, fp/fn percent: 31.336771122570404 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0034602076124567475, fp/fn percent: 40.231743465373214 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0032, fp/fn percent: 41.155866900175134 %
# ====| dm_func = <function dm_func_haar_hash at 0x00000200F6550CA0>, cutoff_background = False, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 12.0, fp/fn percent: 46.72064777327935 %
# Channel dots, compare dots vs worms, threshold: 12.0, fp/fn percent: 46.140868831716574 %
# Channel dots, compare dots vs artifacts, threshold: 11.0, fp/fn percent: 51.05117017056724 %
# Channel tracks, compare tracks vs dots, threshold: 10.0, fp/fn percent: 52.67206477732793 %
# Channel tracks, compare tracks vs worms, threshold: 12.0, fp/fn percent: 45.80174108396518 %
# Channel tracks, compare tracks vs artifacts, threshold: 10.0, fp/fn percent: 50.25599568849367 %
# Channel worms, compare worms vs dots, threshold: 10.0, fp/fn percent: 49.346267397722485 %
# Channel worms, compare worms vs tracks, threshold: 10.0, fp/fn percent: 49.0873350182533 %
# Channel worms, compare worms vs artifacts, threshold: 12.0, fp/fn percent: 40.36777583187391 %
# Channel artifacts, compare artifacts vs dots, threshold: 29.0, fp/fn percent: 17.572391907973024 %
# Channel artifacts, compare artifacts vs tracks, threshold: 24.0, fp/fn percent: 51.1991376987335 %
# Channel artifacts, compare artifacts vs worms, threshold: 22.0, fp/fn percent: 48.42381786339755 %
# ====| dm_func = <function dm_func_haar_hash at 0x00000200F6550CA0>, cutoff_background = False, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.125, fp/fn percent: 25.222672064777328 %
# Channel dots, compare dots vs worms, threshold: 0.0797923875432526, fp/fn percent: 14.002530577815268 %
# Channel dots, compare dots vs artifacts, threshold: 0.2, fp/fn percent: 37.96112653708846 %
# Channel tracks, compare tracks vs dots, threshold: 0.1111111111111111, fp/fn percent: 22.22672064777328 %
# Channel tracks, compare tracks vs worms, threshold: 0.03043545706371191, fp/fn percent: 34.23195731536086 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.04709141274238227, fp/fn percent: 48.55834007006198 %
# Channel worms, compare worms vs dots, threshold: 0.0679354094579008, fp/fn percent: 12.231126107127794 %
# Channel worms, compare worms vs tracks, threshold: 0.027777777777777776, fp/fn percent: 30.63746138725077 %
# Channel worms, compare worms vs artifacts, threshold: 0.02081165452653486, fp/fn percent: 39.404553415061294 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.7755102040816326, fp/fn percent: 35.30345101150337 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.11805555555555555, fp/fn percent: 46.24090541632983 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.04682948960302458, fp/fn percent: 43.52014010507881 %
# ====| dm_func = <function dm_func_haar_hash at 0x00000200F6550CA0>, cutoff_background = True, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 12.0, fp/fn percent: 46.59919028340081 %
# Channel dots, compare dots vs worms, threshold: 12.0, fp/fn percent: 46.39392661324336 %
# Channel dots, compare dots vs artifacts, threshold: 11.0, fp/fn percent: 51.44783815946054 %
# Channel tracks, compare tracks vs dots, threshold: 11.0, fp/fn percent: 49.87854251012146 %
# Channel tracks, compare tracks vs worms, threshold: 11.0, fp/fn percent: 49.98595900028082 %
# Channel tracks, compare tracks vs artifacts, threshold: 9.0, fp/fn percent: 47.3996227431959 %
# Channel worms, compare worms vs dots, threshold: 10.0, fp/fn percent: 51.66596372838465 %
# Channel worms, compare worms vs tracks, threshold: 10.0, fp/fn percent: 49.929795001404095 %
# Channel worms, compare worms vs artifacts, threshold: 9.0, fp/fn percent: 48.161120840630474 %
# Channel artifacts, compare artifacts vs dots, threshold: 10.0, fp/fn percent: 46.13248710829036 %
# Channel artifacts, compare artifacts vs tracks, threshold: 10.0, fp/fn percent: 45.459444893559684 %
# Channel artifacts, compare artifacts vs worms, threshold: 10.0, fp/fn percent: 44.74605954465849 %
# ====| dm_func = <function dm_func_haar_hash at 0x00000200F6550CA0>, cutoff_background = True, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.125, fp/fn percent: 24.574898785425102 %
# Channel dots, compare dots vs worms, threshold: 0.0797923875432526, fp/fn percent: 13.580767608603963 %
# Channel dots, compare dots vs artifacts, threshold: 0.1111111111111111, fp/fn percent: 21.102737009123363 %
# Channel tracks, compare tracks vs dots, threshold: 0.1165247090571766, fp/fn percent: 20.728744939271255 %
# Channel tracks, compare tracks vs worms, threshold: 0.027777777777777776, fp/fn percent: 33.08059533838809 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.027777777777777776, fp/fn percent: 33.17165184586365 %
# Channel worms, compare worms vs dots, threshold: 0.0625, fp/fn percent: 12.695065373260228 %
# Channel worms, compare worms vs tracks, threshold: 0.027700831024930747, fp/fn percent: 32.26621735467565 %
# Channel worms, compare worms vs artifacts, threshold: 0.013323471400394478, fp/fn percent: 45.62171628721541 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.11902777777777777, fp/fn percent: 18.048393494644984 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.03125, fp/fn percent: 32.713554298032875 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.015457788347205707, fp/fn percent: 43.87040280210158 %
# ====| dm_func = <function dm_func_db4_hash at 0x00000200F6550D30>, cutoff_background = False, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 32.0, fp/fn percent: 28.805668016194332 %
# Channel dots, compare dots vs worms, threshold: 34.0, fp/fn percent: 25.263601855757063 %
# Channel dots, compare dots vs artifacts, threshold: 34.0, fp/fn percent: 24.59341531138437 %
# Channel tracks, compare tracks vs dots, threshold: 25.0, fp/fn percent: 48.70445344129555 %
# Channel tracks, compare tracks vs worms, threshold: 34.0, fp/fn percent: 34.372367312552655 %
# Channel tracks, compare tracks vs artifacts, threshold: 35.0, fp/fn percent: 32.390191323093504 %
# Channel worms, compare worms vs dots, threshold: 29.0, fp/fn percent: 46.94221847321805 %
# Channel worms, compare worms vs tracks, threshold: 32.0, fp/fn percent: 46.47570907048582 %
# Channel worms, compare worms vs artifacts, threshold: 39.0, fp/fn percent: 32.486865148861646 %
# Channel artifacts, compare artifacts vs dots, threshold: 87.0, fp/fn percent: 19.873066243554145 %
# Channel artifacts, compare artifacts vs tracks, threshold: 81.0, fp/fn percent: 52.14227970897333 %
# Channel artifacts, compare artifacts vs worms, threshold: 78.0, fp/fn percent: 45.359019264448335 %
# ====| dm_func = <function dm_func_db4_hash at 0x00000200F6550D30>, cutoff_background = False, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.36294063079777367, fp/fn percent: 26.234817813765183 %
# Channel dots, compare dots vs worms, threshold: 0.24, fp/fn percent: 14.761703922395613 %
# Channel dots, compare dots vs artifacts, threshold: 0.48, fp/fn percent: 38.278460928203096 %
# Channel tracks, compare tracks vs dots, threshold: 0.296875, fp/fn percent: 20.48582995951417 %
# Channel tracks, compare tracks vs worms, threshold: 0.09762812500000001, fp/fn percent: 39.31479921370401 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.1301775147928994, fp/fn percent: 49.55537590945836 %
# Channel worms, compare worms vs dots, threshold: 0.234375, fp/fn percent: 10.839308308730493 %
# Channel worms, compare worms vs tracks, threshold: 0.0997481171600681, fp/fn percent: 28.47514743049705 %
# Channel worms, compare worms vs artifacts, threshold: 0.07187131050767415, fp/fn percent: 38.528896672504374 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.061224489795918, fp/fn percent: 35.85878619595398 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.4088888888888889, fp/fn percent: 46.80679062247373 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.1654110680084706, fp/fn percent: 42.03152364273205 %
# ====| dm_func = <function dm_func_db4_hash at 0x00000200F6550D30>, cutoff_background = True, normalize = False |====
# Channel dots, compare dots vs tracks, threshold: 32.0, fp/fn percent: 30.2834008097166 %
# Channel dots, compare dots vs worms, threshold: 32.0, fp/fn percent: 29.05946857865879 %
# Channel dots, compare dots vs artifacts, threshold: 27.0, fp/fn percent: 41.769139230464106 %
# Channel tracks, compare tracks vs dots, threshold: 24.0, fp/fn percent: 49.959514170040485 %
# Channel tracks, compare tracks vs worms, threshold: 29.0, fp/fn percent: 41.140129177197416 %
# Channel tracks, compare tracks vs artifacts, threshold: 26.0, fp/fn percent: 48.85475613042306 %
# Channel worms, compare worms vs dots, threshold: 24.0, fp/fn percent: 49.93673555461831 %
# Channel worms, compare worms vs tracks, threshold: 26.0, fp/fn percent: 45.5770850884583 %
# Channel worms, compare worms vs artifacts, threshold: 24.0, fp/fn percent: 48.9492119089317 %
# Channel artifacts, compare artifacts vs dots, threshold: 27.0, fp/fn percent: 50.7338357794526 %
# Channel artifacts, compare artifacts vs tracks, threshold: 31.0, fp/fn percent: 42.225815144166 %
# Channel artifacts, compare artifacts vs worms, threshold: 31.0, fp/fn percent: 42.38178633975482 %
# ====| dm_func = <function dm_func_db4_hash at 0x00000200F6550D30>, cutoff_background = True, normalize = True |====
# Channel dots, compare dots vs tracks, threshold: 0.34375, fp/fn percent: 25.97165991902834 %
# Channel dots, compare dots vs worms, threshold: 0.2222222222222222, fp/fn percent: 14.33994095318431 %
# Channel dots, compare dots vs artifacts, threshold: 0.29384566326530615, fp/fn percent: 21.34073780245934 %
# Channel tracks, compare tracks vs dots, threshold: 0.296875, fp/fn percent: 18.886639676113358 %
# Channel tracks, compare tracks vs worms, threshold: 0.08024691358024691, fp/fn percent: 35.10249929795001 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.08034477641472101, fp/fn percent: 35.27351118296955 %
# Channel worms, compare worms vs dots, threshold: 0.18324947707614903, fp/fn percent: 9.827077182623366 %
# Channel worms, compare worms vs tracks, threshold: 0.0775, fp/fn percent: 27.773097444538053 %
# Channel worms, compare worms vs artifacts, threshold: 0.03735722391683243, fp/fn percent: 48.774080560420316 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.3333333333333333, fp/fn percent: 20.071400238000795 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.11328125, fp/fn percent: 31.58178388574508 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0518304633434256, fp/fn percent: 43.957968476357266 %
# ====| dm_func = <function dm_func_cr_hash at 0x00000200F6550DC0>, cutoff_background = False, normalize = False |====
