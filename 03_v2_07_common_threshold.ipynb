# %%
import numpy as np

from commons import *
from dataset_loader import load_images, prepare_dataset
from IPython.display import display
import cv2
import pickle
import matplotlib.pyplot as plt
from keras.models import load_model


# TODO: https://pl.wikipedia.org/wiki/Dywergencja_Kullbacka-Leiblera
# https://towardsdatascience.com/kl-divergence-python-example-b87069e4b810
# TODO: entropia wzajemna, cross entropy


DOTS_SRC = 'hit-images-final2/dot'
TRACKS_SRC = 'hit-images-final2/line'
WORMS_SRC = 'hit-images-final2/worms'
ARTIFACTS_SRC = 'hit-images-final2/artefact'

DOTS_AC = 'cache/dots_v2.h5'
TRACKS_AC = 'cache/tracks_v2.h5'
WORMS_AC = 'cache/worms_v2.h5'
ARTIFACTS_AC = 'cache/artifacts_v2.h5'



dots_set =  prepare_dataset(load_images(DOTS_SRC))
worms_set =  prepare_dataset(load_images(WORMS_SRC))
tracks_set =  prepare_dataset(load_images(TRACKS_SRC))
artifacts_set =  prepare_dataset(load_images(ARTIFACTS_SRC))

dots_autoencoder = load_model(DOTS_AC)
worms_autoencoder = load_model(WORMS_AC)
tracks_autoencoder = load_model(TRACKS_AC)
artifacts_autoencoder = load_model(ARTIFACTS_AC)

# %%
# def find_threshold(sa, sb):
#     a = sorted(sa)
#     b = sorted(sb)
#
#     la = len(a)
#     lb = len(b)
#
#     if la > lb:
#         from scipy.ndimage import zoom
#         a2 = zoom(a, lb / la)
#         a = a2
#     elif la < lb:
#         from scipy.ndimage import zoom
#         b2 = zoom(b, la / lb)
#         b = b2
#
#     la = len(a)
#     lb = len(b)
#
#     ta = int(la // 2)
#     tb = int(lb // 2)
#
#     ca = a[ta]
#     cb = b[tb]
#
#     if ca > cb:
#         swap = a
#         a = b
#         b = swap
#
#     np_a = np.array(a)
#     np_b = np.array(b)
#
#     np_a_ex = append_label_column(np_a, 1)
#     np_b_ex = append_label_column(np_b, 2)
#
#     left = 4
#     right = 3
#
#     np_ab = np.vstack([np_a_ex, np_b_ex])
#     np_ab = np_ab[np_ab[:, 0].argsort()]
#
#     labels = np_ab[:,1]
#
#     cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
#     cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
#     cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
#     cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())
#
#     np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])
#
#     half = 0
#     for row in np_ab_ex:
#         rl = row[left]
#         rr = row[right]
#         if rl > rr:
#             break
#         half += 1
#
#     threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2
#
#     fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
#     fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]
#
#     percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100
#
#     return threshold, percent
#

config = {}

dm_funcs = [dm_func_mean2, dm_func_avg_hash, dm_func_p_hash, dm_func_d_hash, dm_func_haar_hash, dm_func_db4_hash] #  , dm_func_cr_hash, dm_func_color_hash
#dm_funcs = [dm_func_mean2]
cutoff_backgrounds = [True, False]
normalizes = [True, False]
autoencoders = [
    (dots_autoencoder, 'dots', dots_set),
    (worms_autoencoder, 'worms', worms_set),
    (tracks_autoencoder, 'tracks', tracks_set),
    (artifacts_autoencoder, 'artifacts', artifacts_set)
]

#calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, normalize=True, cutoff_background=False)
#trained_set = calculated['dots']
#other_set = np.hstack([calculated['worms'], calculated['tracks'], calculated['artifacts']])




for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = []
            for dm_func in dm_funcs:
                print('====| dm_func = %s, cutoff_background = %s, normalize = %s |====' % (str(dm_func.__name__), str(cutoff_background), str(normalize)))
                argv = {'cutoff_background': cutoff_background, 'normalize': normalize, 'dm_func': dm_func}

                #dots_reconstruction = autoencoder.predict(dots_set) if name != 'dots' else []
                #worms_reconstruction = autoencoder.predict(worms_set) if name != 'worms' else []
                #tracks_reconstruction = autoencoder.predict(tracks_set) if name != 'tracks' else []
                #artifacts_reconstruction = autoencoder.predict(artifacts_set) if name != 'artifacts' else []

                #others = np.vstack([dots_reconstruction, worms_reconstruction, tracks_reconstruction, artifacts_reconstruction])

                #prepare_for_histogram(trained_set, others, dm_func, **argv)

                calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv)

                trained_set = calculated[name]
                other_set = []
                for sn in calculated.keys():
                    if sn != name:
                        other_set.append(calculated[sn])
                other_set = np.hstack(other_set)

                threshold, percent = find_threshold(trained_set, other_set)
                plot_threshold(trained_set, other_set, threshold, 'dots', 'others')

                print('Channel %s, threshold: %f, percent: %f' % (name, threshold, percent))

                rows.append((dm_func.__name__, str(cutoff_background), str(normalize), calculated, threshold))
            config[(autoencoder, cutoff_background, normalize)] = rows
# Out:
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel dots, threshold: -10.861665, percent: 4.560000
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 95.680000
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 65.306667
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 64.293333
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.111111, percent: 22.933333
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.321744, percent: 23.280000
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel dots, threshold: -6.602246, percent: 2.320000
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 95.680000
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 65.280000
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 64.240000
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 12.000000, percent: 45.173333
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 31.000000, percent: 32.346667
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel dots, threshold: -10.656127, percent: 4.826667
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 72.053333
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 63.120000
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 63.093333
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.122449, percent: 24.640000
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.350014, percent: 25.040000
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel dots, threshold: -6.348389, percent: 2.106667
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 72.026667
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 63.120000
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 63.040000
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 12.000000, percent: 43.840000
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 32.000000, percent: 30.133333
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel worms, threshold: -8.384952, percent: 35.181452
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.000977, percent: 28.024194
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.010365, percent: 38.508065
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.002589, percent: 36.895161
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.038625, percent: 29.637097
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.129913, percent: 26.411290
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel worms, threshold: -0.010224, percent: 26.411290
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 1.000000, percent: 35.987903
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 8.000000, percent: 37.500000
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 1.000000, percent: 39.516129
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 12.000000, percent: 49.495968
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 38.000000, percent: 42.137097
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel worms, threshold: -8.354397, percent: 35.685484
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.001314, percent: 30.141129
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.011708, percent: 41.028226
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.002770, percent: 38.004032
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.040000, percent: 27.822581
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.137993, percent: 25.302419
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel worms, threshold: -0.039313, percent: 24.899194
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 1.000000, percent: 37.399194
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 8.000000, percent: 39.112903
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 1.000000, percent: 40.927419
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 13.000000, percent: 48.790323
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 39.000000, percent: 41.834677
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: -9.054533, percent: 31.372224
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 75.621478
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 64.086841
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 63.357640
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.076924, percent: 39.360292
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.243422, percent: 40.719258
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: -1.448767, percent: 33.012927
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 75.555187
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 64.053696
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 63.307922
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 12.000000, percent: 45.243619
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 35.000000, percent: 37.122970
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: -8.973225, percent: 32.532317
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 75.654624
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 31.355651
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 29.963540
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.083333, percent: 37.868744
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.259401, percent: 37.802453
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: -1.611760, percent: 28.704011
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 75.604906
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 31.355651
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 29.963540
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 12.000000, percent: 47.414650
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 36.000000, percent: 40.006629
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: -8.362975, percent: 33.746130
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000000, percent: 70.743034
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000000, percent: 46.362229
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000000, percent: 44.040248
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.040828, percent: 30.340557
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.146273, percent: 29.256966
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: -0.095570, percent: 26.315789
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 0.000000, percent: 70.743034
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 0.000000, percent: 46.362229
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 0.000000, percent: 44.040248
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 11.000000, percent: 45.743034
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 35.000000, percent: 49.380805
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: -8.312261, percent: 33.591331
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.001180, percent: 29.179567
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.012647, percent: 39.241486
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.002551, percent: 37.925697
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.071436, percent: 44.891641
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.231258, percent: 45.123839
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: -1.032960, percent: 41.253870
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 1.000000, percent: 31.346749
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 12.000000, percent: 30.882353
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 1.000000, percent: 36.996904
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 14.000000, percent: 43.421053
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 36.000000, percent: 48.916409

# %%
def find_percent(sa, sb, threshold):
    a = sorted(sa)
    b = sorted(sb)

    la = len(a)
    lb = len(b)

    if la > lb:
        from scipy.ndimage import zoom
        a2 = zoom(a, lb / la)
        a = a2
    elif la < lb:
        from scipy.ndimage import zoom
        b2 = zoom(b, la / lb)
        b = b2

    la = len(a)
    lb = len(b)

    ta = int(la // 2)
    tb = int(lb // 2)

    ca = a[ta]
    cb = b[tb]

    if ca > cb:
        swap = a
        a = b
        b = swap

    np_a = np.array(a)
    np_b = np.array(b)

    np_a_ex = append_label_column(np_a, 1)
    np_b_ex = append_label_column(np_b, 2)

    left = 4
    right = 3

    np_ab = np.vstack([np_a_ex, np_b_ex])
    np_ab = np_ab[np_ab[:, 0].argsort()]

    labels = np_ab[:,1]

    cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
    cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
    cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
    cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())

    np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])

    half = 0
    for row in np_ab_ex:
        rl = row[left]
        rr = row[right]
        if rl > rr:
            break
        half += 1

    #threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2

    fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
    fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]

    percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100

    return percent


def confusion_matrix2(rows, channel):
    import matplotlib.pyplot as plt

    x_labels = ["dots", "tracks", "worms", "artifacts"]
    y_labels = []

    matrix = np.zeros((len(rows), len(x_labels)), dtype=np.int32)

    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            set_name = x_labels[j]
            (fun_name, cutoff_background, normalize, similarity, threshold) = rows[i]

            la = channel
            lb = set_name

            if la == lb:
                continue

            a = similarity[la]
            b = similarity[lb]


            #threshold, percent = find_threshold(a, b)
            percent = find_percent(a, b, threshold)

            print('Channel %s, compare %s vs %s, threshold: %s, fp/fn percent: %s %%' % (la, la, lb, str(threshold), str(percent)))
            #plot_threshold(a, b, threshold, la, lb)

            matrix[i, j] = int(100 - percent)
        y_labels.append(rows[i][0])

    fig, ax = plt.subplots()
    im = ax.imshow(matrix)

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(x_labels)), labels=x_labels)
    ax.set_yticks(np.arange(len(y_labels)), labels=y_labels)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            text = ax.text(j, i, matrix[i, j], ha="center", va="center", color="w")

    ax.set_title("x - data set, y - compare method")
    fig.tight_layout()
    plt.show()

for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = config[(autoencoder, cutoff_background, normalize)]
            confusion_matrix2(rows, name)
# Out:
# Channel dots, compare dots vs tracks, threshold: -10.861665192717936, fp/fn percent: 4.72 %
# Channel dots, compare dots vs worms, threshold: -10.861665192717936, fp/fn percent: 2.9233870967741935 %
# Channel dots, compare dots vs artifacts, threshold: -10.861665192717936, fp/fn percent: 5.185758513931889 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.52 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.74596774193549 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 65.86687306501547 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 64.05333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.73790322580645 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 65.71207430340557 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.306666666666665 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 52.41935483870967 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 64.62848297213623 %
# Channel dots, compare dots vs tracks, threshold: 0.1111111111111111, fp/fn percent: 24.773333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.1111111111111111, fp/fn percent: 14.516129032258066 %
# Channel dots, compare dots vs artifacts, threshold: 0.1111111111111111, fp/fn percent: 20.278637770897834 %
# Channel dots, compare dots vs tracks, threshold: 0.32174400334600894, fp/fn percent: 24.959999999999997 %
# Channel dots, compare dots vs worms, threshold: 0.32174400334600894, fp/fn percent: 15.423387096774194 %
# Channel dots, compare dots vs artifacts, threshold: 0.32174400334600894, fp/fn percent: 21.28482972136223 %
# Channel dots, compare dots vs tracks, threshold: -6.602246142578583, fp/fn percent: 1.6533333333333333 %
# Channel dots, compare dots vs worms, threshold: -6.602246142578583, fp/fn percent: 1.2096774193548387 %
# Channel dots, compare dots vs artifacts, threshold: -6.602246142578583, fp/fn percent: 6.3467492260061915 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.49333333333334 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.846774193548384 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 65.86687306501547 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 64.02666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.73790322580645 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 65.71207430340557 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.22666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 52.318548387096776 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 64.55108359133128 %
# Channel dots, compare dots vs tracks, threshold: 11.999999999999964, fp/fn percent: 44.32 %
# Channel dots, compare dots vs worms, threshold: 11.999999999999964, fp/fn percent: 43.44758064516129 %
# Channel dots, compare dots vs artifacts, threshold: 11.999999999999964, fp/fn percent: 50.54179566563467 %
# Channel dots, compare dots vs tracks, threshold: 31.0, fp/fn percent: 31.306666666666665 %
# Channel dots, compare dots vs worms, threshold: 31.0, fp/fn percent: 30.34274193548387 %
# Channel dots, compare dots vs artifacts, threshold: 31.0, fp/fn percent: 38.69969040247678 %
# Channel dots, compare dots vs tracks, threshold: -10.656126844163772, fp/fn percent: 5.066666666666666 %
# Channel dots, compare dots vs worms, threshold: -10.656126844163772, fp/fn percent: 2.9233870967741935 %
# Channel dots, compare dots vs artifacts, threshold: -10.656126844163772, fp/fn percent: 5.263157894736842 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.54666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.94758064516129 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 54.4891640866873 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.65333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.53629032258065 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 54.25696594427245 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 64.05333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 52.11693548387096 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 53.94736842105263 %
# Channel dots, compare dots vs tracks, threshold: 0.12244897959183673, fp/fn percent: 24.37333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.12244897959183673, fp/fn percent: 14.919354838709678 %
# Channel dots, compare dots vs artifacts, threshold: 0.12244897959183673, fp/fn percent: 32.585139318885446 %
# Channel dots, compare dots vs tracks, threshold: 0.35001371353785904, fp/fn percent: 24.826666666666668 %
# Channel dots, compare dots vs worms, threshold: 0.35001371353785904, fp/fn percent: 15.524193548387096 %
# Channel dots, compare dots vs artifacts, threshold: 0.35001371353785904, fp/fn percent: 33.126934984520126 %
# Channel dots, compare dots vs tracks, threshold: -6.348389281639658, fp/fn percent: 1.4133333333333333 %
# Channel dots, compare dots vs worms, threshold: -6.348389281639658, fp/fn percent: 1.1088709677419355 %
# Channel dots, compare dots vs artifacts, threshold: -6.348389281639658, fp/fn percent: 6.191950464396285 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.54666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.74596774193549 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 54.41176470588235 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.6 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.53629032258065 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 54.179566563467496 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.973333333333336 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 52.016129032258064 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 53.86996904024768 %
# Channel dots, compare dots vs tracks, threshold: 12.0, fp/fn percent: 44.693333333333335 %
# Channel dots, compare dots vs worms, threshold: 12.0, fp/fn percent: 46.67338709677419 %
# Channel dots, compare dots vs artifacts, threshold: 12.0, fp/fn percent: 40.24767801857585 %
# Channel dots, compare dots vs tracks, threshold: 32.000000000044906, fp/fn percent: 31.013333333333332 %
# Channel dots, compare dots vs worms, threshold: 32.000000000044906, fp/fn percent: 29.334677419354836 %
# Channel dots, compare dots vs artifacts, threshold: 32.000000000044906, fp/fn percent: 27.167182662538696 %
# Channel worms, compare worms vs dots, threshold: -8.38495221794979, fp/fn percent: 17.641129032258064 %
# Channel worms, compare worms vs tracks, threshold: -8.38495221794979, fp/fn percent: 42.54032258064516 %
# Channel worms, compare worms vs artifacts, threshold: -8.38495221794979, fp/fn percent: 48.891129032258064 %
# Channel worms, compare worms vs dots, threshold: 0.000976501319364189, fp/fn percent: 15.020161290322582 %
# Channel worms, compare worms vs tracks, threshold: 0.000976501319364189, fp/fn percent: 33.770161290322584 %
# Channel worms, compare worms vs artifacts, threshold: 0.000976501319364189, fp/fn percent: 39.01209677419355 %
# Channel worms, compare worms vs dots, threshold: 0.010365225279967659, fp/fn percent: 21.27016129032258 %
# Channel worms, compare worms vs tracks, threshold: 0.010365225279967659, fp/fn percent: 51.20967741935484 %
# Channel worms, compare worms vs artifacts, threshold: 0.010365225279967659, fp/fn percent: 40.020161290322584 %
# Channel worms, compare worms vs dots, threshold: 0.002588900168720867, fp/fn percent: 18.548387096774192 %
# Channel worms, compare worms vs tracks, threshold: 0.002588900168720867, fp/fn percent: 52.318548387096776 %
# Channel worms, compare worms vs artifacts, threshold: 0.002588900168720867, fp/fn percent: 38.608870967741936 %
# Channel worms, compare worms vs dots, threshold: 0.03862542907458406, fp/fn percent: 18.75 %
# Channel worms, compare worms vs tracks, threshold: 0.03862542907458406, fp/fn percent: 32.15725806451613 %
# Channel worms, compare worms vs artifacts, threshold: 0.03862542907458406, fp/fn percent: 50.806451612903224 %
# Channel worms, compare worms vs dots, threshold: 0.129913316656734, fp/fn percent: 16.633064516129032 %
# Channel worms, compare worms vs tracks, threshold: 0.129913316656734, fp/fn percent: 27.82258064516129 %
# Channel worms, compare worms vs artifacts, threshold: 0.129913316656734, fp/fn percent: 52.21774193548387 %
# Channel worms, compare worms vs dots, threshold: -0.010223570975385761, fp/fn percent: 13.205645161290322 %
# Channel worms, compare worms vs tracks, threshold: -0.010223570975385761, fp/fn percent: 29.536290322580644 %
# Channel worms, compare worms vs artifacts, threshold: -0.010223570975385761, fp/fn percent: 49.79838709677419 %
# Channel worms, compare worms vs dots, threshold: 1.0, fp/fn percent: 22.983870967741936 %
# Channel worms, compare worms vs tracks, threshold: 1.0, fp/fn percent: 41.733870967741936 %
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 46.774193548387096 %
# Channel worms, compare worms vs dots, threshold: 8.0, fp/fn percent: 20.665322580645164 %
# Channel worms, compare worms vs tracks, threshold: 8.0, fp/fn percent: 45.86693548387097 %
# Channel worms, compare worms vs artifacts, threshold: 8.0, fp/fn percent: 43.54838709677419 %
# Channel worms, compare worms vs dots, threshold: 1.0, fp/fn percent: 19.35483870967742 %
# Channel worms, compare worms vs tracks, threshold: 1.0, fp/fn percent: 51.00806451612904 %
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 45.26209677419355 %
# Channel worms, compare worms vs dots, threshold: 12.000000000000004, fp/fn percent: 45.96774193548387 %
# Channel worms, compare worms vs tracks, threshold: 12.000000000000004, fp/fn percent: 48.79032258064516 %
# Channel worms, compare worms vs artifacts, threshold: 12.000000000000004, fp/fn percent: 46.16935483870967 %
# Channel worms, compare worms vs dots, threshold: 38.00000000000001, fp/fn percent: 29.73790322580645 %
# Channel worms, compare worms vs tracks, threshold: 38.00000000000001, fp/fn percent: 48.99193548387097 %
# Channel worms, compare worms vs artifacts, threshold: 38.00000000000001, fp/fn percent: 44.556451612903224 %
# Channel worms, compare worms vs dots, threshold: -8.354396613713446, fp/fn percent: 18.245967741935484 %
# Channel worms, compare worms vs tracks, threshold: -8.354396613713446, fp/fn percent: 43.04435483870967 %
# Channel worms, compare worms vs artifacts, threshold: -8.354396613713446, fp/fn percent: 48.38709677419355 %
# Channel worms, compare worms vs dots, threshold: 0.0013142422426817625, fp/fn percent: 16.129032258064516 %
# Channel worms, compare worms vs tracks, threshold: 0.0013142422426817625, fp/fn percent: 34.57661290322581 %
# Channel worms, compare worms vs artifacts, threshold: 0.0013142422426817625, fp/fn percent: 49.899193548387096 %
# Channel worms, compare worms vs dots, threshold: 0.011707957351330293, fp/fn percent: 22.58064516129032 %
# Channel worms, compare worms vs tracks, threshold: 0.011707957351330293, fp/fn percent: 49.899193548387096 %
# Channel worms, compare worms vs artifacts, threshold: 0.011707957351330293, fp/fn percent: 48.185483870967744 %
# Channel worms, compare worms vs dots, threshold: 0.0027700831024925696, fp/fn percent: 19.153225806451612 %
# Channel worms, compare worms vs tracks, threshold: 0.0027700831024925696, fp/fn percent: 52.721774193548384 %
# Channel worms, compare worms vs artifacts, threshold: 0.0027700831024925696, fp/fn percent: 50.50403225806451 %
# Channel worms, compare worms vs dots, threshold: 0.04000000000032816, fp/fn percent: 17.741935483870968 %
# Channel worms, compare worms vs tracks, threshold: 0.04000000000032816, fp/fn percent: 32.056451612903224 %
# Channel worms, compare worms vs artifacts, threshold: 0.04000000000032816, fp/fn percent: 37.600806451612904 %
# Channel worms, compare worms vs dots, threshold: 0.1379928664807157, fp/fn percent: 16.33064516129032 %
# Channel worms, compare worms vs tracks, threshold: 0.1379928664807157, fp/fn percent: 28.42741935483871 %
# Channel worms, compare worms vs artifacts, threshold: 0.1379928664807157, fp/fn percent: 36.59274193548387 %
# Channel worms, compare worms vs dots, threshold: -0.03931255653635607, fp/fn percent: 12.5 %
# Channel worms, compare worms vs tracks, threshold: -0.03931255653635607, fp/fn percent: 29.63709677419355 %
# Channel worms, compare worms vs artifacts, threshold: -0.03931255653635607, fp/fn percent: 38.40725806451613 %
# Channel worms, compare worms vs dots, threshold: 1.0, fp/fn percent: 22.58064516129032 %
# Channel worms, compare worms vs tracks, threshold: 1.0, fp/fn percent: 41.53225806451613 %
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 51.108870967741936 %
# Channel worms, compare worms vs dots, threshold: 8.0, fp/fn percent: 21.370967741935484 %
# Channel worms, compare worms vs tracks, threshold: 8.0, fp/fn percent: 46.57258064516129 %
# Channel worms, compare worms vs artifacts, threshold: 8.0, fp/fn percent: 47.983870967741936 %
# Channel worms, compare worms vs dots, threshold: 1.0, fp/fn percent: 19.657258064516128 %
# Channel worms, compare worms vs tracks, threshold: 1.0, fp/fn percent: 50.0 %
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 54.33467741935484 %
# Channel worms, compare worms vs dots, threshold: 12.99999999999048, fp/fn percent: 44.25403225806452 %
# Channel worms, compare worms vs tracks, threshold: 12.99999999999048, fp/fn percent: 50.0 %
# Channel worms, compare worms vs artifacts, threshold: 12.99999999999048, fp/fn percent: 44.65725806451613 %
# Channel worms, compare worms vs dots, threshold: 39.0, fp/fn percent: 28.931451612903224 %
# Channel worms, compare worms vs tracks, threshold: 39.0, fp/fn percent: 48.79032258064516 %
# Channel worms, compare worms vs artifacts, threshold: 39.0, fp/fn percent: 44.95967741935484 %
# Channel tracks, compare tracks vs dots, threshold: -9.054532697688085, fp/fn percent: 16.026666666666667 %
# Channel tracks, compare tracks vs worms, threshold: -9.054532697688085, fp/fn percent: 43.75 %
# Channel tracks, compare tracks vs artifacts, threshold: -9.054532697688085, fp/fn percent: 43.11145510835913 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 75.52 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 58.66935483870967 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 68.80804953560371 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 64.05333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 64.41532258064517 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 64.08668730650155 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 63.306666666666665 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 63.306451612903224 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 63.46749226006192 %
# Channel tracks, compare tracks vs dots, threshold: 0.0769236050239202, fp/fn percent: 26.346666666666668 %
# Channel tracks, compare tracks vs worms, threshold: 0.0769236050239202, fp/fn percent: 36.189516129032256 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0769236050239202, fp/fn percent: 41.640866873065015 %
# Channel tracks, compare tracks vs dots, threshold: 0.24342214531315798, fp/fn percent: 28.026666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.24342214531315798, fp/fn percent: 34.979838709677416 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.24342214531315798, fp/fn percent: 41.09907120743034 %
# Channel tracks, compare tracks vs dots, threshold: -1.4487669228993714, fp/fn percent: 16.506666666666668 %
# Channel tracks, compare tracks vs worms, threshold: -1.4487669228993714, fp/fn percent: 36.99596774193548 %
# Channel tracks, compare tracks vs artifacts, threshold: -1.4487669228993714, fp/fn percent: 42.10526315789473 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 75.49333333333334 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 58.66935483870967 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 68.80804953560371 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 64.02666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 57.25806451612904 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 64.00928792569658 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 63.22666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 55.443548387096776 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 63.39009287925697 %
# Channel tracks, compare tracks vs dots, threshold: 12.0, fp/fn percent: 44.346666666666664 %
# Channel tracks, compare tracks vs worms, threshold: 12.0, fp/fn percent: 49.69758064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: 12.0, fp/fn percent: 44.42724458204334 %
# Channel tracks, compare tracks vs dots, threshold: 35.0, fp/fn percent: 30.85333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 35.0, fp/fn percent: 49.49596774193548 %
# Channel tracks, compare tracks vs artifacts, threshold: 35.0, fp/fn percent: 44.50464396284829 %
# Channel tracks, compare tracks vs dots, threshold: -8.97322541513423, fp/fn percent: 17.146666666666665 %
# Channel tracks, compare tracks vs worms, threshold: -8.97322541513423, fp/fn percent: 43.44758064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: -8.97322541513423, fp/fn percent: 41.253869969040245 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 75.54666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 58.568548387096776 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 57.50773993808049 %
# Channel tracks, compare tracks vs dots, threshold: 2.2480924391974147e-181, fp/fn percent: 17.68 %
# Channel tracks, compare tracks vs worms, threshold: 2.2480924391974147e-181, fp/fn percent: 53.528225806451616 %
# Channel tracks, compare tracks vs artifacts, threshold: 2.2480924391974147e-181, fp/fn percent: 53.86996904024768 %
# Channel tracks, compare tracks vs dots, threshold: 7.58285966743426e-260, fp/fn percent: 15.040000000000001 %
# Channel tracks, compare tracks vs worms, threshold: 7.58285966743426e-260, fp/fn percent: 55.54435483870967 %
# Channel tracks, compare tracks vs artifacts, threshold: 7.58285966743426e-260, fp/fn percent: 46.51702786377709 %
# Channel tracks, compare tracks vs dots, threshold: 0.08333333333333333, fp/fn percent: 27.813333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 0.08333333333333333, fp/fn percent: 36.391129032258064 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.08333333333333333, fp/fn percent: 53.01857585139319 %
# Channel tracks, compare tracks vs dots, threshold: 0.25940136560042704, fp/fn percent: 27.946666666666665 %
# Channel tracks, compare tracks vs worms, threshold: 0.25940136560042704, fp/fn percent: 36.49193548387097 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.25940136560042704, fp/fn percent: 53.40557275541795 %
# Channel tracks, compare tracks vs dots, threshold: -1.6117604164342136, fp/fn percent: 14.346666666666666 %
# Channel tracks, compare tracks vs worms, threshold: -1.6117604164342136, fp/fn percent: 38.50806451612903 %
# Channel tracks, compare tracks vs artifacts, threshold: -1.6117604164342136, fp/fn percent: 54.79876160990712 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 75.54666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 58.568548387096776 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 57.43034055727554 %
# Channel tracks, compare tracks vs dots, threshold: 2.1303733604716366e-178, fp/fn percent: 17.68 %
# Channel tracks, compare tracks vs worms, threshold: 2.1303733604716366e-178, fp/fn percent: 46.471774193548384 %
# Channel tracks, compare tracks vs artifacts, threshold: 2.1303733604716366e-178, fp/fn percent: 46.13003095975232 %
# Channel tracks, compare tracks vs dots, threshold: 1.0698785150443634e-256, fp/fn percent: 15.040000000000001 %
# Channel tracks, compare tracks vs worms, threshold: 1.0698785150443634e-256, fp/fn percent: 44.45564516129033 %
# Channel tracks, compare tracks vs artifacts, threshold: 1.0698785150443634e-256, fp/fn percent: 46.51702786377709 %
# Channel tracks, compare tracks vs dots, threshold: 12.000000000000005, fp/fn percent: 44.0 %
# Channel tracks, compare tracks vs worms, threshold: 12.000000000000005, fp/fn percent: 49.49596774193548 %
# Channel tracks, compare tracks vs artifacts, threshold: 12.000000000000005, fp/fn percent: 44.50464396284829 %
# Channel tracks, compare tracks vs dots, threshold: 36.0, fp/fn percent: 31.119999999999997 %
# Channel tracks, compare tracks vs worms, threshold: 36.0, fp/fn percent: 49.09274193548387 %
# Channel tracks, compare tracks vs artifacts, threshold: 36.0, fp/fn percent: 56.5015479876161 %
# Channel artifacts, compare artifacts vs dots, threshold: -8.362975020639983, fp/fn percent: 16.873065015479877 %
# Channel artifacts, compare artifacts vs tracks, threshold: -8.362975020639983, fp/fn percent: 41.56346749226007 %
# Channel artifacts, compare artifacts vs worms, threshold: -8.362975020639983, fp/fn percent: 48.891129032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 65.86687306501547 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 68.80804953560371 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 51.91532258064516 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.4625416885288207e-171, fp/fn percent: 29.024767801857585 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.4625416885288207e-171, fp/fn percent: 43.034055727554176 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.4625416885288207e-171, fp/fn percent: 50.30241935483871 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.312399344357349e-29, fp/fn percent: 22.8328173374613 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.312399344357349e-29, fp/fn percent: 45.51083591331269 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.312399344357349e-29, fp/fn percent: 39.61693548387097 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0408281204910661, fp/fn percent: 19.5046439628483 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0408281204910661, fp/fn percent: 33.591331269349844 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0408281204910661, fp/fn percent: 50.806451612903224 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.1462731586035103, fp/fn percent: 18.653250773993808 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.1462731586035103, fp/fn percent: 31.73374613003096 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.1462731586035103, fp/fn percent: 53.125 %
# Channel artifacts, compare artifacts vs dots, threshold: -0.09557049321141121, fp/fn percent: 13.157894736842104 %
# Channel artifacts, compare artifacts vs tracks, threshold: -0.09557049321141121, fp/fn percent: 30.41795665634675 %
# Channel artifacts, compare artifacts vs worms, threshold: -0.09557049321141121, fp/fn percent: 49.193548387096776 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 65.86687306501547 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 68.80804953560371 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 51.91532258064516 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.139274942041033e-168, fp/fn percent: 29.024767801857585 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.139274942041033e-168, fp/fn percent: 43.034055727554176 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.139274942041033e-168, fp/fn percent: 50.403225806451616 %
# Channel artifacts, compare artifacts vs dots, threshold: 2.0507600489360758e-26, fp/fn percent: 22.8328173374613 %
# Channel artifacts, compare artifacts vs tracks, threshold: 2.0507600489360758e-26, fp/fn percent: 45.51083591331269 %
# Channel artifacts, compare artifacts vs worms, threshold: 2.0507600489360758e-26, fp/fn percent: 39.61693548387097 %
# Channel artifacts, compare artifacts vs dots, threshold: 11.000000000000002, fp/fn percent: 49.22600619195047 %
# Channel artifacts, compare artifacts vs tracks, threshold: 11.000000000000002, fp/fn percent: 43.42105263157895 %
# Channel artifacts, compare artifacts vs worms, threshold: 11.000000000000002, fp/fn percent: 45.16129032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 35.0, fp/fn percent: 36.37770897832817 %
# Channel artifacts, compare artifacts vs tracks, threshold: 35.0, fp/fn percent: 44.50464396284829 %
# Channel artifacts, compare artifacts vs worms, threshold: 35.0, fp/fn percent: 43.649193548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: -8.312260556935612, fp/fn percent: 16.95046439628483 %
# Channel artifacts, compare artifacts vs tracks, threshold: -8.312260556935612, fp/fn percent: 41.408668730650156 %
# Channel artifacts, compare artifacts vs worms, threshold: -8.312260556935612, fp/fn percent: 48.58870967741936 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0011800358809907745, fp/fn percent: 15.634674922600619 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0011800358809907745, fp/fn percent: 34.28792569659443 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0011800358809907745, fp/fn percent: 50.201612903225815 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.012646707908282272, fp/fn percent: 21.671826625387 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.012646707908282272, fp/fn percent: 51.23839009287926 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.012646707908282272, fp/fn percent: 47.88306451612903 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0025507121044211043, fp/fn percent: 19.11764705882353 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0025507121044211043, fp/fn percent: 47.523219814241486 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0025507121044211043, fp/fn percent: 51.108870967741936 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.07143578750895119, fp/fn percent: 29.411764705882355 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.07143578750895119, fp/fn percent: 51.08359133126935 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.07143578750895119, fp/fn percent: 34.979838709677416 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.23125811505168825, fp/fn percent: 29.79876160990712 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.23125811505168825, fp/fn percent: 50.92879256965944 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.23125811505168825, fp/fn percent: 33.46774193548387 %
# Channel artifacts, compare artifacts vs dots, threshold: -1.0329599552714321, fp/fn percent: 20.6656346749226 %
# Channel artifacts, compare artifacts vs tracks, threshold: -1.0329599552714321, fp/fn percent: 49.922600619195045 %
# Channel artifacts, compare artifacts vs worms, threshold: -1.0329599552714321, fp/fn percent: 34.375 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.0, fp/fn percent: 17.569659442724458 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.0, fp/fn percent: 36.37770897832817 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.0, fp/fn percent: 51.108870967741936 %
# Channel artifacts, compare artifacts vs dots, threshold: 11.999999999999208, fp/fn percent: 16.486068111455108 %
# Channel artifacts, compare artifacts vs tracks, threshold: 11.999999999999208, fp/fn percent: 37.77089783281733 %
# Channel artifacts, compare artifacts vs worms, threshold: 11.999999999999208, fp/fn percent: 45.16129032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.0, fp/fn percent: 16.09907120743034 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.0, fp/fn percent: 46.90402476780186 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.0, fp/fn percent: 56.1491935483871 %
# Channel artifacts, compare artifacts vs dots, threshold: 14.0, fp/fn percent: 39.78328173374613 %
# Channel artifacts, compare artifacts vs tracks, threshold: 14.0, fp/fn percent: 45.04643962848297 %
# Channel artifacts, compare artifacts vs worms, threshold: 14.0, fp/fn percent: 44.95967741935484 %
# Channel artifacts, compare artifacts vs dots, threshold: 36.0, fp/fn percent: 35.9907120743034 %
# Channel artifacts, compare artifacts vs tracks, threshold: 36.0, fp/fn percent: 56.5015479876161 %
# Channel artifacts, compare artifacts vs worms, threshold: 36.0, fp/fn percent: 53.72983870967742 %
