# %%
import numpy as np

from commons import *
from dataset_loader import load_images, prepare_dataset
from IPython.display import display
import cv2
import pickle
import matplotlib.pyplot as plt
from keras.models import load_model


# TODO: https://pl.wikipedia.org/wiki/Dywergencja_Kullbacka-Leiblera
# https://towardsdatascience.com/kl-divergence-python-example-b87069e4b810
# TODO: entropia wzajemna, cross entropy


DOTS_SRC = 'hit-images-final2/dot'
TRACKS_SRC = 'hit-images-final2/line'
WORMS_SRC = 'hit-images-final2/worms'
ARTIFACTS_SRC = 'hit-images-final2/artefact'

DOTS_AC = 'cache/dots_100000.h5'
TRACKS_AC = 'cache/tracks_100000.h5'
WORMS_AC = 'cache/worms_100000.h5'
ARTIFACTS_AC = 'cache/artifacts_100000.h5'



dots_set =  prepare_dataset(load_images(DOTS_SRC))
worms_set =  prepare_dataset(load_images(WORMS_SRC))
tracks_set =  prepare_dataset(load_images(TRACKS_SRC))
artifacts_set =  prepare_dataset(load_images(ARTIFACTS_SRC))

dots_autoencoder = load_model(DOTS_AC)
worms_autoencoder = load_model(WORMS_AC)
tracks_autoencoder = load_model(TRACKS_AC)
artifacts_autoencoder = load_model(ARTIFACTS_AC)

# %%
# def find_threshold(sa, sb):
#     a = sorted(sa)
#     b = sorted(sb)
#
#     la = len(a)
#     lb = len(b)
#
#     if la > lb:
#         from scipy.ndimage import zoom
#         a2 = zoom(a, lb / la)
#         a = a2
#     elif la < lb:
#         from scipy.ndimage import zoom
#         b2 = zoom(b, la / lb)
#         b = b2
#
#     la = len(a)
#     lb = len(b)
#
#     ta = int(la // 2)
#     tb = int(lb // 2)
#
#     ca = a[ta]
#     cb = b[tb]
#
#     if ca > cb:
#         swap = a
#         a = b
#         b = swap
#
#     np_a = np.array(a)
#     np_b = np.array(b)
#
#     np_a_ex = append_label_column(np_a, 1)
#     np_b_ex = append_label_column(np_b, 2)
#
#     left = 4
#     right = 3
#
#     np_ab = np.vstack([np_a_ex, np_b_ex])
#     np_ab = np_ab[np_ab[:, 0].argsort()]
#
#     labels = np_ab[:,1]
#
#     cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
#     cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
#     cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
#     cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())
#
#     np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])
#
#     half = 0
#     for row in np_ab_ex:
#         rl = row[left]
#         rr = row[right]
#         if rl > rr:
#             break
#         half += 1
#
#     threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2
#
#     fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
#     fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]
#
#     percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100
#
#     return threshold, percent
#

config = {}

dm_funcs = [dm_func_mean2, dm_func_avg_hash, dm_func_p_hash, dm_func_d_hash, dm_func_haar_hash, dm_func_db4_hash] #  , dm_func_cr_hash, dm_func_color_hash
#dm_funcs = [dm_func_mean2]
cutoff_backgrounds = [True, False]
normalizes = [True, False]
autoencoders = [
    (dots_autoencoder, 'dots', dots_set),
    (worms_autoencoder, 'worms', worms_set),
    (tracks_autoencoder, 'tracks', tracks_set),
    (artifacts_autoencoder, 'artifacts', artifacts_set)
]

#calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, normalize=True, cutoff_background=False)
#trained_set = calculated['dots']
#other_set = np.hstack([calculated['worms'], calculated['tracks'], calculated['artifacts']])




for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = []
            for dm_func in dm_funcs:
                print('====| dm_func = %s, cutoff_background = %s, normalize = %s |====' % (str(dm_func.__name__), str(cutoff_background), str(normalize)))
                argv = {'cutoff_background': cutoff_background, 'normalize': normalize, 'dm_func': dm_func}

                #dots_reconstruction = autoencoder.predict(dots_set) if name != 'dots' else []
                #worms_reconstruction = autoencoder.predict(worms_set) if name != 'worms' else []
                #tracks_reconstruction = autoencoder.predict(tracks_set) if name != 'tracks' else []
                #artifacts_reconstruction = autoencoder.predict(artifacts_set) if name != 'artifacts' else []

                #others = np.vstack([dots_reconstruction, worms_reconstruction, tracks_reconstruction, artifacts_reconstruction])

                #prepare_for_histogram(trained_set, others, dm_func, **argv)

                calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv)

                trained_set = calculated[name]
                other_set = []
                for sn in calculated.keys():
                    if sn != name:
                        other_set.append(calculated[sn])
                other_set = np.hstack(other_set)

                threshold, percent = find_threshold(trained_set, other_set)
                plot_threshold(trained_set, other_set, threshold, 'dots', 'others')

                print('Channel %s, threshold: %f, percent: %f' % (name, threshold, percent))

                rows.append((dm_func.__name__, str(cutoff_background), str(normalize), calculated, threshold))
            config[(autoencoder, cutoff_background, normalize)] = rows
# Out:
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel dots, threshold: -11.482073, percent: 3.626667
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 73.973333
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 65.386667
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 61.360000
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.120000, percent: 22.800000
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel dots, threshold: 0.331522, percent: 23.813333
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel dots, threshold: -6.759112, percent: 2.213333
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 73.866667
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 65.333333
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 61.306667
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 12.000000, percent: 44.586667
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel dots, threshold: 31.000000, percent: 31.360000
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel dots, threshold: -11.350298, percent: 3.466667
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 73.893333
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 63.546667
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.000000, percent: 61.600000
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.123967, percent: 25.146667
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel dots, threshold: 0.358021, percent: 24.586667
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel dots, threshold: -7.105503, percent: 5.200000
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 73.840000
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 63.493333
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 0.000000, percent: 61.573333
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 12.000000, percent: 44.053333
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel dots, threshold: 32.000000, percent: 31.200000
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel worms, threshold: -8.429603, percent: 37.903226
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.000625, percent: 28.326613
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.009163, percent: 39.213710
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.003333, percent: 39.012097
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.039970, percent: 29.032258
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel worms, threshold: 0.133071, percent: 26.411290
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel worms, threshold: -0.033912, percent: 28.024194
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 1.000000, percent: 28.024194
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 8.000000, percent: 38.608871
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 1.000000, percent: 32.157258
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 12.496562, percent: 47.278226
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel worms, threshold: 39.000000, percent: 41.633065
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel worms, threshold: -8.354807, percent: 37.802419
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.000692, percent: 28.024194
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.010997, percent: 41.129032
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.003333, percent: 38.306452
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.043084, percent: 28.830645
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel worms, threshold: 0.149394, percent: 26.915323
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel worms, threshold: -0.069911, percent: 26.411290
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 1.000000, percent: 35.987903
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 8.000000, percent: 38.810484
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 1.000000, percent: 32.560484
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 13.000000, percent: 46.270161
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel worms, threshold: 39.000000, percent: 41.431452
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: -9.058487, percent: 29.333775
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 75.538615
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 63.954259
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 27.113026
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.080000, percent: 39.410010
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel tracks, threshold: 0.250000, percent: 41.017567
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: -1.393644, percent: 32.217435
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 75.472324
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 63.921114
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 27.113026
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 12.000000, percent: 45.608220
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel tracks, threshold: 35.000000, percent: 37.056679
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: -9.010026, percent: 29.466357
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 75.555187
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 31.289360
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.000000, percent: 26.980444
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.086420, percent: 37.321843
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel tracks, threshold: 0.270814, percent: 36.741796
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: -1.520479, percent: 28.173682
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 75.505469
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 31.289360
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 0.000000, percent: 26.980444
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 12.000000, percent: 43.221743
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel tracks, threshold: 35.000000, percent: 37.006961
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: -8.372201, percent: 36.068111
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000000, percent: 71.517028
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.000000, percent: 47.910217
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.001616, percent: 46.439628
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.041471, percent: 30.650155
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# Channel artifacts, threshold: 0.149245, percent: 29.179567
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: -0.143369, percent: 28.869969
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 0.000000, percent: 71.517028
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 0.000000, percent: 47.910217
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 1.000000, percent: 47.600619
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 12.000000, percent: 47.058824
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# Channel artifacts, threshold: 35.000000, percent: 49.148607
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: -8.349443, percent: 38.390093
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.000000, percent: 71.362229
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.011834, percent: 39.241486
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.001600, percent: 46.594427
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.077843, percent: 46.052632
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# Channel artifacts, threshold: 0.238990, percent: 44.891641
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: -0.926874, percent: 41.253870
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 0.000000, percent: 71.362229
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 10.000000, percent: 33.049536
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 1.000000, percent: 47.291022
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 12.000000, percent: 46.904025
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# Channel artifacts, threshold: 35.000000, percent: 50.154799

# %%
def find_percent(sa, sb, threshold):
    a = sorted(sa)
    b = sorted(sb)

    la = len(a)
    lb = len(b)

    if la > lb:
        from scipy.ndimage import zoom
        a2 = zoom(a, lb / la)
        a = a2
    elif la < lb:
        from scipy.ndimage import zoom
        b2 = zoom(b, la / lb)
        b = b2

    la = len(a)
    lb = len(b)

    ta = int(la // 2)
    tb = int(lb // 2)

    ca = a[ta]
    cb = b[tb]

    if ca > cb:
        swap = a
        a = b
        b = swap

    np_a = np.array(a)
    np_b = np.array(b)

    np_a_ex = append_label_column(np_a, 1)
    np_b_ex = append_label_column(np_b, 2)

    left = 4
    right = 3

    np_ab = np.vstack([np_a_ex, np_b_ex])
    np_ab = np_ab[np_ab[:, 0].argsort()]

    labels = np_ab[:,1]

    cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
    cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
    cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
    cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())

    np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])

    half = 0
    for row in np_ab_ex:
        rl = row[left]
        rr = row[right]
        if rl > rr:
            break
        half += 1

    #threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2

    fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
    fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]

    percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100

    return percent


def confusion_matrix2(rows, channel):
    import matplotlib.pyplot as plt

    x_labels = ["dots", "tracks", "worms", "artifacts"]
    y_labels = []

    matrix = np.zeros((len(rows), len(x_labels)), dtype=np.int32)

    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            set_name = x_labels[j]
            (fun_name, cutoff_background, normalize, similarity, threshold) = rows[i]

            la = channel
            lb = set_name

            if la == lb:
                continue

            a = similarity[la]
            b = similarity[lb]


            #threshold, percent = find_threshold(a, b)
            percent = find_percent(a, b, threshold)

            print('Channel %s, compare %s vs %s, threshold: %s, fp/fn percent: %s %%' % (la, la, lb, str(threshold), str(percent)))
            #plot_threshold(a, b, threshold, la, lb)

            matrix[i, j] = int(100 - percent)
        y_labels.append(rows[i][0])

    fig, ax = plt.subplots()
    im = ax.imshow(matrix)

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(x_labels)), labels=x_labels)
    ax.set_yticks(np.arange(len(y_labels)), labels=y_labels)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            text = ax.text(j, i, matrix[i, j], ha="center", va="center", color="w")

    ax.set_title("x - data set, y - compare method")
    fig.tight_layout()
    plt.show()

for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = config[(autoencoder, cutoff_background, normalize)]
            confusion_matrix2(rows, name)
# Out:
# Channel dots, compare dots vs tracks, threshold: -11.482073417728305, fp/fn percent: 3.6533333333333333 %
# Channel dots, compare dots vs worms, threshold: -11.482073417728305, fp/fn percent: 2.620967741935484 %
# Channel dots, compare dots vs artifacts, threshold: -11.482073417728305, fp/fn percent: 4.411764705882353 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.49333333333334 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 56.451612903225815 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 66.48606811145511 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.946666666666665 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.34274193548387 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 66.48606811145511 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 60.10666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 50.30241935483871 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 62.07430340557275 %
# Channel dots, compare dots vs tracks, threshold: 0.12, fp/fn percent: 24.213333333333335 %
# Channel dots, compare dots vs worms, threshold: 0.12, fp/fn percent: 14.818548387096776 %
# Channel dots, compare dots vs artifacts, threshold: 0.12, fp/fn percent: 21.207430340557277 %
# Channel dots, compare dots vs tracks, threshold: 0.33152189304574053, fp/fn percent: 25.52 %
# Channel dots, compare dots vs worms, threshold: 0.33152189304574053, fp/fn percent: 15.725806451612904 %
# Channel dots, compare dots vs artifacts, threshold: 0.33152189304574053, fp/fn percent: 21.826625386996902 %
# Channel dots, compare dots vs tracks, threshold: -6.7591119199373555, fp/fn percent: 1.6266666666666665 %
# Channel dots, compare dots vs worms, threshold: -6.7591119199373555, fp/fn percent: 1.1088709677419355 %
# Channel dots, compare dots vs artifacts, threshold: -6.7591119199373555, fp/fn percent: 5.88235294117647 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.41333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 56.55241935483871 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 66.48606811145511 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.89333333333334 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.34274193548387 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 66.48606811145511 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 60.026666666666664 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 50.30241935483871 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 61.99690402476781 %
# Channel dots, compare dots vs tracks, threshold: 12.0, fp/fn percent: 44.10666666666667 %
# Channel dots, compare dots vs worms, threshold: 12.0, fp/fn percent: 45.26209677419355 %
# Channel dots, compare dots vs artifacts, threshold: 12.0, fp/fn percent: 51.702786377708975 %
# Channel dots, compare dots vs tracks, threshold: 31.00000000202183, fp/fn percent: 30.240000000000002 %
# Channel dots, compare dots vs worms, threshold: 31.00000000202183, fp/fn percent: 30.64516129032258 %
# Channel dots, compare dots vs artifacts, threshold: 31.00000000202183, fp/fn percent: 37.84829721362229 %
# Channel dots, compare dots vs tracks, threshold: -11.350298360711792, fp/fn percent: 3.546666666666667 %
# Channel dots, compare dots vs worms, threshold: -11.350298360711792, fp/fn percent: 2.4193548387096775 %
# Channel dots, compare dots vs artifacts, threshold: -11.350298360711792, fp/fn percent: 4.102167182662539 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.52 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 56.25 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 66.3312693498452 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.839999999999996 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.73790322580645 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 55.10835913312694 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 60.45333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 50.30241935483871 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 62.38390092879257 %
# Channel dots, compare dots vs tracks, threshold: 0.12396694036675215, fp/fn percent: 24.85333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.12396694036675215, fp/fn percent: 16.028225806451612 %
# Channel dots, compare dots vs artifacts, threshold: 0.12396694036675215, fp/fn percent: 33.28173374613003 %
# Channel dots, compare dots vs tracks, threshold: 0.35802073251804045, fp/fn percent: 24.426666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.35802073251804045, fp/fn percent: 15.221774193548388 %
# Channel dots, compare dots vs artifacts, threshold: 0.35802073251804045, fp/fn percent: 32.6625386996904 %
# Channel dots, compare dots vs tracks, threshold: -7.1055033642548295, fp/fn percent: 2.9066666666666667 %
# Channel dots, compare dots vs worms, threshold: -7.1055033642548295, fp/fn percent: 2.620967741935484 %
# Channel dots, compare dots vs artifacts, threshold: -7.1055033642548295, fp/fn percent: 18.03405572755418 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 75.44 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 56.3508064516129 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 66.3312693498452 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 63.81333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.73790322580645 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 55.10835913312694 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 60.42666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 50.30241935483871 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 62.306501547987615 %
# Channel dots, compare dots vs tracks, threshold: 12.0, fp/fn percent: 43.76 %
# Channel dots, compare dots vs worms, threshold: 12.0, fp/fn percent: 42.439516129032256 %
# Channel dots, compare dots vs artifacts, threshold: 12.0, fp/fn percent: 51.857585139318886 %
# Channel dots, compare dots vs tracks, threshold: 32.0, fp/fn percent: 30.906666666666666 %
# Channel dots, compare dots vs worms, threshold: 32.0, fp/fn percent: 28.931451612903224 %
# Channel dots, compare dots vs artifacts, threshold: 32.0, fp/fn percent: 38.0030959752322 %
# Channel worms, compare worms vs dots, threshold: -8.429602876436217, fp/fn percent: 18.951612903225808 %
# Channel worms, compare worms vs tracks, threshold: -8.429602876436217, fp/fn percent: 46.67338709677419 %
# Channel worms, compare worms vs artifacts, threshold: -8.429602876436217, fp/fn percent: 48.48790322580645 %
# Channel worms, compare worms vs dots, threshold: 0.000625, fp/fn percent: 15.020161290322582 %
# Channel worms, compare worms vs tracks, threshold: 0.000625, fp/fn percent: 34.17338709677419 %
# Channel worms, compare worms vs artifacts, threshold: 0.000625, fp/fn percent: 39.11290322580645 %
# Channel worms, compare worms vs dots, threshold: 0.009162848812994586, fp/fn percent: 21.774193548387096 %
# Channel worms, compare worms vs tracks, threshold: 0.009162848812994586, fp/fn percent: 50.70564516129033 %
# Channel worms, compare worms vs artifacts, threshold: 0.009162848812994586, fp/fn percent: 40.625 %
# Channel worms, compare worms vs dots, threshold: 0.0033333333333333335, fp/fn percent: 19.858870967741936 %
# Channel worms, compare worms vs tracks, threshold: 0.0033333333333333335, fp/fn percent: 50.1008064516129 %
# Channel worms, compare worms vs artifacts, threshold: 0.0033333333333333335, fp/fn percent: 39.71774193548387 %
# Channel worms, compare worms vs dots, threshold: 0.03996996020025054, fp/fn percent: 18.04435483870968 %
# Channel worms, compare worms vs tracks, threshold: 0.03996996020025054, fp/fn percent: 31.653225806451612 %
# Channel worms, compare worms vs artifacts, threshold: 0.03996996020025054, fp/fn percent: 50.90725806451613 %
# Channel worms, compare worms vs dots, threshold: 0.13307107178010524, fp/fn percent: 16.129032258064516 %
# Channel worms, compare worms vs tracks, threshold: 0.13307107178010524, fp/fn percent: 28.326612903225808 %
# Channel worms, compare worms vs artifacts, threshold: 0.13307107178010524, fp/fn percent: 52.318548387096776 %
# Channel worms, compare worms vs dots, threshold: -0.03391171354567522, fp/fn percent: 14.012096774193546 %
# Channel worms, compare worms vs tracks, threshold: -0.03391171354567522, fp/fn percent: 32.25806451612903 %
# Channel worms, compare worms vs artifacts, threshold: -0.03391171354567522, fp/fn percent: 48.79032258064516 %
# Channel worms, compare worms vs dots, threshold: 0.9999999999999999, fp/fn percent: 14.717741935483872 %
# Channel worms, compare worms vs tracks, threshold: 0.9999999999999999, fp/fn percent: 33.46774193548387 %
# Channel worms, compare worms vs artifacts, threshold: 0.9999999999999999, fp/fn percent: 38.00403225806452 %
# Channel worms, compare worms vs dots, threshold: 8.0, fp/fn percent: 22.076612903225808 %
# Channel worms, compare worms vs tracks, threshold: 8.0, fp/fn percent: 47.37903225806452 %
# Channel worms, compare worms vs artifacts, threshold: 8.0, fp/fn percent: 43.649193548387096 %
# Channel worms, compare worms vs dots, threshold: 1.0000000000000002, fp/fn percent: 15.221774193548388 %
# Channel worms, compare worms vs tracks, threshold: 1.0000000000000002, fp/fn percent: 40.725806451612904 %
# Channel worms, compare worms vs artifacts, threshold: 1.0000000000000002, fp/fn percent: 43.145161290322584 %
# Channel worms, compare worms vs dots, threshold: 12.496562034296574, fp/fn percent: 43.346774193548384 %
# Channel worms, compare worms vs tracks, threshold: 12.496562034296574, fp/fn percent: 49.899193548387096 %
# Channel worms, compare worms vs artifacts, threshold: 12.496562034296574, fp/fn percent: 45.16129032258064 %
# Channel worms, compare worms vs dots, threshold: 38.99999990273399, fp/fn percent: 28.62903225806452 %
# Channel worms, compare worms vs tracks, threshold: 38.99999990273399, fp/fn percent: 49.193548387096776 %
# Channel worms, compare worms vs artifacts, threshold: 38.99999990273399, fp/fn percent: 44.45564516129033 %
# Channel worms, compare worms vs dots, threshold: -8.354807085079827, fp/fn percent: 18.951612903225808 %
# Channel worms, compare worms vs tracks, threshold: -8.354807085079827, fp/fn percent: 46.471774193548384 %
# Channel worms, compare worms vs artifacts, threshold: -8.354807085079827, fp/fn percent: 51.51209677419355 %
# Channel worms, compare worms vs dots, threshold: 0.0006915453266702067, fp/fn percent: 14.818548387096776 %
# Channel worms, compare worms vs tracks, threshold: 0.0006915453266702067, fp/fn percent: 33.87096774193548 %
# Channel worms, compare worms vs artifacts, threshold: 0.0006915453266702067, fp/fn percent: 39.21370967741936 %
# Channel worms, compare worms vs dots, threshold: 0.01099661032320965, fp/fn percent: 22.883064516129032 %
# Channel worms, compare worms vs tracks, threshold: 0.01099661032320965, fp/fn percent: 50.0 %
# Channel worms, compare worms vs artifacts, threshold: 0.01099661032320965, fp/fn percent: 48.48790322580645 %
# Channel worms, compare worms vs dots, threshold: 0.003332639178120228, fp/fn percent: 19.35483870967742 %
# Channel worms, compare worms vs tracks, threshold: 0.003332639178120228, fp/fn percent: 50.30241935483871 %
# Channel worms, compare worms vs artifacts, threshold: 0.003332639178120228, fp/fn percent: 39.516129032258064 %
# Channel worms, compare worms vs dots, threshold: 0.04308390022675737, fp/fn percent: 19.052419354838708 %
# Channel worms, compare worms vs tracks, threshold: 0.04308390022675737, fp/fn percent: 32.66129032258064 %
# Channel worms, compare worms vs artifacts, threshold: 0.04308390022675737, fp/fn percent: 38.40725806451613 %
# Channel worms, compare worms vs dots, threshold: 0.14939446366782005, fp/fn percent: 16.834677419354836 %
# Channel worms, compare worms vs tracks, threshold: 0.14939446366782005, fp/fn percent: 30.74596774193548 %
# Channel worms, compare worms vs artifacts, threshold: 0.14939446366782005, fp/fn percent: 37.600806451612904 %
# Channel worms, compare worms vs dots, threshold: -0.06991073709980984, fp/fn percent: 13.205645161290322 %
# Channel worms, compare worms vs tracks, threshold: -0.06991073709980984, fp/fn percent: 32.15725806451613 %
# Channel worms, compare worms vs artifacts, threshold: -0.06991073709980984, fp/fn percent: 37.903225806451616 %
# Channel worms, compare worms vs dots, threshold: 1.0, fp/fn percent: 22.883064516129032 %
# Channel worms, compare worms vs tracks, threshold: 1.0, fp/fn percent: 41.733870967741936 %
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 46.16935483870967 %
# Channel worms, compare worms vs dots, threshold: 8.0, fp/fn percent: 21.068548387096776 %
# Channel worms, compare worms vs tracks, threshold: 8.0, fp/fn percent: 45.96774193548387 %
# Channel worms, compare worms vs artifacts, threshold: 8.0, fp/fn percent: 48.28629032258064 %
# Channel worms, compare worms vs dots, threshold: 1.0000000000000002, fp/fn percent: 15.826612903225806 %
# Channel worms, compare worms vs tracks, threshold: 1.0000000000000002, fp/fn percent: 41.33064516129033 %
# Channel worms, compare worms vs artifacts, threshold: 1.0000000000000002, fp/fn percent: 43.649193548387096 %
# Channel worms, compare worms vs dots, threshold: 13.000000000000002, fp/fn percent: 41.229838709677416 %
# Channel worms, compare worms vs tracks, threshold: 13.000000000000002, fp/fn percent: 49.395161290322584 %
# Channel worms, compare worms vs artifacts, threshold: 13.000000000000002, fp/fn percent: 44.153225806451616 %
# Channel worms, compare worms vs dots, threshold: 39.0, fp/fn percent: 28.62903225806452 %
# Channel worms, compare worms vs tracks, threshold: 39.0, fp/fn percent: 48.689516129032256 %
# Channel worms, compare worms vs artifacts, threshold: 39.0, fp/fn percent: 44.25403225806452 %
# Channel tracks, compare tracks vs dots, threshold: -9.058486719783282, fp/fn percent: 14.666666666666666 %
# Channel tracks, compare tracks vs worms, threshold: -9.058486719783282, fp/fn percent: 46.975806451612904 %
# Channel tracks, compare tracks vs artifacts, threshold: -9.058486719783282, fp/fn percent: 46.20743034055727 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 75.49333333333334 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 59.4758064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 69.42724458204334 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 63.946666666666665 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 63.70967741935484 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 64.00928792569658 %
# Channel tracks, compare tracks vs dots, threshold: 4.738995434321696e-84, fp/fn percent: 13.706666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 4.738995434321696e-84, fp/fn percent: 55.74596774193549 %
# Channel tracks, compare tracks vs artifacts, threshold: 4.738995434321696e-84, fp/fn percent: 44.11764705882353 %
# Channel tracks, compare tracks vs dots, threshold: 0.07999999981584258, fp/fn percent: 26.640000000000004 %
# Channel tracks, compare tracks vs worms, threshold: 0.07999999981584258, fp/fn percent: 36.693548387096776 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.07999999981584258, fp/fn percent: 41.795665634674926 %
# Channel tracks, compare tracks vs dots, threshold: 0.25, fp/fn percent: 28.720000000000002 %
# Channel tracks, compare tracks vs worms, threshold: 0.25, fp/fn percent: 35.78629032258064 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.25, fp/fn percent: 41.253869969040245 %
# Channel tracks, compare tracks vs dots, threshold: -1.3936442931621205, fp/fn percent: 16.106666666666666 %
# Channel tracks, compare tracks vs worms, threshold: -1.3936442931621205, fp/fn percent: 39.21370967741936 %
# Channel tracks, compare tracks vs artifacts, threshold: -1.3936442931621205, fp/fn percent: 42.95665634674923 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 75.41333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 59.4758064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 69.3498452012384 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 63.89333333333334 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 58.36693548387096 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 63.93188854489165 %
# Channel tracks, compare tracks vs dots, threshold: 6.806204041924719e-81, fp/fn percent: 13.706666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 6.806204041924719e-81, fp/fn percent: 44.25403225806452 %
# Channel tracks, compare tracks vs artifacts, threshold: 6.806204041924719e-81, fp/fn percent: 55.88235294117647 %
# Channel tracks, compare tracks vs dots, threshold: 12.0, fp/fn percent: 44.10666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 12.0, fp/fn percent: 51.81451612903226 %
# Channel tracks, compare tracks vs artifacts, threshold: 12.0, fp/fn percent: 45.27863777089783 %
# Channel tracks, compare tracks vs dots, threshold: 35.0, fp/fn percent: 30.85333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 35.0, fp/fn percent: 50.201612903225815 %
# Channel tracks, compare tracks vs artifacts, threshold: 35.0, fp/fn percent: 44.42724458204334 %
# Channel tracks, compare tracks vs dots, threshold: -9.010026407949468, fp/fn percent: 14.746666666666666 %
# Channel tracks, compare tracks vs worms, threshold: -9.010026407949468, fp/fn percent: 47.17741935483871 %
# Channel tracks, compare tracks vs artifacts, threshold: -9.010026407949468, fp/fn percent: 54.33436532507739 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 75.52 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 59.173387096774185 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 69.27244582043343 %
# Channel tracks, compare tracks vs dots, threshold: 1.7739955249027424e-197, fp/fn percent: 17.973333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 1.7739955249027424e-197, fp/fn percent: 53.2258064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: 1.7739955249027424e-197, fp/fn percent: 53.1733746130031 %
# Channel tracks, compare tracks vs dots, threshold: 2.887585901385724e-113, fp/fn percent: 13.626666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 2.887585901385724e-113, fp/fn percent: 55.64516129032258 %
# Channel tracks, compare tracks vs artifacts, threshold: 2.887585901385724e-113, fp/fn percent: 43.73065015479876 %
# Channel tracks, compare tracks vs dots, threshold: 0.08641975308641975, fp/fn percent: 27.68 %
# Channel tracks, compare tracks vs worms, threshold: 0.08641975308641975, fp/fn percent: 38.104838709677416 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.08641975308641975, fp/fn percent: 53.71517027863777 %
# Channel tracks, compare tracks vs dots, threshold: 0.27081374222383015, fp/fn percent: 26.453333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 0.27081374222383015, fp/fn percent: 37.19758064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.27081374222383015, fp/fn percent: 53.32817337461301 %
# Channel tracks, compare tracks vs dots, threshold: -1.520479450018065, fp/fn percent: 14.08 %
# Channel tracks, compare tracks vs worms, threshold: -1.520479450018065, fp/fn percent: 40.42338709677419 %
# Channel tracks, compare tracks vs artifacts, threshold: -1.520479450018065, fp/fn percent: 55.030959752321984 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 75.44 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 59.173387096774185 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 69.19504643962848 %
# Channel tracks, compare tracks vs dots, threshold: 1.6799255524390675e-194, fp/fn percent: 17.973333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 1.6799255524390675e-194, fp/fn percent: 46.774193548387096 %
# Channel tracks, compare tracks vs artifacts, threshold: 1.6799255524390675e-194, fp/fn percent: 46.82662538699691 %
# Channel tracks, compare tracks vs dots, threshold: 4.1471866993324853e-110, fp/fn percent: 13.626666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 4.1471866993324853e-110, fp/fn percent: 44.354838709677416 %
# Channel tracks, compare tracks vs artifacts, threshold: 4.1471866993324853e-110, fp/fn percent: 56.26934984520123 %
# Channel tracks, compare tracks vs dots, threshold: 12.000000000000002, fp/fn percent: 41.06666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 12.000000000000002, fp/fn percent: 49.395161290322584 %
# Channel tracks, compare tracks vs artifacts, threshold: 12.000000000000002, fp/fn percent: 43.42105263157895 %
# Channel tracks, compare tracks vs dots, threshold: 35.0, fp/fn percent: 30.64 %
# Channel tracks, compare tracks vs worms, threshold: 35.0, fp/fn percent: 49.09274193548387 %
# Channel tracks, compare tracks vs artifacts, threshold: 35.0, fp/fn percent: 43.962848297213625 %
# Channel artifacts, compare artifacts vs dots, threshold: -8.372200953772918, fp/fn percent: 18.03405572755418 %
# Channel artifacts, compare artifacts vs tracks, threshold: -8.372200953772918, fp/fn percent: 45.04643962848297 %
# Channel artifacts, compare artifacts vs worms, threshold: -8.372200953772918, fp/fn percent: 48.891129032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 66.48606811145511 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 69.42724458204334 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 52.11693548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: 5.2813638938571935e-264, fp/fn percent: 32.27554179566564 %
# Channel artifacts, compare artifacts vs tracks, threshold: 5.2813638938571935e-264, fp/fn percent: 40.78947368421053 %
# Channel artifacts, compare artifacts vs worms, threshold: 5.2813638938571935e-264, fp/fn percent: 50.90725806451613 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0016163391645153532, fp/fn percent: 23.374613003095977 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0016163391645153532, fp/fn percent: 41.95046439628483 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0016163391645153532, fp/fn percent: 37.29838709677419 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.04147133796064875, fp/fn percent: 19.58204334365325 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.04147133796064875, fp/fn percent: 33.82352941176471 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.04147133796064875, fp/fn percent: 52.11693548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.14924549224372263, fp/fn percent: 18.188854489164086 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.14924549224372263, fp/fn percent: 31.88854489164087 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.14924549224372263, fp/fn percent: 53.42741935483871 %
# Channel artifacts, compare artifacts vs dots, threshold: -0.14336878548588558, fp/fn percent: 14.473684210526317 %
# Channel artifacts, compare artifacts vs tracks, threshold: -0.14336878548588558, fp/fn percent: 33.978328173374614 %
# Channel artifacts, compare artifacts vs worms, threshold: -0.14336878548588558, fp/fn percent: 48.38709677419355 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 66.48606811145511 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 69.3498452012384 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 52.11693548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: 7.932198927598318e-261, fp/fn percent: 32.19814241486068 %
# Channel artifacts, compare artifacts vs tracks, threshold: 7.932198927598318e-261, fp/fn percent: 40.78947368421053 %
# Channel artifacts, compare artifacts vs worms, threshold: 7.932198927598318e-261, fp/fn percent: 50.90725806451613 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.0, fp/fn percent: 24.148606811145513 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.0, fp/fn percent: 58.746130030959755 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.0, fp/fn percent: 43.649193548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: 11.999999977834475, fp/fn percent: 51.39318885448917 %
# Channel artifacts, compare artifacts vs tracks, threshold: 11.999999977834475, fp/fn percent: 45.04643962848297 %
# Channel artifacts, compare artifacts vs worms, threshold: 11.999999977834475, fp/fn percent: 42.641129032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 35.00000000000004, fp/fn percent: 36.60990712074303 %
# Channel artifacts, compare artifacts vs tracks, threshold: 35.00000000000004, fp/fn percent: 43.88544891640867 %
# Channel artifacts, compare artifacts vs worms, threshold: 35.00000000000004, fp/fn percent: 44.25403225806452 %
# Channel artifacts, compare artifacts vs dots, threshold: -8.349442834491066, fp/fn percent: 20.046439628482972 %
# Channel artifacts, compare artifacts vs tracks, threshold: -8.349442834491066, fp/fn percent: 54.56656346749226 %
# Channel artifacts, compare artifacts vs worms, threshold: -8.349442834491066, fp/fn percent: 49.899193548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 66.3312693498452 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 69.27244582043343 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 52.016129032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.011834311260238168, fp/fn percent: 21.981424148606813 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.011834311260238168, fp/fn percent: 51.23839009287926 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.011834311260238168, fp/fn percent: 47.983870967741936 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0016, fp/fn percent: 23.52941176470588 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0016, fp/fn percent: 42.3374613003096 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0016, fp/fn percent: 37.19758064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.07784334609698716, fp/fn percent: 30.185758513931887 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.07784334609698716, fp/fn percent: 52.55417956656346 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.07784334609698716, fp/fn percent: 34.87903225806452 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.23898979765651357, fp/fn percent: 29.102167182662537 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.23898979765651357, fp/fn percent: 51.16099071207431 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.23898979765651357, fp/fn percent: 35.08064516129033 %
# Channel artifacts, compare artifacts vs dots, threshold: -0.9268738900963545, fp/fn percent: 20.6656346749226 %
# Channel artifacts, compare artifacts vs tracks, threshold: -0.9268738900963545, fp/fn percent: 50.30959752321982 %
# Channel artifacts, compare artifacts vs worms, threshold: -0.9268738900963545, fp/fn percent: 37.19758064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 66.3312693498452 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 69.19504643962848 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 52.016129032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 10.0, fp/fn percent: 17.80185758513932 %
# Channel artifacts, compare artifacts vs tracks, threshold: 10.0, fp/fn percent: 40.40247678018576 %
# Channel artifacts, compare artifacts vs worms, threshold: 10.0, fp/fn percent: 46.875 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.0, fp/fn percent: 24.226006191950464 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.0, fp/fn percent: 58.6687306501548 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.0, fp/fn percent: 43.850806451612904 %
# Channel artifacts, compare artifacts vs dots, threshold: 12.0, fp/fn percent: 51.857585139318886 %
# Channel artifacts, compare artifacts vs tracks, threshold: 12.0, fp/fn percent: 44.969040247678016 %
# Channel artifacts, compare artifacts vs worms, threshold: 12.0, fp/fn percent: 43.346774193548384 %
# Channel artifacts, compare artifacts vs dots, threshold: 35.0, fp/fn percent: 36.60990712074303 %
# Channel artifacts, compare artifacts vs tracks, threshold: 35.0, fp/fn percent: 43.962848297213625 %
# Channel artifacts, compare artifacts vs worms, threshold: 35.0, fp/fn percent: 42.33870967741936 %
