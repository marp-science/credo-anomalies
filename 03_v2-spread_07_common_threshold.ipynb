# %%
import numpy as np

from commons import *
from dataset_loader import load_images, prepare_dataset, load_from_file
from IPython.display import display
import cv2
import pickle
import matplotlib.pyplot as plt
from keras.models import load_model


# TODO: https://pl.wikipedia.org/wiki/Dywergencja_Kullbacka-Leiblera
# https://towardsdatascience.com/kl-divergence-python-example-b87069e4b810
# TODO: entropia wzajemna, cross entropy


DOTS_AC = 'cache/dots_v2_spread.h5'
TRACKS_AC = 'cache/tracks_v2_spread.h5'
WORMS_AC = 'cache/worms_v2_spread.h5'
ARTIFACTS_AC = 'cache/artifacts_v2_spread.h5'

DOTS_SPREAD = 'cache/dots_v2_spread.pickle'
WORMS_SPREAD = 'cache/worms_v2_spread.pickle'
TRACKS_SPREAD = 'cache/tracks_v2_spread.pickle'
ARTIFACTS_SPREAD = 'cache/artifacts_v2_spread.pickle'

dots_set =  prepare_dataset(load_from_file(DOTS_SPREAD)[0])
worms_set =  prepare_dataset(load_from_file(WORMS_SPREAD)[0])
tracks_set =  prepare_dataset(load_from_file(TRACKS_SPREAD)[0])
artifacts_set =  prepare_dataset(load_from_file(ARTIFACTS_SPREAD)[0])

dots_autoencoder = load_model(DOTS_AC)
worms_autoencoder = load_model(WORMS_AC)
tracks_autoencoder = load_model(TRACKS_AC)
artifacts_autoencoder = load_model(ARTIFACTS_AC)

# %%
# def find_threshold(sa, sb):
#     a = sorted(sa)
#     b = sorted(sb)
#
#     la = len(a)
#     lb = len(b)
#
#     if la > lb:
#         from scipy.ndimage import zoom
#         a2 = zoom(a, lb / la)
#         a = a2
#     elif la < lb:
#         from scipy.ndimage import zoom
#         b2 = zoom(b, la / lb)
#         b = b2
#
#     la = len(a)
#     lb = len(b)
#
#     ta = int(la // 2)
#     tb = int(lb // 2)
#
#     ca = a[ta]
#     cb = b[tb]
#
#     if ca > cb:
#         swap = a
#         a = b
#         b = swap
#
#     np_a = np.array(a)
#     np_b = np.array(b)
#
#     np_a_ex = append_label_column(np_a, 1)
#     np_b_ex = append_label_column(np_b, 2)
#
#     left = 4
#     right = 3
#
#     np_ab = np.vstack([np_a_ex, np_b_ex])
#     np_ab = np_ab[np_ab[:, 0].argsort()]
#
#     labels = np_ab[:,1]
#
#     cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
#     cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
#     cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
#     cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())
#
#     np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])
#
#     half = 0
#     for row in np_ab_ex:
#         rl = row[left]
#         rr = row[right]
#         if rl > rr:
#             break
#         half += 1
#
#     threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2
#
#     fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
#     fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]
#
#     percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100
#
#     return threshold, percent
#

config = {}

dm_funcs = [dm_func_mean2, dm_func_avg_hash, dm_func_p_hash, dm_func_d_hash, dm_func_haar_hash, dm_func_db4_hash] #  , dm_func_cr_hash, dm_func_color_hash
#dm_funcs = [dm_func_mean2]
cutoff_backgrounds = [True, False]
normalizes = [True, False]
autoencoders = [
    (dots_autoencoder, 'dots', dots_set),
    (worms_autoencoder, 'worms', worms_set),
    (tracks_autoencoder, 'tracks', tracks_set),
    (artifacts_autoencoder, 'artifacts', artifacts_set)
]

#calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, normalize=True, cutoff_background=False)
#trained_set = calculated['dots']
#other_set = np.hstack([calculated['worms'], calculated['tracks'], calculated['artifacts']])




for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = []
            for dm_func in dm_funcs:
                print('====| dm_func = %s, cutoff_background = %s, normalize = %s |====' % (str(dm_func.__name__), str(cutoff_background), str(normalize)))
                argv = {'cutoff_background': cutoff_background, 'normalize': normalize, 'dm_func': dm_func}

                #dots_reconstruction = autoencoder.predict(dots_set) if name != 'dots' else []
                #worms_reconstruction = autoencoder.predict(worms_set) if name != 'worms' else []
                #tracks_reconstruction = autoencoder.predict(tracks_set) if name != 'tracks' else []
                #artifacts_reconstruction = autoencoder.predict(artifacts_set) if name != 'artifacts' else []

                #others = np.vstack([dots_reconstruction, worms_reconstruction, tracks_reconstruction, artifacts_reconstruction])

                #prepare_for_histogram(trained_set, others, dm_func, **argv)

                calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv)

                trained_set = calculated[name]
                other_set = []
                for sn in calculated.keys():
                    if sn != name:
                        other_set.append(calculated[sn])
                other_set = np.hstack(other_set)

                threshold, percent = find_threshold(trained_set, other_set)
                plot_threshold(trained_set, other_set, threshold, 'dots', 'others')

                print('Channel %s, threshold: %f, percent: %f' % (name, threshold, percent))

                rows.append((dm_func.__name__, str(cutoff_background), str(normalize), calculated, threshold))
            config[(autoencoder, cutoff_background, normalize)] = rows
# Out:
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: -11.772095, percent: 4.933333
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 95.920000
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 71.760000
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 6ms/step
# Channel dots, threshold: 0.000000, percent: 68.453333
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.076923, percent: 19.546667
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.200000, percent: 25.253333
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 6ms/step
# Channel dots, threshold: -6.264522, percent: 2.266667
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 1s 9ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 95.893333
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 71.706667
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 68.426667
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 10.000000, percent: 45.386667
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 31.000000, percent: 34.880000
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: -11.686548, percent: 4.906667
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 95.840000
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 6ms/step
# Channel dots, threshold: 0.000000, percent: 68.960000
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 69.226667
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.082020, percent: 21.786667
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.222027, percent: 25.946667
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: -6.625803, percent: 5.253333
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 95.813333
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 68.933333
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 69.200000
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 11.000000, percent: 43.066667
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 32.000000, percent: 32.213333
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 6ms/step
# Channel worms, threshold: -9.150842, percent: 32.963710
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.000988, percent: 28.729839
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.003410, percent: 33.266129
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.001275, percent: 34.475806
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.023670, percent: 30.040323
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.084722, percent: 29.939516
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: -0.072658, percent: 24.697581
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 1.000000, percent: 32.862903
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 4.000000, percent: 33.568548
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 1.000000, percent: 39.112903
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 12.000000, percent: 47.983871
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 40.000000, percent: 39.919355
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: -9.164746, percent: 31.250000
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.001148, percent: 28.427419
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.005525, percent: 35.685484
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 1s 7ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.001250, percent: 33.770161
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.027515, percent: 30.947581
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.095459, percent: 29.737903
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: -0.165265, percent: 23.588710
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 1.000000, percent: 31.955645
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 8.000000, percent: 35.786290
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 1.000000, percent: 37.903226
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 13.000000, percent: 44.556452
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 42.000000, percent: 39.112903
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: -9.953885, percent: 32.018561
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 75.008286
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 72.207491
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 68.694067
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.048443, percent: 39.360292
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.146816, percent: 41.581041
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: -1.741098, percent: 33.046072
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 74.958568
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 72.141200
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 68.660921
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 11.000000, percent: 47.414650
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 34.000005, percent: 41.332449
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 1s 10ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: -10.106061, percent: 28.239973
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 82.598608
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 71.511435
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 69.539277
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.053252, percent: 35.117667
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.166081, percent: 38.200199
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: -1.957037, percent: 28.770302
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 82.548890
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 71.461717
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 69.489559
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 12.000000, percent: 50.679483
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 37.000000, percent: 43.868081
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: -9.153369, percent: 31.888545
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 70.201238
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 72.213622
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 69.814241
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.024937, percent: 30.959752
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.092244, percent: 32.198142
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: -0.244081, percent: 26.083591
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 70.201238
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 72.136223
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 69.814241
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 10.000000, percent: 46.594427
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 35.000000, percent: 49.071207
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: -9.638082, percent: 41.253870
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 69.427245
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.006198, percent: 33.978328
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 71.130031
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.044703, percent: 44.891641
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.145186, percent: 45.433437
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: -1.279480, percent: 40.634675
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 69.349845
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 8.000000, percent: 32.120743
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 71.052632
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 14.000000, percent: 40.092879
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 42.000000, percent: 46.517028

# %%
def find_percent(sa, sb, threshold):
    a = sorted(sa)
    b = sorted(sb)

    la = len(a)
    lb = len(b)

    if la > lb:
        from scipy.ndimage import zoom
        a2 = zoom(a, lb / la)
        a = a2
    elif la < lb:
        from scipy.ndimage import zoom
        b2 = zoom(b, la / lb)
        b = b2

    la = len(a)
    lb = len(b)

    ta = int(la // 2)
    tb = int(lb // 2)

    ca = a[ta]
    cb = b[tb]

    if ca > cb:
        swap = a
        a = b
        b = swap

    np_a = np.array(a)
    np_b = np.array(b)

    np_a_ex = append_label_column(np_a, 1)
    np_b_ex = append_label_column(np_b, 2)

    left = 4
    right = 3

    np_ab = np.vstack([np_a_ex, np_b_ex])
    np_ab = np_ab[np_ab[:, 0].argsort()]

    labels = np_ab[:,1]

    cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
    cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
    cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
    cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())

    np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])

    half = 0
    for row in np_ab_ex:
        rl = row[left]
        rr = row[right]
        if rl > rr:
            break
        half += 1

    #threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2

    fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
    fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]

    percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100

    return percent


def confusion_matrix2(rows, channel):
    import matplotlib.pyplot as plt

    x_labels = ["dots", "tracks", "worms", "artifacts"]
    y_labels = []

    matrix = np.zeros((len(rows), len(x_labels)), dtype=np.int32)

    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            set_name = x_labels[j]
            (fun_name, cutoff_background, normalize, similarity, threshold) = rows[i]

            la = channel
            lb = set_name

            if la == lb:
                continue

            a = similarity[la]
            b = similarity[lb]


            #threshold, percent = find_threshold(a, b)
            percent = find_percent(a, b, threshold)

            print('Channel %s, compare %s vs %s, threshold: %s, fp/fn percent: %s %%' % (la, la, lb, str(threshold), str(percent)))
            #plot_threshold(a, b, threshold, la, lb)

            matrix[i, j] = int(100 - percent)
        y_labels.append(rows[i][0])

    fig, ax = plt.subplots()
    im = ax.imshow(matrix)

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(x_labels)), labels=x_labels)
    ax.set_yticks(np.arange(len(y_labels)), labels=y_labels)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            text = ax.text(j, i, matrix[i, j], ha="center", va="center", color="w")

    ax.set_title("x - data set, y - compare method")
    fig.tight_layout()
    plt.show()

for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = config[(autoencoder, cutoff_background, normalize)]
            confusion_matrix2(rows, name)
# Out:
# Channel dots, compare dots vs tracks, threshold: -11.772094904302966, fp/fn percent: 5.013333333333334 %
# Channel dots, compare dots vs worms, threshold: -11.772094904302966, fp/fn percent: 2.721774193548387 %
# Channel dots, compare dots vs artifacts, threshold: -11.772094904302966, fp/fn percent: 6.269349845201239 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 74.98666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.04032258064516 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 65.24767801857585 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 72.16 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 57.56048387096774 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 67.3374613003096 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 68.77333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 53.931451612903224 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 65.01547987616098 %
# Channel dots, compare dots vs tracks, threshold: 0.07692289575769123, fp/fn percent: 20.85333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.07692289575769123, fp/fn percent: 12.701612903225806 %
# Channel dots, compare dots vs artifacts, threshold: 0.07692289575769123, fp/fn percent: 18.653250773993808 %
# Channel dots, compare dots vs tracks, threshold: 0.2, fp/fn percent: 27.12 %
# Channel dots, compare dots vs worms, threshold: 0.2, fp/fn percent: 16.22983870967742 %
# Channel dots, compare dots vs artifacts, threshold: 0.2, fp/fn percent: 23.142414860681114 %
# Channel dots, compare dots vs tracks, threshold: -6.2645224345661, fp/fn percent: 1.6533333333333333 %
# Channel dots, compare dots vs worms, threshold: -6.2645224345661, fp/fn percent: 1.1088709677419355 %
# Channel dots, compare dots vs artifacts, threshold: -6.2645224345661, fp/fn percent: 6.114551083591331 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 74.96000000000001 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.93951612903226 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 65.24767801857585 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 72.08 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 57.45967741935484 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 67.26006191950464 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 68.74666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 53.931451612903224 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 64.93808049535603 %
# Channel dots, compare dots vs tracks, threshold: 10.00000000000002, fp/fn percent: 45.013333333333335 %
# Channel dots, compare dots vs worms, threshold: 10.00000000000002, fp/fn percent: 42.33870967741936 %
# Channel dots, compare dots vs artifacts, threshold: 10.00000000000002, fp/fn percent: 50.30959752321982 %
# Channel dots, compare dots vs tracks, threshold: 30.99999959632035, fp/fn percent: 34.93333333333333 %
# Channel dots, compare dots vs worms, threshold: 30.99999959632035, fp/fn percent: 27.318548387096776 %
# Channel dots, compare dots vs artifacts, threshold: 30.99999959632035, fp/fn percent: 39.39628482972136 %
# Channel dots, compare dots vs tracks, threshold: -11.686548154945882, fp/fn percent: 5.04 %
# Channel dots, compare dots vs worms, threshold: -11.686548154945882, fp/fn percent: 2.721774193548387 %
# Channel dots, compare dots vs artifacts, threshold: -11.686548154945882, fp/fn percent: 6.037151702786378 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 94.58666666666666 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.03225806451613 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 64.47368421052632 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 71.52 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.24193548387096 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 54.10216718266254 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 69.57333333333334 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.233870967741936 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 66.25386996904025 %
# Channel dots, compare dots vs tracks, threshold: 0.08201989042570161, fp/fn percent: 21.36 %
# Channel dots, compare dots vs worms, threshold: 0.08201989042570161, fp/fn percent: 13.306451612903224 %
# Channel dots, compare dots vs artifacts, threshold: 0.08201989042570161, fp/fn percent: 30.41795665634675 %
# Channel dots, compare dots vs tracks, threshold: 0.22202688954528893, fp/fn percent: 25.94666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.22202688954528893, fp/fn percent: 15.92741935483871 %
# Channel dots, compare dots vs artifacts, threshold: 0.22202688954528893, fp/fn percent: 33.746130030959755 %
# Channel dots, compare dots vs tracks, threshold: -6.625803001062106, fp/fn percent: 2.9066666666666667 %
# Channel dots, compare dots vs worms, threshold: -6.625803001062106, fp/fn percent: 2.620967741935484 %
# Channel dots, compare dots vs artifacts, threshold: -6.625803001062106, fp/fn percent: 18.343653250773993 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 94.53333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.03225806451613 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 64.47368421052632 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 71.49333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.34274193548387 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 54.024767801857585 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 69.49333333333333 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 54.233870967741936 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent:
%
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 43.75 %
# Channel worms, compare worms vs dots, threshold: 8.0, fp/fn percent: 21.572580645161292 %
# Channel worms, compare worms vs tracks, threshold: 8.0, fp/fn percent: 39.71774193548387 %
# Channel worms, compare worms vs artifacts, threshold: 8.0, fp/fn percent: 48.48790322580645 %
# Channel worms, compare worms vs dots, threshold: 1.0, fp/fn percent: 21.471774193548388 %
# Channel worms, compare worms vs tracks, threshold: 1.0, fp/fn percent: 45.86693548387097 %
# Channel worms, compare worms vs artifacts, threshold: 1.0, fp/fn percent: 44.556451612903224 %
# Channel worms, compare worms vs dots, threshold: 13.000000000000002, fp/fn percent: 39.91935483870967 %
# Channel worms, compare worms vs tracks, threshold: 13.000000000000002, fp/fn percent: 44.75806451612903 %
# Channel worms, compare worms vs artifacts, threshold: 13.000000000000002, fp/fn percent: 45.36290322580645 %
# Channel worms, compare worms vs dots, threshold: 42.00000000000001, fp/fn percent: 28.528225806451612 %
# Channel worms, compare worms vs tracks, threshold: 42.00000000000001, fp/fn percent: 42.84274193548387 %
# Channel worms, compare worms vs artifacts, threshold: 42.00000000000001, fp/fn percent: 50.70564516129033 %
# Channel tracks, compare tracks vs dots, threshold: -9.95388536236117, fp/fn percent: 16.053333333333335 %
# Channel tracks, compare tracks vs worms, threshold: -9.95388536236117, fp/fn percent: 41.63306451612903 %
# Channel tracks, compare tracks vs artifacts, threshold: -9.95388536236117, fp/fn percent: 41.873065015479874 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 74.98666666666666 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 57.86290322580645 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 68.18885448916409 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 72.16 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 60.68548387096774 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 70.20123839009288 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 68.77333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 56.75403225806451 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 68.73065015479877 %
# Channel tracks, compare tracks vs dots, threshold: 0.048442887020283, fp/fn percent: 26.400000000000002 %
# Channel tracks, compare tracks vs worms, threshold: 0.048442887020283, fp/fn percent: 37.399193548387096 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.048442887020283, fp/fn percent: 40.94427244582043 %
# Channel tracks, compare tracks vs dots, threshold: 0.14681583096730352, fp/fn percent: 29.62666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.14681583096730352, fp/fn percent: 36.08870967741936 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.14681583096730352, fp/fn percent: 40.86687306501548 %
# Channel tracks, compare tracks vs dots, threshold: -1.7410976548094501, fp/fn percent: 16.53333333333333 %
# Channel tracks, compare tracks vs worms, threshold: -1.7410976548094501, fp/fn percent: 36.59274193548387 %
# Channel tracks, compare tracks vs artifacts, threshold: -1.7410976548094501, fp/fn percent: 42.26006191950464 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 74.96000000000001 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 57.76209677419355 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 68.11145510835914 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 72.08 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 60.68548387096774 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 70.12383900928792 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 68.74666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 56.75403225806451 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 68.65325077399382 %
# Channel tracks, compare tracks vs dots, threshold: 11.0, fp/fn percent: 45.94666666666667 %
# Channel tracks, compare tracks vs worms, threshold: 11.0, fp/fn percent: 48.08467741935484 %
# Channel tracks, compare tracks vs artifacts, threshold: 11.0, fp/fn percent: 46.20743034055727 %
# Channel tracks, compare tracks vs dots, threshold: 34.00000505773128, fp/fn percent: 35.38666666666666 %
# Channel tracks, compare tracks vs worms, threshold: 34.00000505773128, fp/fn percent: 43.44758064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: 34.00000505773128, fp/fn percent: 46.82662538699691 %
# Channel tracks, compare tracks vs dots, threshold: -10.106061483295067, fp/fn percent: 14.16 %
# Channel tracks, compare tracks vs worms, threshold: -10.106061483295067, fp/fn percent: 42.13709677419355 %
# Channel tracks, compare tracks vs artifacts, threshold: -10.106061483295067, fp/fn percent: 53.637770897832816 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent:
%
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 68.11145510835914 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 50.90725806451613 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 67.26006191950464 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 70.12383900928792 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 52.721774193548384 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 64.93808049535603 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 68.65325077399382 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 50.1008064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 10.000000000000002, fp/fn percent: 50.69659442724458 %
# Channel artifacts, compare artifacts vs tracks, threshold: 10.000000000000002, fp/fn percent: 44.969040247678016 %
# Channel artifacts, compare artifacts vs worms, threshold: 10.000000000000002, fp/fn percent: 42.943548387096776 %
# Channel artifacts, compare artifacts vs dots, threshold: 35.0, fp/fn percent: 39.0092879256966 %
# Channel artifacts, compare artifacts vs tracks, threshold: 35.0, fp/fn percent: 47.29102167182663 %
# Channel artifacts, compare artifacts vs worms, threshold: 35.0, fp/fn percent: 40.42338709677419 %
# Channel artifacts, compare artifacts vs dots, threshold: -9.638081630556243, fp/fn percent: 20.6656346749226 %
# Channel artifacts, compare artifacts vs tracks, threshold: -9.638081630556243, fp/fn percent: 50.77399380804953 %
# Channel artifacts, compare artifacts vs worms, threshold: -9.638081630556243, fp/fn percent: 39.91935483870967 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 64.47368421052632 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 67.41486068111455 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 50.70564516129033 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.006198347107438017, fp/fn percent: 20.975232198142415 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.006198347107438017, fp/fn percent: 39.78328173374613 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.006198347107438017, fp/fn percent: 47.983870967741936 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 66.25386996904025 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 69.5046439628483 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 50.1008064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.044703077419610694, fp/fn percent: 28.482972136222912 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.044703077419610694, fp/fn percent: 51.62538699690402 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.044703077419610694, fp/fn percent: 35.78629032258064 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.14518571922270368, fp/fn percent: 31.037151702786375 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.14518571922270368, fp/fn percent: 50.92879256965944 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.14518571922270368, fp/fn percent: 34.87903225806452 %
# Channel artifacts, compare artifacts vs dots, threshold: -1.279479640575102, fp/fn percent: 20.356037151702786 %
# Channel artifacts, compare artifacts vs tracks, threshold: -1.279479640575102, fp/fn percent: 49.07120743034056 %
# Channel artifacts, compare artifacts vs worms, threshold: -1.279479640575102, fp/fn percent: 34.778225806451616 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 64.47368421052632 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 67.3374613003096 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 50.70564516129033 %
# Channel artifacts, compare artifacts vs dots, threshold: 8.0, fp/fn percent: 18.575851393188856 %
# Channel artifacts, compare artifacts vs tracks, threshold: 8.0, fp/fn percent: 37.15170278637771 %
# Channel artifacts, compare artifacts vs worms, threshold: 8.0, fp/fn percent: 48.48790322580645 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 66.17647058823529 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 69.42724458204334 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 50.1008064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 14.0, fp/fn percent: 36.30030959752322 %
# Channel artifacts, compare artifacts vs tracks, threshold: 14.0, fp/fn percent: 41.253869969040245 %
# Channel artifacts, compare artifacts vs worms, threshold: 14.0, fp/fn percent: 47.17741935483871 %
# Channel artifacts, compare artifacts vs dots, threshold: 42.0, fp/fn percent: 36.14551083591331 %
# Channel artifacts, compare artifacts vs tracks, threshold: 42.0, fp/fn percent: 50.69659442724458 %
# Channel artifacts, compare artifacts vs worms, threshold: 42.0, fp/fn percent: 52.41935483870967 %
