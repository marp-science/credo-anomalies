# %%
# Please visit:
#
# https://download.nkg-mn.com/credo/anomalies/
#
# Pretrained dots_100000.h5 and others can be downloaded from mentioned website.

# %%
from align_images_pca import align_image
from PIL import Image
import numpy as np
import glob


TRACKS_SRC = 'hit-images-final2/line'
WORMS_SRC = 'hit-images-final2/worms'


def load_images(src):
    images = []
    files = list(glob.glob("%s/*.png" % src))
    files = sorted(files)
    for image_path in files:
        img = Image.open(image_path)
        img = img.convert('L')
        image = np.asarray(img)
        #image = np.asarray(Image.open(image_path).convert('L'))
        image = align_image(image)
        mask = np.where(image > 25, 1, 0)
        image = mask * image
        image = image.astype(np.float32) / np.max(image)
        image = np.expand_dims(image, 2)
        images.append(image)
    return np.asarray(images), files


tracks_set, tacks_files = load_images(TRACKS_SRC)
worms_set, worms_files = load_images(WORMS_SRC)

# %%
def augmentation_mirror(src, files):
    images = []
    files_aug = []
    for i in range(0, len(src)):
        img = src[i]
        images.append(img)
        images.append(np.flip(img))
        files_aug.append(files[i])
        files_aug.append(files[i])
    return np.asarray(images), files_aug


tracks2_set, tacks2_files = augmentation_mirror(tracks_set, tacks_files)
worms2_set, worms2_files = augmentation_mirror(worms_set, worms_files)

# %%
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    p = np.random.permutation(df.shape[0])
    n = int(train_percent * len(p))
    m = int(validate_percent * len(p)) + n
    train = p[:n]
    validation = p[n:m]
    test = p[m:]
    return train, validation, test


tracks2_train, tracks2_validate, tracks2_test = train_validate_test_split(tracks2_set)
worms2_train, worms2_validate, worms2_test = train_validate_test_split(worms2_set)

# %%
from commons import *
from dataset_loader import load_from_file
from IPython.display import display
import matplotlib.pyplot as plt
import cv2

#DOTS_DST = 'cache/dots_100000.pickle'
#ARTIFACTS_DST = 'cache/artifacts_100000.pickle'

#DOTS_AC = 'cache/dots_100000.h5'
TRACKS_AC = 'cache/th_optics_100000.h5'
#WORMS_AC = 'cache/worms_100000.h5'
#ARTIFACTS_AC = 'cache/artifacts_100000.h5'

def train_and_test(train_set, validation_set, fn):
    autoencoder = original_autoencoder()
    autoencoder = train_or_cache(train_set, autoencoder, fn, validation_set=validation_set, force_train=True)

    for df_func, df_name in zip(
            [dm_func_mean],
            ['mean']
    ):
        for img_set, set_names in zip([validation_set], ['train']):
            decoded = autoencoder.predict(img_set)

            vis, errors = visualize_predictions(decoded, img_set, df_func, False, 16)
            img_path = fn.replace('.h5', '-vis.png')
            hist_path = fn.replace('.h5', '-hist.png')
            cv2.imwrite(img_path, vis)
            display(Image.open(img_path))
            if len(img_set) > 256:
                vis, errors = visualize_predictions(decoded, img_set, df_func, False)
                img_path = fn.replace('.h5', '-vis_full.png')
                cv2.imwrite(img_path, vis)

            plt.figure(figsize=(8,6))
            plt.hist(errors, bins=100, alpha=0.5, label=set_names)
            plt.xlabel("Data", size=14)
            plt.ylabel("Count", size=14)
            plt.title(df_name)
            plt.legend(loc='upper right')
            plt.savefig(hist_path)


train_and_test(tracks2_set[tracks2_train], tracks2_set[tracks2_validate], TRACKS_AC)
# Out:
# 320
# 0
# 128
# 18496
# 0
# 256
# 0
# 230416
# 244800
# 0
# 36928
# 0
# 256
# 18464
# 0
# 128
# 289
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 60, 60, 1)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  leaky_re_lu (LeakyReLU)     (None, 30, 30, 32)        0
#
#  batch_normalization (BatchN  (None, 30, 30, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 15, 15, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 15, 15, 64)        0
#
#  batch_normalization_1 (Batc  (None, 15, 15, 64)       256
#  hNormalization)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 16)                230416
#
# =================================================================
# Total params: 249,616
# Trainable params: 249,424
# Non-trainable params: 192
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 16)]              0
#
#  dense_1 (Dense)             (None, 14400)             244800
#
#  reshape (Reshape)           (None, 15, 15, 64)        0
#
#  conv2d_transpose (Conv2DTra  (None, 30, 30, 64)       36928
#  nspose)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 30, 30, 64)        0
#
#  batch_normalization_2 (Batc  (None, 30, 30, 64)       256
#  hNormalization)
#
#  conv2d_transpose_1 (Conv2DT  (None, 60, 60, 32)       18464
#  ranspose)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 60, 60, 32)        0
#
#  batch_normalization_3 (Batc  (None, 60, 60, 32)       128
#  hNormalization)
#
#  conv2d_transpose_2 (Conv2DT  (None, 60, 60, 1)        289
#  ranspose)
#
#  activation (Activation)     (None, 60, 60, 1)         0
#
# =================================================================
# Total params: 300,865
# Trainable params: 300,673
# Non-trainable params: 192
# _________________________________________________________________
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 60, 60, 1)]       0
#
#  encoder (Functional)        (None, 16)                249616
#
#  decoder (Functional)        (None, 60, 60, 1)         300865
#
# =================================================================
# Total params: 550,481
# Trainable params: 550,097
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/200
# 115/115 [==============================] - 5s 14ms/step - loss: 0.0625 - accuracy: 0.9430 - val_loss: 0.0213 - val_accuracy: 0.9795
# Epoch 2/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0174 - accuracy: 0.9793 - val_loss: 0.0167 - val_accuracy: 0.9795
# Epoch 3/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0170 - accuracy: 0.9794 - val_loss: 0.0175 - val_accuracy: 0.9795
# Epoch 4/200
# 115/115 [==============================] - 1s 11ms/step - loss: 0.0168 - accuracy: 0.9794 - val_loss: 0.0167 - val_accuracy: 0.9795
# Epoch 5/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0166 - accuracy: 0.9796 - val_loss: 0.0164 - val_accuracy: 0.9797
# Epoch 6/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0157 - accuracy: 0.9805 - val_loss: 0.0141 - val_accuracy: 0.9820
# Epoch 7/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0137 - accuracy: 0.9825 - val_loss: 0.0122 - val_accuracy: 0.9840
# Epoch 8/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0099 - accuracy: 0.9864 - val_loss: 0.0079 - val_accuracy: 0.9881
# Epoch 9/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0080 - accuracy: 0.9881 - val_loss: 0.0079 - val_accuracy: 0.9881
# Epoch 10/200
# 115/115 [==============================] - 1s 11ms/step - loss: 0.0080 - accuracy: 0.9881 - val_loss: 0.0079 - val_accuracy: 0.9881
# Epoch 11/200
# 115/115 [==============================] - 1s 9ms/step - loss: 0.0080 - accuracy: 0.9881 - val_loss: 0.0079 - val_accuracy: 0.9881
# Epoch 12/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0080 - accuracy: 0.9881 - val_loss: 0.0079 - val_accuracy: 0.9881
# Epoch 13/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0080 - accuracy: 0.9881 - val_loss: 0.0079 - val_accuracy: 0.9881
# Epoch 14/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0080 - accuracy: 0.9881 - val_loss: 0.0079 - val_accuracy: 0.9881
# Epoch 15/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0079 - accuracy: 0.9882 - val_loss: 0.0077 - val_accuracy: 0.9884
# Epoch 16/200
# 115/115 [==============================] - 1s 9ms/step - loss: 0.0077 - accuracy: 0.9883 - val_loss: 0.0077 - val_accuracy: 0.9883
# Epoch 17/200
# 115/115 [==============================] - 1s 11ms/step - loss: 0.0077 - accuracy: 0.9883 - val_loss: 0.0077 - val_accuracy: 0.9883
# Epoch 18/200
# 115/115 [==============================] - 1s 11ms/step - loss: 0.0077 - accuracy: 0.9883 - val_loss: 0.0077 - val_accuracy: 0.9884
# Epoch 19/200
# 115/115 [==============================] - 1s 10ms/step - loss: 0.0067 - accuracy: 0.9893 - val_loss: 0.0502 - val_accuracy: 0.9354
# Epoch 20/200
# 115/115 [==============================] - 1s 11ms/step - loss: 0.0017 - accuracy: 0.9944 - val_loss: 0.0019 - val_accuracy: 0.9938
# Epoch 21/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.4081e-04 - accuracy: 0.9945 - val_loss: 0.0028 - val_accuracy: 0.9929
# Epoch 22/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.3512e-04 - accuracy: 0.9946 - val_loss: 0.0038 - val_accuracy: 0.9921
# Epoch 23/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.5811e-04 - accuracy: 0.9946 - val_loss: 0.0029 - val_accuracy: 0.9927
# Epoch 24/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.0316e-04 - accuracy: 0.9946 - val_loss: 9.5789e-04 - val_accuracy: 0.9944
# Epoch 25/200
# 115/115 [==============================] - 1s 11ms/step - loss: 2.7627e-04 - accuracy: 0.9947 - val_loss: 5.2868e-04 - val_accuracy: 0.9946
# Epoch 26/200
# 115/115 [==============================] - 1s 11ms/step - loss: 2.4181e-04 - accuracy: 0.9947 - val_loss: 7.4530e-04 - val_accuracy: 0.9945
# Epoch 27/200
# 115/115 [==============================] - 1s 11ms/step - loss: 2.1465e-04 - accuracy: 0.9947 - val_loss: 3.1729e-04 - val_accuracy: 0.9947
# Epoch 28/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.9557e-04 - accuracy: 0.9947 - val_loss: 2.9175e-04 - val_accuracy: 0.9947
# Epoch 29/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.8156e-04 - accuracy: 0.9947 - val_loss: 2.6995e-04 - val_accuracy: 0.9947
# Epoch 30/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.6957e-04 - accuracy: 0.9947 - val_loss: 5.0981e-04 - val_accuracy: 0.9946
# Epoch 31/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.5896e-04 - accuracy: 0.9947 - val_loss: 2.7033e-04 - val_accuracy: 0.9947
# Epoch 32/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.4945e-04 - accuracy: 0.9947 - val_loss: 1.6482e-04 - val_accuracy: 0.9947
# Epoch 33/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.4202e-04 - accuracy: 0.9947 - val_loss: 2.5721e-04 - val_accuracy: 0.9947
# Epoch 34/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.3551e-04 - accuracy: 0.9947 - val_loss: 1.6836e-04 - val_accuracy: 0.9947
# Epoch 35/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.3076e-04 - accuracy: 0.9947 - val_loss: 8.4429e-04 - val_accuracy: 0.9943
# Epoch 36/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.2595e-04 - accuracy: 0.9947 - val_loss: 3.1617e-04 - val_accuracy: 0.9947
# Epoch 37/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.2066e-04 - accuracy: 0.9947 - val_loss: 7.3361e-04 - val_accuracy: 0.9944
# Epoch 38/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.1790e-04 - accuracy: 0.9947 - val_loss: 3.5799e-04 - val_accuracy: 0.9946
# Epoch 39/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.1406e-04 - accuracy: 0.9947 - val_loss: 3.4106e-04 - val_accuracy: 0.9946
# Epoch 40/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.1115e-04 - accuracy: 0.9947 - val_loss: 1.9285e-04 - val_accuracy: 0.9947
# Epoch 41/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.0797e-04 - accuracy: 0.9947 - val_loss: 3.3028e-04 - val_accuracy: 0.9947
# Epoch 42/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.0659e-04 - accuracy: 0.9947 - val_loss: 3.3191e-04 - val_accuracy: 0.9946
# Epoch 43/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.0439e-04 - accuracy: 0.9947 - val_loss: 4.7080e-04 - val_accuracy: 0.9945
# Epoch 44/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.0285e-04 - accuracy: 0.9947 - val_loss: 5.0154e-04 - val_accuracy: 0.9945
# Epoch 45/200
# 115/115 [==============================] - 1s 11ms/step - loss: 9.9201e-05 - accuracy: 0.9947 - val_loss: 1.6866e-04 - val_accuracy: 0.9947
# Epoch 46/200
# 115/115 [==============================] - 1s 11ms/step - loss: 9.7171e-05 - accuracy: 0.9947 - val_loss: 1.2789e-04 - val_accuracy: 0.9947
# Epoch 47/200
# 115/115 [==============================] - 1s 11ms/step - loss: 9.5280e-05 - accuracy: 0.9947 - val_loss: 4.6305e-04 - val_accuracy: 0.9946
# Epoch 48/200
# 115/115 [==============================] - 1s 10ms/step - loss: 9.5178e-05 - accuracy: 0.9947 - val_loss: 2.7935e-04 - val_accuracy: 0.9947
# Epoch 49/200
# 115/115 [==============================] - 1s 11ms/step - loss: 9.4431e-05 - accuracy: 0.9947 - val_loss: 1.8699e-04 - val_accuracy: 0.9947
# Epoch 50/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.0439e-04 - accuracy: 0.9947 - val_loss: 0.0010 - val_accuracy: 0.9941
# Epoch 51/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.0400e-04 - accuracy: 0.9947 - val_loss: 2.0872e-04 - val_accuracy: 0.9947
# Epoch 52/200
# 115/115 [==============================] - 1s 10ms/step - loss: 9.4589e-05 - accuracy: 0.9947 - val_loss: 1.1220e-04 - val_accuracy: 0.9947
# Epoch 53/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.8339e-05 - accuracy: 0.9947 - val_loss: 3.4209e-04 - val_accuracy: 0.9947
# Epoch 54/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.5229e-05 - accuracy: 0.9947 - val_loss: 1.5437e-04 - val_accuracy: 0.9947
# Epoch 55/200
# 115/115 [==============================] - 1s 11ms/step - loss: 8.4455e-05 - accuracy: 0.9947 - val_loss: 1.1750e-04 - val_accuracy: 0.9947
# Epoch 56/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.3968e-05 - accuracy: 0.9947 - val_loss: 1.1131e-04 - val_accuracy: 0.9947
# Epoch 57/200
# 115/115 [==============================] - 1s 11ms/step - loss: 8.5347e-05 - accuracy: 0.9947 - val_loss: 4.4144e-04 - val_accuracy: 0.9946
# Epoch 58/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.6538e-05 - accuracy: 0.9947 - val_loss: 2.7072e-04 - val_accuracy: 0.9947
# Epoch 59/200
# 115/115 [==============================] - 1s 11ms/step - loss: 8.3678e-05 - accuracy: 0.9947 - val_loss: 1.6753e-04 - val_accuracy: 0.9947
# Epoch 60/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.7470e-05 - accuracy: 0.9947 - val_loss: 4.7295e-04 - val_accuracy: 0.9946
# Epoch 61/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.4496e-05 - accuracy: 0.9947 - val_loss: 1.8937e-04 - val_accuracy: 0.9947
# Epoch 62/200
# 115/115 [==============================] - 1s 11ms/step - loss: 8.6023e-05 - accuracy: 0.9947 - val_loss: 1.9825e-04 - val_accuracy: 0.9947
# Epoch 63/200
# 115/115 [==============================] - 1s 9ms/step - loss: 8.9140e-05 - accuracy: 0.9947 - val_loss: 1.8427e-04 - val_accuracy: 0.9947
# Epoch 64/200
# 115/115 [==============================] - 1s 11ms/step - loss: 8.6574e-05 - accuracy: 0.9947 - val_loss: 1.2531e-04 - val_accuracy: 0.9947
# Epoch 65/200
# 115/115 [==============================] - 1s 11ms/step - loss: 8.5854e-05 - accuracy: 0.9947 - val_loss: 1.5044e-04 - val_accuracy: 0.9947
# Epoch 66/200
# 115/115 [==============================] - 1s 11ms/step - loss: 8.6976e-05 - accuracy: 0.9947 - val_loss: 2.4779e-04 - val_accuracy: 0.9947
# Epoch 67/200
# 115/115 [==============================] - 1s 11ms/step - loss: 9.3739e-05 - accuracy: 0.9947 - val_loss: 2.6173e-04 - val_accuracy: 0.9947
# Epoch 68/200
# 115/115 [==============================] - 1s 10ms/step - loss: 1.0105e-04 - accuracy: 0.9947 - val_loss: 1.9833e-04 - val_accuracy: 0.9947
# Epoch 69/200
# 115/115 [==============================] - 1s 11ms/step - loss: 1.0897e-04 - accuracy: 0.9947 - val_loss: 1.6848e-04 - val_accuracy: 0.9947
# Epoch 70/200
# 115/115 [==============================] - 1s 10ms/step - loss: 9.0192e-05 - accuracy: 0.9947 - val_loss: 3.6401e-04 - val_accuracy: 0.9947
# Epoch 71/200
# 115/115 [==============================] - 1s 11ms/step - loss: 8.2076e-05 - accuracy: 0.9947 - val_loss: 7.7573e-04 - val_accuracy: 0.9945
# Epoch 72/200
# 115/115 [==============================] - 1s 11ms/step - loss: 7.8703e-05 - accuracy: 0.9947 - val_loss: 1.2976e-04 - val_accuracy: 0.9947
# Epoch 73/200
# 115/115 [==============================] - 1s 11ms/step - loss: 7.6539e-05 - accuracy: 0.9947 - val_loss: 1.1271e-04 - val_accuracy: 0.9947
# Epoch 74/200
# 115/115 [==============================] - 1s 11ms/step - loss: 7.4937e-05 - accuracy: 0.9947 - val_loss: 1.3818e-04 - val_accuracy: 0.9947
# Epoch 75/200
# 115/115 [==============================] - 1s 11ms/step - loss: 7.4188e-05 - accuracy: 0.9947 - val_loss: 1.1029e-04 - val_accuracy: 0.9947
# Epoch 76/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.3653e-05 - accuracy: 0.9947 - val_loss: 1.0881e-04 - val_accuracy: 0.9947
# Epoch 77/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.3978e-05 - accuracy: 0.9947 - val_loss: 1.3599e-04 - val_accuracy: 0.9947
# Epoch 78/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.4059e-05 - accuracy: 0.9947 - val_loss: 1.2329e-04 - val_accuracy: 0.9947
# Epoch 79/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.3117e-05 - accuracy: 0.9947 - val_loss: 1.2138e-04 - val_accuracy: 0.9947
# Epoch 80/200
# 115/115 [==============================] - 1s 11ms/step - loss: 7.3070e-05 - accuracy: 0.9947 - val_loss: 1.3000e-04 - val_accuracy: 0.9947
# Epoch 81/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.3959e-05 - accuracy: 0.9947 - val_loss: 1.2155e-04 - val_accuracy: 0.9947
# Epoch 82/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.5617e-05 - accuracy: 0.9947 - val_loss: 2.4834e-04 - val_accuracy: 0.9947
# Epoch 83/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.7676e-05 - accuracy: 0.9947 - val_loss: 1.4869e-04 - val_accuracy: 0.9947
# Epoch 84/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.5331e-05 - accuracy: 0.9947 - val_loss: 1.9198e-04 - val_accuracy: 0.9947
# Epoch 85/200
# 115/115 [==============================] - 1s 12ms/step - loss: 7.3711e-05 - accuracy: 0.9947 - val_loss: 1.3447e-04 - val_accuracy: 0.9947
# Epoch 86/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.2668e-05 - accuracy: 0.9947 - val_loss: 1.6199e-04 - val_accuracy: 0.9947
# Epoch 87/200
# 115/115 [==============================] - 1s 11ms/step - loss: 7.5422e-05 - accuracy: 0.9947 - val_loss: 1.2940e-04 - val_accuracy: 0.9947
# Epoch 88/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.3024e-05 - accuracy: 0.9947 - val_loss: 2.0701e-04 - val_accuracy: 0.9947
# Epoch 89/200
# 115/115 [==============================] - 1s 10ms/step - loss: 9.2643e-05 - accuracy: 0.9947 - val_loss: 1.5004e-04 - val_accuracy: 0.9947
# Epoch 90/200
# 115/115 [==============================] - 1s 10ms/step - loss: 9.0264e-05 - accuracy: 0.9947 - val_loss: 1.8449e-04 - val_accuracy: 0.9947
# Epoch 91/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.9558e-05 - accuracy: 0.9947 - val_loss: 1.9155e-04 - val_accuracy: 0.9947
# Epoch 92/200
# 115/115 [==============================] - 1s 10ms/step - loss: 8.6276e-05 - accuracy: 0.9947 - val_loss: 1.2717e-04 - val_accuracy: 0.9947
# Epoch 93/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.5552e-05 - accuracy: 0.9947 - val_loss: 1.4763e-04 - val_accuracy: 0.9947
# Epoch 94/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.8095e-05 - accuracy: 0.9947 - val_loss: 2.1568e-04 - val_accuracy: 0.9947
# Epoch 95/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.3831e-05 - accuracy: 0.9947 - val_loss: 1.6750e-04 - val_accuracy: 0.9947
# Epoch 96/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.2560e-05 - accuracy: 0.9947 - val_loss: 1.7294e-04 - val_accuracy: 0.9947
# Epoch 97/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1230e-05 - accuracy: 0.9947 - val_loss: 1.1175e-04 - val_accuracy: 0.9947
# Epoch 98/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.0592e-05 - accuracy: 0.9947 - val_loss: 1.1112e-04 - val_accuracy: 0.9947
# Epoch 99/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.0324e-05 - accuracy: 0.9947 - val_loss: 1.2198e-04 - val_accuracy: 0.9947
# Epoch 100/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.0874e-05 - accuracy: 0.9947 - val_loss: 1.0714e-04 - val_accuracy: 0.9947
# Epoch 101/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.0663e-05 - accuracy: 0.9947 - val_loss: 1.0643e-04 - val_accuracy: 0.9947
# Epoch 102/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.0258e-05 - accuracy: 0.9947 - val_loss: 1.1538e-04 - val_accuracy: 0.9947
# Epoch 103/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1035e-05 - accuracy: 0.9947 - val_loss: 1.1353e-04 - val_accuracy: 0.9947
# Epoch 104/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1311e-05 - accuracy: 0.9947 - val_loss: 1.3300e-04 - val_accuracy: 0.9947
# Epoch 105/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1631e-05 - accuracy: 0.9947 - val_loss: 1.2017e-04 - val_accuracy: 0.9947
# Epoch 106/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.2179e-05 - accuracy: 0.9947 - val_loss: 1.4736e-04 - val_accuracy: 0.9947
# Epoch 107/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.3736e-05 - accuracy: 0.9947 - val_loss: 2.1982e-04 - val_accuracy: 0.9947
# Epoch 108/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.8709e-05 - accuracy: 0.9947 - val_loss: 1.4524e-04 - val_accuracy: 0.9947
# Epoch 109/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.8328e-05 - accuracy: 0.9947 - val_loss: 1.4877e-04 - val_accuracy: 0.9947
# Epoch 110/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.5651e-05 - accuracy: 0.9947 - val_loss: 1.7147e-04 - val_accuracy: 0.9947
# Epoch 111/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.5660e-05 - accuracy: 0.9947 - val_loss: 1.3529e-04 - val_accuracy: 0.9947
# Epoch 112/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.6705e-05 - accuracy: 0.9947 - val_loss: 1.2676e-04 - val_accuracy: 0.9947
# Epoch 113/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.3112e-05 - accuracy: 0.9947 - val_loss: 1.0357e-04 - val_accuracy: 0.9947
# Epoch 114/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.1730e-05 - accuracy: 0.9947 - val_loss: 1.1583e-04 - val_accuracy: 0.9947
# Epoch 115/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.0563e-05 - accuracy: 0.9947 - val_loss: 1.3463e-04 - val_accuracy: 0.9947
# Epoch 116/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.1394e-05 - accuracy: 0.9947 - val_loss: 1.1457e-04 - val_accuracy: 0.9947
# Epoch 117/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1696e-05 - accuracy: 0.9947 - val_loss: 1.1592e-04 - val_accuracy: 0.9947
# Epoch 118/200
# 115/115 [==============================] - 1s 9ms/step - loss: 6.3183e-05 - accuracy: 0.9947 - val_loss: 1.3658e-04 - val_accuracy: 0.9947
# Epoch 119/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.5536e-05 - accuracy: 0.9947 - val_loss: 1.2449e-04 - val_accuracy: 0.9947
# Epoch 120/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.1537e-05 - accuracy: 0.9947 - val_loss: 1.2198e-04 - val_accuracy: 0.9947
# Epoch 121/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.5174e-05 - accuracy: 0.9947 - val_loss: 1.1678e-04 - val_accuracy: 0.9947
# Epoch 122/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.6180e-05 - accuracy: 0.9947 - val_loss: 1.2681e-04 - val_accuracy: 0.9947
# Epoch 123/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.3292e-05 - accuracy: 0.9947 - val_loss: 1.7876e-04 - val_accuracy: 0.9947
# Epoch 124/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.6057e-05 - accuracy: 0.9947 - val_loss: 1.2104e-04 - val_accuracy: 0.9947
# Epoch 125/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1870e-05 - accuracy: 0.9947 - val_loss: 1.1351e-04 - val_accuracy: 0.9947
# Epoch 126/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.0866e-05 - accuracy: 0.9947 - val_loss: 1.0534e-04 - val_accuracy: 0.9947
# Epoch 127/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.9764e-05 - accuracy: 0.9947 - val_loss: 1.2824e-04 - val_accuracy: 0.9947
# Epoch 128/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.9939e-05 - accuracy: 0.9947 - val_loss: 1.1280e-04 - val_accuracy: 0.9947
# Epoch 129/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1693e-05 - accuracy: 0.9947 - val_loss: 1.0841e-04 - val_accuracy: 0.9947
# Epoch 130/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.3503e-05 - accuracy: 0.9947 - val_loss: 1.1821e-04 - val_accuracy: 0.9947
# Epoch 131/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.6151e-05 - accuracy: 0.9947 - val_loss: 1.4611e-04 - val_accuracy: 0.9947
# Epoch 132/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.7729e-05 - accuracy: 0.9947 - val_loss: 1.4692e-04 - val_accuracy: 0.9947
# Epoch 133/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.4520e-05 - accuracy: 0.9947 - val_loss: 1.3757e-04 - val_accuracy: 0.9947
# Epoch 134/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1196e-05 - accuracy: 0.9947 - val_loss: 1.2673e-04 - val_accuracy: 0.9947
# Epoch 135/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.6397e-05 - accuracy: 0.9947 - val_loss: 1.4204e-04 - val_accuracy: 0.9947
# Epoch 136/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.3100e-05 - accuracy: 0.9947 - val_loss: 1.1839e-04 - val_accuracy: 0.9947
# Epoch 137/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.1508e-05 - accuracy: 0.9947 - val_loss: 1.1296e-04 - val_accuracy: 0.9947
# Epoch 138/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.0153e-05 - accuracy: 0.9947 - val_loss: 1.0097e-04 - val_accuracy: 0.9947
# Epoch 139/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.8786e-05 - accuracy: 0.9947 - val_loss: 1.0935e-04 - val_accuracy: 0.9947
# Epoch 140/200
# 115/115 [==============================] - 1s 11ms/step - loss: 4.8192e-05 - accuracy: 0.9947 - val_loss: 1.0303e-04 - val_accuracy: 0.9947
# Epoch 141/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.7807e-05 - accuracy: 0.9947 - val_loss: 1.1773e-04 - val_accuracy: 0.9947
# Epoch 142/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.7717e-05 - accuracy: 0.9947 - val_loss: 1.0408e-04 - val_accuracy: 0.9947
# Epoch 143/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.7951e-05 - accuracy: 0.9947 - val_loss: 1.0618e-04 - val_accuracy: 0.9947
# Epoch 144/200
# 115/115 [==============================] - 1s 11ms/step - loss: 4.7942e-05 - accuracy: 0.9947 - val_loss: 1.1508e-04 - val_accuracy: 0.9947
# Epoch 145/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.7488e-05 - accuracy: 0.9947 - val_loss: 1.0735e-04 - val_accuracy: 0.9947
# Epoch 146/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.6809e-05 - accuracy: 0.9947 - val_loss: 1.1603e-04 - val_accuracy: 0.9947
# Epoch 147/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.7202e-05 - accuracy: 0.9947 - val_loss: 1.0557e-04 - val_accuracy: 0.9947
# Epoch 148/200
# 115/115 [==============================] - 1s 11ms/step - loss: 4.7074e-05 - accuracy: 0.9947 - val_loss: 1.0722e-04 - val_accuracy: 0.9947
# Epoch 149/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.7253e-05 - accuracy: 0.9947 - val_loss: 1.1201e-04 - val_accuracy: 0.9947
# Epoch 150/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.7574e-05 - accuracy: 0.9947 - val_loss: 1.4576e-04 - val_accuracy: 0.9947
# Epoch 151/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.7588e-05 - accuracy: 0.9947 - val_loss: 1.0779e-04 - val_accuracy: 0.9947
# Epoch 152/200
# 115/115 [==============================] - 1s 9ms/step - loss: 4.7073e-05 - accuracy: 0.9947 - val_loss: 1.1157e-04 - val_accuracy: 0.9947
# Epoch 153/200
# 115/115 [==============================] - 1s 11ms/step - loss: 4.7439e-05 - accuracy: 0.9947 - val_loss: 1.2249e-04 - val_accuracy: 0.9947
# Epoch 154/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.8454e-05 - accuracy: 0.9947 - val_loss: 1.1819e-04 - val_accuracy: 0.9947
# Epoch 155/200
# 115/115 [==============================] - 1s 11ms/step - loss: 4.8454e-05 - accuracy: 0.9947 - val_loss: 1.3137e-04 - val_accuracy: 0.9947
# Epoch 156/200
# 115/115 [==============================] - 1s 11ms/step - loss: 4.9834e-05 - accuracy: 0.9947 - val_loss: 1.5352e-04 - val_accuracy: 0.9947
# Epoch 157/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.1121e-05 - accuracy: 0.9947 - val_loss: 1.4961e-04 - val_accuracy: 0.9947
# Epoch 158/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.5497e-05 - accuracy: 0.9947 - val_loss: 1.2729e-04 - val_accuracy: 0.9947
# Epoch 159/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.8495e-05 - accuracy: 0.9947 - val_loss: 1.4300e-04 - val_accuracy: 0.9947
# Epoch 160/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.1804e-05 - accuracy: 0.9947 - val_loss: 1.5024e-04 - val_accuracy: 0.9947
# Epoch 161/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.3913e-05 - accuracy: 0.9947 - val_loss: 1.7835e-04 - val_accuracy: 0.9947
# Epoch 162/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.3843e-05 - accuracy: 0.9947 - val_loss: 1.5281e-04 - val_accuracy: 0.9947
# Epoch 163/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.0908e-05 - accuracy: 0.9947 - val_loss: 1.2308e-04 - val_accuracy: 0.9947
# Epoch 164/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.8021e-05 - accuracy: 0.9947 - val_loss: 1.2566e-04 - val_accuracy: 0.9947
# Epoch 165/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.8152e-05 - accuracy: 0.9947 - val_loss: 1.2025e-04 - val_accuracy: 0.9947
# Epoch 166/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.6627e-05 - accuracy: 0.9947 - val_loss: 1.1131e-04 - val_accuracy: 0.9947
# Epoch 167/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.3060e-05 - accuracy: 0.9947 - val_loss: 1.0959e-04 - val_accuracy: 0.9947
# Epoch 168/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.1498e-05 - accuracy: 0.9947 - val_loss: 1.2140e-04 - val_accuracy: 0.9947
# Epoch 169/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.0580e-05 - accuracy: 0.9947 - val_loss: 1.1937e-04 - val_accuracy: 0.9947
# Epoch 170/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.0348e-05 - accuracy: 0.9947 - val_loss: 1.1723e-04 - val_accuracy: 0.9947
# Epoch 171/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.0364e-05 - accuracy: 0.9947 - val_loss: 1.2089e-04 - val_accuracy: 0.9947
# Epoch 172/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.0289e-05 - accuracy: 0.9947 - val_loss: 1.1921e-04 - val_accuracy: 0.9947
# Epoch 173/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.0859e-05 - accuracy: 0.9947 - val_loss: 1.5048e-04 - val_accuracy: 0.9947
# Epoch 174/200
# 115/115 [==============================] - 1s 12ms/step - loss: 5.2566e-05 - accuracy: 0.9947 - val_loss: 1.3798e-04 - val_accuracy: 0.9947
# Epoch 175/200
# 115/115 [==============================] - 1s 11ms/step - loss: 5.5706e-05 - accuracy: 0.9947 - val_loss: 1.3417e-04 - val_accuracy: 0.9947
# Epoch 176/200
# 115/115 [==============================] - 1s 9ms/step - loss: 6.1310e-05 - accuracy: 0.9947 - val_loss: 1.4360e-04 - val_accuracy: 0.9947
# Epoch 177/200
# 115/115 [==============================] - 1s 11ms/step - loss: 6.9403e-05 - accuracy: 0.9947 - val_loss: 1.2182e-04 - val_accuracy: 0.9947
# Epoch 178/200
# 115/115 [==============================] - 1s 10ms/step - loss: 7.3873e-05 - accuracy: 0.9947 - val_loss: 1.4579e-04 - val_accuracy: 0.9947
# Epoch 179/200
# 115/115 [==============================] - 1s 10ms/step - loss: 6.5765e-05 - accuracy: 0.9947 - val_loss: 1.4905e-04 - val_accuracy: 0.9947
# Epoch 180/200
# 115/115 [==============================] - 1s 10ms/step - loss: 5.4903e-05 - accuracy: 0.9947 - val_loss: 1.4955e-04 - val_accuracy: 0.9947
# Epoch 181/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.8616e-05 - accuracy: 0.9947 - val_loss: 1.4798e-04 - val_accuracy: 0.9947
# Epoch 182/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.4322e-05 - accuracy: 0.9947 - val_loss: 1.2781e-04 - val_accuracy: 0.9947
# Epoch 183/200
# 115/115 [==============================] - 1s 9ms/step - loss: 4.1913e-05 - accuracy: 0.9947 - val_loss: 1.2796e-04 - val_accuracy: 0.9947
# Epoch 184/200
# 115/115 [==============================] - 1s 10ms/step - loss: 4.0408e-05 - accuracy: 0.9947 - val_loss: 1.1727e-04 - val_accuracy: 0.9947
# Epoch 185/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.9495e-05 - accuracy: 0.9947 - val_loss: 1.2419e-04 - val_accuracy: 0.9947
# Epoch 186/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.8767e-05 - accuracy: 0.9947 - val_loss: 1.1168e-04 - val_accuracy: 0.9947
# Epoch 187/200
# 115/115 [==============================] - 1s 11ms/step - loss: 3.8428e-05 - accuracy: 0.9947 - val_loss: 1.3036e-04 - val_accuracy: 0.9947
# Epoch 188/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.8165e-05 - accuracy: 0.9947 - val_loss: 1.2100e-04 - val_accuracy: 0.9947
# Epoch 189/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.8106e-05 - accuracy: 0.9947 - val_loss: 1.2371e-04 - val_accuracy: 0.9947
# Epoch 190/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.8377e-05 - accuracy: 0.9947 - val_loss: 1.1059e-04 - val_accuracy: 0.9947
# Epoch 191/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.8189e-05 - accuracy: 0.9947 - val_loss: 1.2749e-04 - val_accuracy: 0.9947
# Epoch 192/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.8015e-05 - accuracy: 0.9947 - val_loss: 1.0895e-04 - val_accuracy: 0.9947
# Epoch 193/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.7845e-05 - accuracy: 0.9947 - val_loss: 1.4824e-04 - val_accuracy: 0.9947
# Epoch 194/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.7724e-05 - accuracy: 0.9947 - val_loss: 1.3621e-04 - val_accuracy: 0.9947
# Epoch 195/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.7982e-05 - accuracy: 0.9947 - val_loss: 1.2417e-04 - val_accuracy: 0.9947
# Epoch 196/200
# 115/115 [==============================] - 1s 11ms/step - loss: 3.7798e-05 - accuracy: 0.9947 - val_loss: 1.1360e-04 - val_accuracy: 0.9947
# Epoch 197/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.7577e-05 - accuracy: 0.9947 - val_loss: 1.1445e-04 - val_accuracy: 0.9947
# Epoch 198/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.7448e-05 - accuracy: 0.9947 - val_loss: 1.1416e-04 - val_accuracy: 0.9947
# Epoch 199/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.7590e-05 - accuracy: 0.9947 - val_loss: 1.7101e-04 - val_accuracy: 0.9947
# Epoch 200/200
# 115/115 [==============================] - 1s 10ms/step - loss: 3.8304e-05 - accuracy: 0.9947 - val_loss: 1.0863e-04 - val_accuracy: 0.9947
# Saved in: cache/th_optics_100000.h5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 60, 60, 1)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  leaky_re_lu (LeakyReLU)     (None, 30, 30, 32)        0
#
#  batch_normalization (BatchN  (None, 30, 30, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 15, 15, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 15, 15, 64)        0
#
#  batch_normalization_1 (Batc  (None, 15, 15, 64)       256
#  hNormalization)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 16)                230416
#
# =================================================================
# Total params: 249,616
# Trainable params: 249,424
# Non-trainable params: 192
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 16)]              0
#
#  decoder (Functional)        (None, 60, 60, 1)         300865
#
# =================================================================
# Total params: 300,865
# Trainable params: 300,673
# Non-trainable params: 192
# _________________________________________________________________
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1920x1152 at 0x17A7E635D30>

# %%
from keras.models import load_model

def encoder_embedding(model_file, test_set):
    encoder = load_model(model_file.replace('.h5', '-encoder.h5'))
    embedding = encoder.predict(test_set)
    #with_c = np.vstack([v, np.ones(v.shape) * c])
    #transposed = with_c.transpose()
    return embedding

# %%
def dbscan(embedding, t_files, eps):
    img_count = len(embedding)
    threshold = 1
    p = 16

    #for a in range(emb_array.shape[0]):
    #    emb_array[a] = emb_array[a] / w

    #emb_array_copy = np.copy(emb_array[0:img_count, 3:50])
    emb_array_copy = np.copy(embedding[0:img_count, 0:p])


    from sklearn.cluster import DBSCAN
    from sklearn import metrics
    from sklearn.datasets import make_blobs
    from sklearn.preprocessing import StandardScaler

    db = DBSCAN(min_samples=5, eps=eps).fit(emb_array_copy)
    #core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
    #core_samples_mask[db.core_sample_indices_] = True
    labels = db.labels_

    # Number of clusters in labels, ignoring noise if present.
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise_ = list(labels).count(-1)

    import matplotlib.pyplot as plt

    # Black removed and is used for noise instead.
    """
    unique_labels = set(labels)
    colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
    for k, col in zip(unique_labels, colors):
        if k == -1:
            # Black used for noise.
            col = [0, 0, 0, 1]

        class_member_mask = labels == k

        xy = emb_array_copy[class_member_mask & core_samples_mask]
        plt.plot(
            xy[:, 0],
            xy[:, 1],
            "o",
            markerfacecolor=tuple(col),
            markeredgecolor="k",
            markersize=14,
        )

        xy = emb_array_copy[class_member_mask & ~core_samples_mask]
        plt.plot(
            xy[:, 0],
            xy[:, 1],
            "o",
            markerfacecolor=tuple(col),
            markeredgecolor="k",
            markersize=6,
        )
    """
    result = np.where(labels == -1)
    my_ids = result[0]
    print(labels)
    print(my_ids)
    print(len(my_ids))


    import matplotlib.pyplot as plt


    fig = plt.figure(figsize=(32, 32))
    columns = 5
    rows = int(len(my_ids) / 5) + 1

    for aaa in range(len(my_ids)):
        #img_help = cv2.imread('d:\\dane\\credo\\png\\' + all_files_names[my_ids[aaa]])
        img_help = cv2.imread(t_files[my_ids[aaa]])
        print(t_files[my_ids[aaa]])

        aaa1 = aaa + 1
        xxxxx = (aaa % 5) + 1
        r = fig.add_subplot(rows, columns, aaa1)
        r.axis("off")
        plt.imshow(img_help)
        #cv2.imshow(str(aaa), img_help)
        #print(all_files_names[my_ids[0]])

    plt.show()

# %%
tracks_embedding = encoder_embedding(TRACKS_AC, tracks2_set[tracks2_test])
tracks_t_files = np.asarray(tacks2_files)[tracks2_test]
dbscan(tracks_embedding, tracks_t_files, 120)
# Out:
# [-1  0  0 ...  0  0  0]
# [   0    9   36   59   91  134  157  175  194  280  319  320  370  429
#   431  447  466  504  524  576  613  617  634  675  722  809  855  875
#   907  951  985 1007 1023 1030 1037 1203]
# 36
# hit-images-final2/line\23321006.png
# hit-images-final2/line\11853599.png
# hit-images-final2/line\24274103.png
# hit-images-final2/line\23278286.png
# hit-images-final2/line\23143320.png
# hit-images-final2/line\23769959.png
# hit-images-final2/line\23300748.png
# hit-images-final2/line\22171264.png
# hit-images-final2/line\23915027.png
# hit-images-final2/line\24579151.png
# hit-images-final2/line\22508283.png
# hit-images-final2/line\23321006.png
# hit-images-final2/line\23777350.png
# hit-images-final2/line\23654690.png
# hit-images-final2/line\17223488.png
# hit-images-final2/line\22009779.png
# hit-images-final2/line\17643570.png
# hit-images-final2/line\22445078.png
# hit-images-final2/line\14276151.png
# hit-images-final2/line\23214854.png
# hit-images-final2/line\23278286.png
# hit-images-final2/line\11834173.png
# hit-images-final2/line\13827658.png
# hit-images-final2/line\22177963.png
# hit-images-final2/line\23375637.png
# hit-images-final2/line\23186082.png
# hit-images-final2/line\22032561.png
# hit-images-final2/line\22171278.png
# hit-images-final2/line\23478695.png
# hit-images-final2/line\22508283.png
# hit-images-final2/line\24139535.png
# hit-images-final2/line\23769437.png
# hit-images-final2/line\24579151.png
# hit-images-final2/line\13873250.png
# hit-images-final2/line\22500203.png
# hit-images-final2/line\23929607.png

# %%
worms_embedding = encoder_embedding(TRACKS_AC, worms2_set[worms2_test])
worms_t_files = np.asarray(worms2_files)[worms2_test]

embedding = np.vstack([tracks_embedding, worms_embedding])
t_files = np.hstack([tracks_t_files, worms_t_files])

dbscan(embedding, t_files, 140)
# Out:
# [-1  0  0 ...  0 -1  0]
# [   0  280  320  466  613 1226 1229 1230 1235 1257 1264 1275 1276 1297
#  1303 1309 1312 1321 1324 1334 1345 1372 1374 1376 1383 1395 1405 1423]
# 28
# hit-images-final2/line\23321006.png
# hit-images-final2/line\24579151.png
# hit-images-final2/line\23321006.png
# hit-images-final2/line\17643570.png
# hit-images-final2/line\23278286.png
# hit-images-final2/worms\11699067.png
# hit-images-final2/worms\22110467.png
# hit-images-final2/worms\22437786.png
# hit-images-final2/worms\13836130.png
# hit-images-final2/worms\11823281.png
# hit-images-final2/worms\22250688.png
# hit-images-final2/worms\22008402.png
# hit-images-final2/worms\11822754.png
# hit-images-final2/worms\22347601.png
# hit-images-final2/worms\22030300.png
# hit-images-final2/worms\22110467.png
# hit-images-final2/worms\22436594.png
# hit-images-final2/worms\22391460.png
# hit-images-final2/worms\22013151.png
# hit-images-final2/worms\22351432.png
# hit-images-final2/worms\22300627.png
# hit-images-final2/worms\22011869.png
# hit-images-final2/worms\22280257.png
# hit-images-final2/worms\22177539.png
# hit-images-final2/worms\22030411.png
# hit-images-final2/worms\22376080.png
# hit-images-final2/worms\22484485.png
# hit-images-final2/worms\22400258.png

# %%
me_set, me_files = load_images('hit-images-final2/me')
me_embedding = encoder_embedding(TRACKS_AC, me_set)
me_files = np.asarray(me_files)

embedding = np.vstack([tracks_embedding, me_embedding])
t_files = np.hstack([tracks_t_files, me_files])

dbscan(embedding, t_files, 150)
# Out:
# [-1  0  0 ...  0  0 -1]
# [   0 1226]
# 2
# hit-images-final2/line\23321006.png
# hit-images-final2/me\6044.png

# %%
def optics(embedding, t_files, eps):
    img_count = len(embedding)
    threshold = 1
    p = 16

    #for a in range(emb_array.shape[0]):
    #    emb_array[a] = emb_array[a] / w

    #emb_array_copy = np.copy(emb_array[0:img_count, 3:50])
    emb_array_copy = np.copy(embedding[0:img_count, 0:p])


    from sklearn.cluster import OPTICS
    from sklearn import metrics
    from sklearn.datasets import make_blobs
    from sklearn.preprocessing import StandardScaler

    db = OPTICS(min_samples=5, cluster_method='dbscan', eps=eps).fit(emb_array_copy)
    #core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
    #core_samples_mask[db.core_sample_indices_] = True
    labels = db.labels_

    # Number of clusters in labels, ignoring noise if present.
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise_ = list(labels).count(-1)

    import matplotlib.pyplot as plt

    # Black removed and is used for noise instead.
    """
    unique_labels = set(labels)
    colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
    for k, col in zip(unique_labels, colors):
        if k == -1:
            # Black used for noise.
            col = [0, 0, 0, 1]

        class_member_mask = labels == k

        xy = emb_array_copy[class_member_mask & core_samples_mask]
        plt.plot(
            xy[:, 0],
            xy[:, 1],
            "o",
            markerfacecolor=tuple(col),
            markeredgecolor="k",
            markersize=14,
        )

        xy = emb_array_copy[class_member_mask & ~core_samples_mask]
        plt.plot(
            xy[:, 0],
            xy[:, 1],
            "o",
            markerfacecolor=tuple(col),
            markeredgecolor="k",
            markersize=6,
        )
    """
    result = np.where(labels == -1)
    my_ids = result[0]
    print(labels)
    print(my_ids)
    print(len(my_ids))


    import matplotlib.pyplot as plt


    fig = plt.figure(figsize=(32, 32))
    columns = 5
    rows = int(len(my_ids) / 5) + 1

    for aaa in range(len(my_ids)):
        #img_help = cv2.imread('d:\\dane\\credo\\png\\' + all_files_names[my_ids[aaa]])
        img_help = cv2.imread(t_files[my_ids[aaa]])
        print(t_files[my_ids[aaa]])

        aaa1 = aaa + 1
        xxxxx = (aaa % 5) + 1
        r = fig.add_subplot(rows, columns, aaa1)
        r.axis("off")
        plt.imshow(img_help)
        #cv2.imshow(str(aaa), img_help)
        #print(all_files_names[my_ids[0]])

    plt.show()

# %%
tracks_embedding = encoder_embedding(TRACKS_AC, tracks2_set[tracks2_test])
tracks_t_files = np.asarray(tacks2_files)[tracks2_test]
optics(tracks_embedding, tracks_t_files, 120)
# Out:
# [-1  0  0 ...  0  0  0]
# [   0    9   36   59   91  134  157  175  194  280  319  320  370  429
#   431  447  466  504  524  576  613  617  634  675  722  809  855  875
#   907  951  985 1007 1023 1030 1037 1203]
# 36
# hit-images-final2/line\23321006.png
# hit-images-final2/line\11853599.png
# hit-images-final2/line\24274103.png
# hit-images-final2/line\23278286.png
# hit-images-final2/line\23143320.png
# hit-images-final2/line\23769959.png
# hit-images-final2/line\23300748.png
# hit-images-final2/line\22171264.png
# hit-images-final2/line\23915027.png
# hit-images-final2/line\24579151.png
# hit-images-final2/line\22508283.png
# hit-images-final2/line\23321006.png
# hit-images-final2/line\23777350.png
# hit-images-final2/line\23654690.png
# hit-images-final2/line\17223488.png
# hit-images-final2/line\22009779.png
# hit-images-final2/line\17643570.png
# hit-images-final2/line\22445078.png
# hit-images-final2/line\14276151.png
# hit-images-final2/line\23214854.png
# hit-images-final2/line\23278286.png
# hit-images-final2/line\11834173.png
# hit-images-final2/line\13827658.png
# hit-images-final2/line\22177963.png
# hit-images-final2/line\23375637.png
# hit-images-final2/line\23186082.png
# hit-images-final2/line\22032561.png
# hit-images-final2/line\22171278.png
# hit-images-final2/line\23478695.png
# hit-images-final2/line\22508283.png
# hit-images-final2/line\24139535.png
# hit-images-final2/line\23769437.png
# hit-images-final2/line\24579151.png
# hit-images-final2/line\13873250.png
# hit-images-final2/line\22500203.png
# hit-images-final2/line\23929607.png

# %%
worms_embedding = encoder_embedding(TRACKS_AC, worms2_set[worms2_test])
worms_t_files = np.asarray(worms2_files)[worms2_test]

embedding = np.vstack([tracks_embedding, worms_embedding])
t_files = np.hstack([tracks_t_files, worms_t_files])

optics(embedding, t_files, 140)
# Out:
# [-1  0  0 ...  0 -1  0]
# [   0  280  320  466  613 1226 1229 1230 1235 1257 1264 1275 1276 1297
#  1303 1309 1312 1321 1324 1334 1345 1372 1374 1376 1383 1395 1405 1423]
# 28
# hit-images-final2/line\23321006.png
# hit-images-final2/line\24579151.png
# hit-images-final2/line\23321006.png
# hit-images-final2/line\17643570.png
# hit-images-final2/line\23278286.png
# hit-images-final2/worms\11699067.png
# hit-images-final2/worms\22110467.png
# hit-images-final2/worms\22437786.png
# hit-images-final2/worms\13836130.png
# hit-images-final2/worms\11823281.png
# hit-images-final2/worms\22250688.png
# hit-images-final2/worms\22008402.png
# hit-images-final2/worms\11822754.png
# hit-images-final2/worms\22347601.png
# hit-images-final2/worms\22030300.png
# hit-images-final2/worms\22110467.png
# hit-images-final2/worms\22436594.png
# hit-images-final2/worms\22391460.png
# hit-images-final2/worms\22013151.png
# hit-images-final2/worms\22351432.png
# hit-images-final2/worms\22300627.png
# hit-images-final2/worms\22011869.png
# hit-images-final2/worms\22280257.png
# hit-images-final2/worms\22177539.png
# hit-images-final2/worms\22030411.png
# hit-images-final2/worms\22376080.png
# hit-images-final2/worms\22484485.png
# hit-images-final2/worms\22400258.png

# %%
me_set, me_files = load_images('hit-images-final2/me')
me_embedding = encoder_embedding(TRACKS_AC, me_set)
me_files = np.asarray(me_files)

embedding = np.vstack([tracks_embedding, me_embedding])
t_files = np.hstack([tracks_t_files, me_files])

optics(embedding, t_files, 120)
# Out:
# [-1  0  0 ...  0  0 -1]
# [   0    9   36   59   91  134  157  175  194  280  319  320  370  429
#   431  447  466  504  524  576  613  617  634  675  722  809  855  875
#   907  951  985 1007 1023 1030 1037 1203 1226]
# 37
# hit-images-final2/line\23321006.png
# hit-images-final2/line\11853599.png
# hit-images-final2/line\24274103.png
# hit-images-final2/line\23278286.png
# hit-images-final2/line\23143320.png
# hit-images-final2/line\23769959.png
# hit-images-final2/line\23300748.png
# hit-images-final2/line\22171264.png
# hit-images-final2/line\23915027.png
# hit-images-final2/line\24579151.png
# hit-images-final2/line\22508283.png
# hit-images-final2/line\23321006.png
# hit-images-final2/line\23777350.png
# hit-images-final2/line\23654690.png
# hit-images-final2/line\17223488.png
# hit-images-final2/line\22009779.png
# hit-images-final2/line\17643570.png
# hit-images-final2/line\22445078.png
# hit-images-final2/line\14276151.png
# hit-images-final2/line\23214854.png
# hit-images-final2/line\23278286.png
# hit-images-final2/line\11834173.png
# hit-images-final2/line\13827658.png
# hit-images-final2/line\22177963.png
# hit-images-final2/line\23375637.png
# hit-images-final2/line\23186082.png
# hit-images-final2/line\22032561.png
# hit-images-final2/line\22171278.png
# hit-images-final2/line\23478695.png
# hit-images-final2/line\22508283.png
# hit-images-final2/line\24139535.png
# hit-images-final2/line\23769437.png
# hit-images-final2/line\24579151.png
# hit-images-final2/line\13873250.png
# hit-images-final2/line\22500203.png
# hit-images-final2/line\23929607.png
# hit-images-final2/me\6044.png

# %%
me_set, me_files = load_images('hit-images-final2/me')
me_embedding = encoder_embedding(TRACKS_AC, me_set)
me_files = np.asarray(me_files)

embedding = np.vstack([tracks_embedding, me_embedding])
t_files = np.hstack([tracks_t_files, me_files])

optics(embedding, t_files, 180)
# Out:
# [ 0  0  0 ...  0  0 -1]
# [1226]
# 1
# hit-images-final2/me\6044.png
