# %%
import numpy as np

from commons import *
from dataset_loader import load_images, prepare_dataset
from IPython.display import display
import cv2
import pickle
import matplotlib.pyplot as plt
from keras.models import load_model


# TODO: https://pl.wikipedia.org/wiki/Dywergencja_Kullbacka-Leiblera
# https://towardsdatascience.com/kl-divergence-python-example-b87069e4b810
# TODO: entropia wzajemna, cross entropy


DOTS_SRC = 'hit-images-final2/dot'
TRACKS_SRC = 'hit-images-final2/line'
WORMS_SRC = 'hit-images-final2/worms'
ARTIFACTS_SRC = 'hit-images-final2/artefact'

DOTS_AC = 'cache/dots_v2_hough.h5'
TRACKS_AC = 'cache/tracks_v2_hough.h5'
WORMS_AC = 'cache/worms_v2_hough.h5'
ARTIFACTS_AC = 'cache/artifacts_v2_hough.h5'

dots_set =  prepare_dataset(normalize_rotation(load_images(DOTS_SRC)))
worms_set =  prepare_dataset(normalize_rotation(load_images(WORMS_SRC)))
tracks_set =  prepare_dataset(normalize_rotation(load_images(TRACKS_SRC)))
artifacts_set =  prepare_dataset(normalize_rotation(load_images(ARTIFACTS_SRC)))

dots_autoencoder = load_model(DOTS_AC)
worms_autoencoder = load_model(WORMS_AC)
tracks_autoencoder = load_model(TRACKS_AC)
artifacts_autoencoder = load_model(ARTIFACTS_AC)

# %%
# def find_threshold(sa, sb):
#     a = sorted(sa)
#     b = sorted(sb)
#
#     la = len(a)
#     lb = len(b)
#
#     if la > lb:
#         from scipy.ndimage import zoom
#         a2 = zoom(a, lb / la)
#         a = a2
#     elif la < lb:
#         from scipy.ndimage import zoom
#         b2 = zoom(b, la / lb)
#         b = b2
#
#     la = len(a)
#     lb = len(b)
#
#     ta = int(la // 2)
#     tb = int(lb // 2)
#
#     ca = a[ta]
#     cb = b[tb]
#
#     if ca > cb:
#         swap = a
#         a = b
#         b = swap
#
#     np_a = np.array(a)
#     np_b = np.array(b)
#
#     np_a_ex = append_label_column(np_a, 1)
#     np_b_ex = append_label_column(np_b, 2)
#
#     left = 4
#     right = 3
#
#     np_ab = np.vstack([np_a_ex, np_b_ex])
#     np_ab = np_ab[np_ab[:, 0].argsort()]
#
#     labels = np_ab[:,1]
#
#     cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
#     cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
#     cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
#     cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())
#
#     np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])
#
#     half = 0
#     for row in np_ab_ex:
#         rl = row[left]
#         rr = row[right]
#         if rl > rr:
#             break
#         half += 1
#
#     threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2
#
#     fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
#     fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]
#
#     percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100
#
#     return threshold, percent
#

config = {}

dm_funcs = [dm_func_mean2, dm_func_avg_hash, dm_func_p_hash, dm_func_d_hash, dm_func_haar_hash, dm_func_db4_hash] #  , dm_func_cr_hash, dm_func_color_hash
#dm_funcs = [dm_func_mean2]
cutoff_backgrounds = [True, False]
normalizes = [True, False]
autoencoders = [
    (dots_autoencoder, 'dots', dots_set),
    (worms_autoencoder, 'worms', worms_set),
    (tracks_autoencoder, 'tracks', tracks_set),
    (artifacts_autoencoder, 'artifacts', artifacts_set)
]

#calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, normalize=True, cutoff_background=False)
#trained_set = calculated['dots']
#other_set = np.hstack([calculated['worms'], calculated['tracks'], calculated['artifacts']])




for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = []
            for dm_func in dm_funcs:
                print('====| dm_func = %s, cutoff_background = %s, normalize = %s |====' % (str(dm_func.__name__), str(cutoff_background), str(normalize)))
                argv = {'cutoff_background': cutoff_background, 'normalize': normalize, 'dm_func': dm_func}

                #dots_reconstruction = autoencoder.predict(dots_set) if name != 'dots' else []
                #worms_reconstruction = autoencoder.predict(worms_set) if name != 'worms' else []
                #tracks_reconstruction = autoencoder.predict(tracks_set) if name != 'tracks' else []
                #artifacts_reconstruction = autoencoder.predict(artifacts_set) if name != 'artifacts' else []

                #others = np.vstack([dots_reconstruction, worms_reconstruction, tracks_reconstruction, artifacts_reconstruction])

                #prepare_for_histogram(trained_set, others, dm_func, **argv)

                calculated = calc_similarity(dots_autoencoder, dots_set, tracks_set, worms_set, artifacts_set, **argv)

                trained_set = calculated[name]
                other_set = []
                for sn in calculated.keys():
                    if sn != name:
                        other_set.append(calculated[sn])
                other_set = np.hstack(other_set)

                threshold, percent = find_threshold(trained_set, other_set)
                plot_threshold(trained_set, other_set, threshold, 'dots', 'others')

                print('Channel %s, threshold: %f, percent: %f' % (name, threshold, percent))

                rows.append((dm_func.__name__, str(cutoff_background), str(normalize), calculated, threshold))
            config[(autoencoder, cutoff_background, normalize)] = rows
# Out:
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 2s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 9ms/step
# Channel dots, threshold: -12.373723, percent: 2.106667
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 72.986667
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 67.973333
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 65.013333
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.076387, percent: 26.266667
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.246504, percent: 25.973333
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 1s 10ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: -6.485200, percent: 2.053333
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 72.933333
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 67.920000
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 64.960000
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 9.000000, percent: 40.533333
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 8ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 29.000000, percent: 30.373333
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: -12.159778, percent: 2.026667
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 96.240000
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 65.946667
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 65.760000
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.077143, percent: 29.306667
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.250000, percent: 28.693333
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: -7.565939, percent: 5.040000
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 96.240000
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 0.000000, percent: 65.920000
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel dots, threshold: 0.000000, percent: 65.680000
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 10.000000, percent: 38.133333
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel dots, threshold: 30.000000, percent: 29.440000
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: -8.916326, percent: 34.879032
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.000972, percent: 28.225806
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.006177, percent: 35.786290
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.001479, percent: 37.802419
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.026052, percent: 34.576613
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.090278, percent: 32.862903
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: -0.121474, percent: 25.907258
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 6ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 1.000000, percent: 34.778226
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 8.000000, percent: 35.584677
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 1.000000, percent: 42.036290
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 1s 12ms/step
# 16/16 [==============================] - 0s 8ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 11.002220, percent: 45.866935
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 6ms/step
# Channel worms, threshold: 38.000000, percent: 39.415323
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: -8.936972, percent: 33.568548
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.001010, percent: 28.427419
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.007258, percent: 38.104839
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.001418, percent: 36.995968
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 0.027005, percent: 33.266129
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 0.092696, percent: 31.754032
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: -0.180848, percent: 24.596774
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 1.000000, percent: 34.979839
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 8.000000, percent: 36.895161
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel worms, threshold: 1.000000, percent: 42.439516
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 12.000000, percent: 48.487903
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel worms, threshold: 38.499990, percent: 40.221774
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: -9.655560, percent: 30.957905
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 74.560822
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 67.268810
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 0.000000, percent: 64.252569
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.048608, percent: 43.172025
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.163265, percent: 42.028505
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 6ms/step
# Channel tracks, threshold: -1.526728, percent: 33.112363
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 1s 8ms/step
# 16/16 [==============================] - 1s 63ms/step
# 96/96 [==============================] - 1s 8ms/step
# 21/21 [==============================] - 0s 8ms/step
# Channel tracks, threshold: 0.000000, percent: 74.494531
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 2s 28ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 1s 14ms/step
# 21/21 [==============================] - 0s 7ms/step
# Channel tracks, threshold: 0.000000, percent: 67.235665
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 1s 17ms/step
# 16/16 [==============================] - 0s 10ms/step
# 96/96 [==============================] - 2s 18ms/step
# 21/21 [==============================] - 0s 19ms/step
# Channel tracks, threshold: 0.000000, percent: 64.202851
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 1s 12ms/step
# 16/16 [==============================] - 0s 12ms/step
# 96/96 [==============================] - 2s 17ms/step
# 21/21 [==============================] - 1s 64ms/step
# Channel tracks, threshold: 10.000000, percent: 43.072589
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 1s 16ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 22ms/step
# Channel tracks, threshold: 33.000000, percent: 37.553861
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: -9.620928, percent: 31.156778
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 83.278091
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 66.970500
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 65.097779
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.049999, percent: 41.017567
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 1s 10ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.175776, percent: 39.774611
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: -1.681151, percent: 28.770302
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 83.228373
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 66.904209
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel tracks, threshold: 0.000000, percent: 65.064634
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 11.000000, percent: 44.812728
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 1s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel tracks, threshold: 34.000000, percent: 39.807756
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 1s 10ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 1s 6ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: -8.908361, percent: 33.746130
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 7ms/step
# Channel artifacts, threshold: 0.000000, percent: 71.052632
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000000, percent: 72.445820
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000000, percent: 42.801858
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.022203, percent: 30.340557
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 6ms/step
# Channel artifacts, threshold: 0.083333, percent: 29.411765
# ====| dm_func = dm_func_mean2, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: -0.188299, percent: 25.773994
# ====| dm_func = dm_func_avg_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 70.975232
# ====| dm_func = dm_func_p_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000000, percent: 72.368421
# ====| dm_func = dm_func_d_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.000000, percent: 42.801858
# ====| dm_func = dm_func_haar_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 10.000000, percent: 48.219814
# ====| dm_func = dm_func_db4_hash, cutoff_background = True, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 33.000000, percent: 49.148607
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 7ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: -9.174668, percent: 42.414861
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000000, percent: 70.820433
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.007136, percent: 37.306502
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000000, percent: 44.504644
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.041322, percent: 45.356037
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = True |====
# 59/59 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 0.148039, percent: 44.969040
# ====| dm_func = dm_func_mean2, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: -1.103083, percent: 41.021672
# ====| dm_func = dm_func_avg_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 6ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000000, percent: 70.820433
# ====| dm_func = dm_func_p_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 12.000000, percent: 32.972136
# ====| dm_func = dm_func_d_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 0.000000, percent: 44.504644
# ====| dm_func = dm_func_haar_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 5ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 5ms/step
# Channel artifacts, threshold: 13.000000, percent: 41.176471
# ====| dm_func = dm_func_db4_hash, cutoff_background = False, normalize = False |====
# 59/59 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# 96/96 [==============================] - 0s 5ms/step
# 21/21 [==============================] - 0s 4ms/step
# Channel artifacts, threshold: 40.000000, percent: 36.145511

# %%
def find_percent(sa, sb, threshold):
    a = sorted(sa)
    b = sorted(sb)

    la = len(a)
    lb = len(b)

    if la > lb:
        from scipy.ndimage import zoom
        a2 = zoom(a, lb / la)
        a = a2
    elif la < lb:
        from scipy.ndimage import zoom
        b2 = zoom(b, la / lb)
        b = b2

    la = len(a)
    lb = len(b)

    ta = int(la // 2)
    tb = int(lb // 2)

    ca = a[ta]
    cb = b[tb]

    if ca > cb:
        swap = a
        a = b
        b = swap

    np_a = np.array(a)
    np_b = np.array(b)

    np_a_ex = append_label_column(np_a, 1)
    np_b_ex = append_label_column(np_b, 2)

    left = 4
    right = 3

    np_ab = np.vstack([np_a_ex, np_b_ex])
    np_ab = np_ab[np_ab[:, 0].argsort()]

    labels = np_ab[:,1]

    cumsum_a = np.where(labels == 1, 1 / len(a), 0).cumsum()
    cumsum_ar = np.flip(np.flip(np.where(labels == 1, 1 / len(a), 0)).cumsum())
    cumsum_b = np.where(labels == 2, 1 / len(b), 0).cumsum()
    cumsum_br = np.flip(np.flip(np.where(labels == 2, 1 / len(b), 0)).cumsum())

    np_ab_ex = np.hstack([np_ab, np.vstack([cumsum_a, cumsum_ar, cumsum_b, cumsum_br]).transpose()])

    half = 0
    for row in np_ab_ex:
        rl = row[left]
        rr = row[right]
        if rl > rr:
            break
        half += 1

    #threshold = (np_ab_ex[half - 1, 0] + np_ab_ex[half, 0])/2

    fp_a = np_ab[np.where((np_ab[:,1] == 1) & (np_ab[:,0] >= threshold))]
    fp_b = np_ab[np.where((np_ab[:,1] == 2) & (np_ab[:,0] <= threshold))]

    percent = (fp_a.shape[0] + fp_b.shape[0]) / np_ab.shape[0] * 100

    return percent


def confusion_matrix2(rows, channel):
    import matplotlib.pyplot as plt

    x_labels = ["dots", "tracks", "worms", "artifacts"]
    y_labels = []

    matrix = np.zeros((len(rows), len(x_labels)), dtype=np.int32)

    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            set_name = x_labels[j]
            (fun_name, cutoff_background, normalize, similarity, threshold) = rows[i]

            la = channel
            lb = set_name

            if la == lb:
                continue

            a = similarity[la]
            b = similarity[lb]


            #threshold, percent = find_threshold(a, b)
            percent = find_percent(a, b, threshold)

            print('Channel %s, compare %s vs %s, threshold: %s, fp/fn percent: %s %%' % (la, la, lb, str(threshold), str(percent)))
            #plot_threshold(a, b, threshold, la, lb)

            matrix[i, j] = int(100 - percent)
        y_labels.append(rows[i][0])

    fig, ax = plt.subplots()
    im = ax.imshow(matrix)

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(x_labels)), labels=x_labels)
    ax.set_yticks(np.arange(len(y_labels)), labels=y_labels)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(0, len(rows)):
        for j in range(0, len(x_labels)):
            text = ax.text(j, i, matrix[i, j], ha="center", va="center", color="w")

    ax.set_title("x - data set, y - compare method")
    fig.tight_layout()
    plt.show()

for autoencoder, name, trained_set in autoencoders:
    for cutoff_background in cutoff_backgrounds:
        for normalize in normalizes:
            rows = config[(autoencoder, cutoff_background, normalize)]
            confusion_matrix2(rows, name)
# Out:
# Channel dots, compare dots vs tracks, threshold: -12.373723225432052, fp/fn percent: 1.3866666666666667 %
# Channel dots, compare dots vs worms, threshold: -12.373723225432052, fp/fn percent: 1.1088709677419355 %
# Channel dots, compare dots vs artifacts, threshold: -12.373723225432052, fp/fn percent: 6.269349845201239 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 74.58666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.141129032258064 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 66.02167182662538 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 67.30666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 55.64516129032258 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 67.56965944272446 %
# Channel dots, compare dots vs tracks, threshold: 0.0, fp/fn percent: 64.18666666666667 %
# Channel dots, compare dots vs worms, threshold: 0.0, fp/fn percent: 53.528225806451616 %
# Channel dots, compare dots vs artifacts, threshold: 0.0, fp/fn percent: 64.00928792569658 %
# Channel dots, compare dots vs tracks, threshold: 0.0763870860890869, fp/fn percent: 28.293333333333333 %
# Channel dots, compare dots vs worms, threshold: 0
666666667 %
# Channel tracks, compare tracks vs worms, threshold: 0.17577552860382406, fp/fn percent: 38.50806451612903 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.17577552860382406, fp/fn percent: 51.857585139318886 %
# Channel tracks, compare tracks vs dots, threshold: -1.681151120986509, fp/fn percent: 14.399999999999999 %
# Channel tracks, compare tracks vs worms, threshold: -1.681151120986509, fp/fn percent: 38.104838709677416 %
# Channel tracks, compare tracks vs artifacts, threshold: -1.681151120986509, fp/fn percent: 54.87616099071207 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 94.98666666666666 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 57.86290322580645 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 68.73065015479877 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 66.88 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 58.568548387096776 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 58.591331269349844 %
# Channel tracks, compare tracks vs dots, threshold: 0.0, fp/fn percent: 64.93333333333334 %
# Channel tracks, compare tracks vs worms, threshold: 0.0, fp/fn percent: 56.451612903225815 %
# Channel tracks, compare tracks vs artifacts, threshold: 0.0, fp/fn percent: 65.01547987616098 %
# Channel tracks, compare tracks vs dots, threshold: 11.0, fp/fn percent: 39.44 %
# Channel tracks, compare tracks vs worms, threshold: 11.0, fp/fn percent: 50.1008064516129 %
# Channel tracks, compare tracks vs artifacts, threshold: 11.0, fp/fn percent: 46.28482972136223 %
# Channel tracks, compare tracks vs dots, threshold: 34.0, fp/fn percent: 30.133333333333333 %
# Channel tracks, compare tracks vs worms, threshold: 34.0, fp/fn percent: 45.766129032258064 %
# Channel tracks, compare tracks vs artifacts, threshold: 34.0, fp/fn percent: 44.349845201238395 %
# Channel artifacts, compare artifacts vs dots, threshold: -8.908361001901286, fp/fn percent: 16.95046439628483 %
# Channel artifacts, compare artifacts vs tracks, threshold: -8.908361001901286, fp/fn percent: 41.56346749226007 %
# Channel artifacts, compare artifacts vs worms, threshold: -8.908361001901286, fp/fn percent: 50.806451612903224 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 66.02167182662538 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 69.04024767801857 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 51.00806451612904 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 67.56965944272446 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 67.26006191950464 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 50.60483870967742 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.3912535318572973e-26, fp/fn percent: 22.21362229102167 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.3912535318572973e-26, fp/fn percent: 47.05882352941176 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.3912535318572973e-26, fp/fn percent: 41.028225806451616 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.022203307961924084, fp/fn percent: 22.678018575851393 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.022203307961924084, fp/fn percent: 32.35294117647059 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.022203307961924084, fp/fn percent: 46.068548387096776 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.08333335993308577, fp/fn percent: 21.28482972136223 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.08333335993308577, fp/fn percent: 31.346749226006192 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.08333335993308577, fp/fn percent: 47.479838709677416 %
# Channel artifacts, compare artifacts vs dots, threshold: -0.18829911335904626, fp/fn percent: 12.925696594427244 %
# Channel artifacts, compare artifacts vs tracks, threshold: -0.18829911335904626, fp/fn percent: 29.64396284829721 %
# Channel artifacts, compare artifacts vs worms, threshold: -0.18829911335904626, fp/fn percent: 49.69758064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 66.02167182662538 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 69.04024767801857 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 51.00806451612904 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 67.49226006191951 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 67.18266253869969 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 50.60483870967742 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.3411121533316737e-23, fp/fn percent: 22.21362229102167 %
# Channel artifacts, compare artifacts vs tracks, threshold: 3.3411121533316737e-23, fp/fn percent: 47.05882352941176 %
# Channel artifacts, compare artifacts vs worms, threshold: 3.3411121533316737e-23, fp/fn percent: 41.12903225806452 %
# Channel artifacts, compare artifacts vs dots, threshold: 10.0, fp/fn percent: 46.43962848297213 %
# Channel artifacts, compare artifacts vs tracks, threshold: 10.0, fp/fn percent: 45.12383900928793 %
# Channel artifacts, compare artifacts vs worms, threshold: 10.0, fp/fn percent: 44.556451612903224 %
# Channel artifacts, compare artifacts vs dots, threshold: 33.00000000000002, fp/fn percent: 36.14551083591331 %
# Channel artifacts, compare artifacts vs tracks, threshold: 33.00000000000002, fp/fn percent: 43.962848297213625 %
# Channel artifacts, compare artifacts vs worms, threshold: 33.00000000000002, fp/fn percent: 40.42338709677419 %
# Channel artifacts, compare artifacts vs dots, threshold: -9.174667872402502, fp/fn percent: 22.987616099071207 %
# Channel artifacts, compare artifacts vs tracks, threshold: -9.174667872402502, fp/fn percent: 57.19814241486068 %
# Channel artifacts, compare artifacts vs worms, threshold: -9.174667872402502, fp/fn percent: 43.44758064516129 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 65.94427244582043 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 68.73065015479877 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 51.00806451612904 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.007136485912001025, fp/fn percent: 20.743034055727556 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.007136485912001025, fp/fn percent: 45.51083591331269 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.007136485912001025, fp/fn percent: 49.79838709677419 %
# Channel artifacts, compare artifacts vs dots, threshold: 1.1894597334906244e-201, fp/fn percent: 27.012383900928793 %
# Channel artifacts, compare artifacts vs tracks, threshold: 1.1894597334906244e-201, fp/fn percent: 44.50464396284829 %
# Channel artifacts, compare artifacts vs worms, threshold: 1.1894597334906244e-201, fp/fn percent: 50.201612903225815 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.04132196256698112, fp/fn percent: 34.59752321981424 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.04132196256698112, fp/fn percent: 49.22600619195047 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.04132196256698112, fp/fn percent: 38.810483870967744 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.1480389148614386, fp/fn percent: 32.43034055727554 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.1480389148614386, fp/fn percent: 49.690402476780186 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.1480389148614386, fp/fn percent: 37.399193548387096 %
# Channel artifacts, compare artifacts vs dots, threshold: -1.103083302227501, fp/fn percent: 20.510835913312693 %
# Channel artifacts, compare artifacts vs tracks, threshold: -1.103083302227501, fp/fn percent: 49.53560371517028 %
# Channel artifacts, compare artifacts vs worms, threshold: -1.103083302227501, fp/fn percent: 33.971774193548384 %
# Channel artifacts, compare artifacts vs dots, threshold: 0.0, fp/fn percent: 65.86687306501547 %
# Channel artifacts, compare artifacts vs tracks, threshold: 0.0, fp/fn percent: 68.73065015479877 %
# Channel artifacts, compare artifacts vs worms, threshold: 0.0, fp/fn percent: 51.00806451612904 %
# Channel artifacts, compare artifacts vs dots, threshold: 12.0, fp/fn percent: 18.03405572755418 %
# Channel artifacts, compare artifacts vs tracks, threshold: 12.0, fp/fn percent: 39.318885448916404 %
# Channel artifacts, compare artifacts vs worms, threshold: 12.0, fp/fn percent: 56.1491935483871 %
# Channel artifacts, compare artifacts vs dots, threshold: 3.500337135293418e-198, fp/fn percent: 27.012383900928793 %
# Channel artifacts, compare artifacts vs tracks, threshold: 3.500337135293418e-198, fp/fn percent: 44.50464396284829 %
# Channel artifacts, compare artifacts vs worms, threshold: 3.500337135293418e-198, fp/fn percent: 50.201612903225815 %
# Channel artifacts, compare artifacts vs dots, threshold: 13.0, fp/fn percent: 34.05572755417957 %
# Channel artifacts, compare artifacts vs tracks, threshold: 13.0, fp/fn percent: 44.73684210526316 %
# Channel artifacts, compare artifacts vs worms, threshold: 13.0, fp/fn percent: 45.26209677419355 %
# Channel artifacts, compare artifacts vs dots, threshold: 40.00000000000001, fp/fn percent: 23.142414860681114 %
# Channel artifacts, compare artifacts vs tracks, threshold: 40.00000000000001, fp/fn percent: 42.18266253869969 %
# Channel artifacts, compare artifacts vs worms, threshold: 40.00000000000001, fp/fn percent: 45.16129032258064 %
